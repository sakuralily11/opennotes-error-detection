# %%
# Import libraries
import os
import re
import random
import pickle
import subprocess
import numpy as np
import pandas as pd
import datetime as dt

from tqdm import tqdm
from datetime import datetime
from collections import Counter

# %% [markdown]
# # 1. Setup concept extractors
#
# Some options were [MetaMap](https://metamap.nlm.nih.gov/) and [spaCy](https://spacy.io/).
#
# [MetaMap](https://metamap.nlm.nih.gov/) is specific to recognizing UMLS concepts. There is a [Python wrapper](https://github.com/AnthonyMRios/pymetamap), but known to be slow and bad.
#
# [spaCy](https://spacy.io/) is a popular NLP Python package with an extensive library for named entity recognition. It has a wide variety of [extensions](https://spacy.io/universe) and models to choose from. We're going with the following.
#
# * [scispaCy](https://spacy.io/universe/project/scispacy) contains spaCy models for processing biomedical, scientific or clinical text. It seems easy to use and has a wide variety of concepts it can recognize, including UMLS, RxNorm, etc.
#
# * [negspaCy](https://spacy.io/universe/project/negspacy) identifies negations using some extension of regEx. Probably useful for things like, "this pt is diabetic" v. "this pt is not diabetic." [todo: negation identification of medspacy might be better, https://github.com/medspacy/medspacy]
#
# * [Med7](https://github.com/kormilitzin/med7) is a model trained for recognizing entities in prescription text, e.g. identifies drug name, dosage, duration, etc., which could be useful stuff to check for conflicts.
#
# We're going with spaCy for this.. and coming up with a coherent way to integrate entities picked up by these three extensions/models.

# %% [markdown]
# ## i) Installations

# %%
import sys; sys.executable
# Out:
# '/opt/conda/envs/opennotes/bin/python'

# %%
import spacy
import scispacy

from pprint import pprint
from collections import OrderedDict

from spacy import displacy
# from scispacy.abbreviation import AbbreviationDetector # UMLS already contains abbrev. detect
from scispacy.umls_linking import UmlsEntityLinker

# should be 2.3.5 and >=0.3.0
spacy.__version__, scispacy.__version__
# Out:
# ('2.3.5', '0.3.0')

# %% [markdown]
# ## ii) Setting up the model
#
# The model is used to form word/sentence embeddings for the NER task. Thus, it's important to choose model that has been tuned for our specific use case (e.g. clinical text, prescription information) so the embeddings are useful for naming the entity.
#
# [Note to self:] one potential idea to look into if we have time remaining, something about using custom model for spacy pipeline (could we do smth with the romanov models since they've been trained specifically for conflict detection?) -- https://spacy.io/usage/v3

# %% [markdown]
# ### a) scispaCy
#
# For scispaCy, we set up one of their models that has been trained on biomedical data. Other models can be found [here](https://allenai.github.io/scispacy/).
#
# We load two models since we will be linking different entity linkers (knowledge bases that link text to named entites) later.

# %%
## uncomment to install model if not already installed
# !/opt/conda/envs/opennotes/bin/python -m pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.5/en_core_sci_sm-0.2.5.tar.gz

# %%
# for umls (general biomedical concepts)
umls_nlp   = spacy.load("en_core_sci_sm")

# for rxnorm (prescriptions)
rxnorm_nlp = spacy.load("en_core_sci_sm")

# %% [markdown]
# ### b) Med7
#
# For Med7, we set up their model that has been trained specifically for NER of medication-related concepts: dosage, drug names, duration, form, frequency, route of administration, and strength. The model is trained on MIMIC-III, so it should work well for us.

# %%
# # installs Med7 model
# !/opt/conda/envs/opennotes/bin/python3.7 -m pip install https://www.dropbox.com/s/xbgsy6tyctvrqz3/en_core_med7_lg.tar.gz?dl=1
# Out:
# Collecting https://www.dropbox.com/s/xbgsy6tyctvrqz3/en_core_med7_lg.tar.gz?dl=1
#   Downloading https://www.dropbox.com/s/xbgsy6tyctvrqz3/en_core_med7_lg.tar.gz?dl=1 (892.8 MB)
#      |████████████████████████████████| 892.8 MB 7.3 kB/s s eta 0:00:01    |██████████████                  | 392.1 MB 69.8 MB/s eta 0:00:08     |███████████████████████████████▏| 871.0 MB 316 kB/s eta 0:01:09
# Requirement already satisfied: spacy>=2.3.2 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from en-core-med7-lg==0.0.3) (2.3.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (4.60.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (2.25.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (0.8.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (1.20.2)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (7.4.1)
# Requirement already satisfied: setuptools in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (49.6.0.post20210108)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from spacy>=2.3.2->en-core-med7-lg==0.0.3) (3.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.3.2->en-core-med7-lg==0.0.3) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.3.2->en-core-med7-lg==0.0.3) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.3.2->en-core-med7-lg==0.0.3) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.2->en-core-med7-lg==0.0.3) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.2->en-core-med7-lg==0.0.3) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.2->en-core-med7-lg==0.0.3) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/envs/opennotes/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.2->en-core-med7-lg==0.0.3) (4.0.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/opt/conda/envs/opennotes/bin/python3.7 -m pip install --upgrade pip' command.

# %%
sys.executable
# Out:
# '/opt/conda/envs/opennotes/bin/python'

# %%
med7_nlp = spacy.load("en_core_med7_lg")

# %% [markdown]
# ## iii) Adding an entity linker
#
# The EntityLinker is a spaCy component that links to a knowledge base. The linker compares words with the concepts in the specified knowledge base (e.g. scispaCy's UMLS does some form of character overlap-based nearest neighbor search, has option to resolve abbreviations first).
#
# [Note: Entities generally get resolved to a list of different entities. This [blog post](http://sujitpal.blogspot.com/2020/08/disambiguating-scispacy-umls-entities.html) describes one potential way to disambiguate this by figuring out "most likely" set of entities. Gonna start off with just resolving to the 1st entity tho... hopefully that's sufficient.]

# %% [markdown]
# ### a) scispaCy

# %% [markdown]
# #### UMLS Linker
#
# UMLS linker maps entities to the UMLS concept. Main parts we'll be interested in are: semantic type and concept (mainly the common name, maybe the CUI might become important later).
#
# * _Semantic type_ is the broader category that the entity falls under, e.g. disease, pharmacologic substance, etc. See [this](https://metamap.nlm.nih.gov/Docs/SemanticTypes_2018AB.txt) for a full list.
#
# * _Concepts_ refer to the more fundamental entity itself, e.g. pneumothorax, ventillator, etc. Many concepts can fall under a semantic type.
#
# More info on `UmlsEntityLinker` ([source code](https://github.com/allenai/scispacy/blob/4ade4ec897fa48c2ecf3187caa08a949920d126d/scispacy/linking.py#L9))
#
# See source code for `.jsonl` file with the knowledge base.

# %%
from scispacy.umls_linking import UmlsEntityLinker

# abbreviation_pipe = AbbreviationDetector(nlp) # automatically included with UMLS linker
# nlp.add_pipe(abbreviation_pipe)
umls_linker = UmlsEntityLinker(k=10,                          # number of nearest neighbors to look up from
                               threshold=0.7,                 # confidence threshold to be added as candidate
                               max_entities_per_mention=1,    # number of entities returned per concept (todo: tune)
                               filter_for_definitions=False,  # no definition is OK
                               resolve_abbreviations=True)    # resolve abbreviations before linking
umls_nlp.add_pipe(umls_linker)
# Out:
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2020-10-09/umls/tfidf_vectors_sparse.npz not found in cache, downloading to /tmp/tmpceyc9jdd
# Finished download, copying /tmp/tmpceyc9jdd to cache at /home/dianaflores71798/.scispacy/datasets/e9f7327283e43f0482f7c0c71b71dec278a58ccb3ffdd03c2c2350159e7ef146.f2a350ad19015b2591545f7feeed6a6d6d2fffcd635d868a5d7fc0dfc3cadfd8.tfidf_vectors_sparse.npz
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2020-10-09/umls/nmslib_index.bin not found in cache, downloading to /tmp/tmp8bfisdlm
# Finished download, copying /tmp/tmp8bfisdlm to cache at /home/dianaflores71798/.scispacy/datasets/f48455d6c79262057cce66b4619123c2b558b21092d42fac97f47bb99a5b8f9f.dd70d3dffe7d90d7ac8914460e16a48375dab32485fb6313a34e6fbcaf53218b.nmslib_index.bin
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2020-10-09/umls/tfidf_vectorizer.joblib not found in cache, downloading to /tmp/tmp1mce318j
# Finished download, copying /tmp/tmp1mce318j to cache at /home/dianaflores71798/.scispacy/datasets/8c32f1e7ddf19ec695c321f68a71f06a191aec8efcf6b645b78fa6250d8d81d3.89019b4a62a096f33ea23677557a4cde66ebc8228f30afabac38e32f834020dc.tfidf_vectorizer.joblib
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.20.3 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.20.3 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2020-10-09/umls/concept_aliases.json not found in cache, downloading to /tmp/tmp57gxwrb0
# Finished download, copying /tmp/tmp57gxwrb0 to cache at /home/dianaflores71798/.scispacy/datasets/1428ec15d3b1061731ea273c03699130b3d6b90948993e74bda66af605ff8e2a.aeb7a686c654df6bccb6c2c23d3eda3eb381daaefda4592b58158d0bee53b352.concept_aliases.json
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/kbs/2020-10-09/umls_2020_aa_cat0129.jsonl not found in cache, downloading to /tmp/tmpzwfe6t6n
# Finished download, copying /tmp/tmpzwfe6t6n to cache at /home/dianaflores71798/.scispacy/datasets/4d7fb8fcae1035d1e0a47d9072b43d5a628057d35497fbfb2499b4b7b2dd4dd7.05ec7eef12f336d4666da85b7fa69b9401883a7dd4244473f7b88b413ccbba03.umls_2020_aa_cat0129.jsonl
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/umls_semantic_type_tree.tsv not found in cache, downloading to /tmp/tmpnve9ywt_
# Finished download, copying /tmp/tmpnve9ywt_ to cache at /home/dianaflores71798/.scispacy/datasets/21a1012c532c3a431d60895c509f5b4d45b0f8966c4178b892190a302b21836f.330707f4efe774134872b9f77f0e3208c1d30f50800b3b39a6b8ec21d9adf1b7.umls_semantic_type_tree.tsv

# %% [markdown]
# #### RxNorm Linker
#
# RxNorm linker maps entities to RxNorm, an ontology for clinical drug names. It contains about 100k concepts for normalized names for clinical drugs. It is comprised of several other drug vocabularies commonly used in pharmacy management and drug interaction, including First Databank, Micromedex, and the Gold Standard Drug Database.
#
# More info on `RxNorm` ([NIH page](https://www.nlm.nih.gov/research/umls/rxnorm/index.html), [source code](https://github.com/allenai/scispacy/blob/2290a80cfe0948e48d8ecfbd60064019d57a6874/scispacy/linking_utils.py#L120))
#
# See source code for `.jsonl` file with the knowledge base.

# %%
from scispacy.linking import EntityLinker

# rxnorm_linker = EntityLinker(resolve_abbreviations=True, name="rxnorm")
rxnorm_linker = EntityLinker(k=10,                          # number of nearest neighbors to look up from
                             threshold=0.7,                 # confidence threshold to be added as candidate
                             max_entities_per_mention=1,    # number of entities returned per concept (todo: tune)
                             filter_for_definitions=False,  # no definition is OK
                             resolve_abbreviations=True,    # resolve abbreviations before linking
                             name="rxnorm")                 # RxNorm ontology

rxnorm_nlp.add_pipe(rxnorm_linker)
# Out:
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.22.2.post1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.22.2.post1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %% [markdown]
# ### b) Med7
#
# No need for entity linker

# %% [markdown]
# ### c) Negspacy [TODO]

# %% [markdown]
# # 2. Setup data structures
#
# ## Categorizing type of conflict
#
# The first larger task is to categorize by the type of conflict to check for since our method will likely be different (at least for the rule based). We wrote up a short list [here](https://docs.google.com/document/d/1fEBk0JHeyQWshYWW5w_VTkaYyRfm9MBxJ9DAGoVa8Yw/edit?usp=sharing).
#
# To do this, we're using the semantic type that is identified by the UMLS linker. Here's a table of the semantic types we're filtering for, and which conflict they'll be used for.
#
# Here's a [full list](https://metamap.nlm.nih.gov/Docs/SemanticTypes_2018AB.txt) of semantic types. You can look up definitions of semantic types [here](http://linkedlifedata.com/resource/umls-semnetwork/T033).
#
# | Conflict | Semantic Type |
# | --- | ----------- |
# | Diagnoses-related errors | Disease or Syndrome (T047), Diagnostic Procedure(T060) |
# | Inaccurate description of medical history (symptoms) | Sign or Symptom (T184) |
# | Inaccurate description of medical history (operations) | Therapeutic or Preventive Procedure (T061) |
# | Inaccurate description of medical history (other) | [all of the above and below] |
# | Medication or allergies | Clinical Drug (T200), Pharmacologic Substance (T121) |
# | Test procedures or results | Laboratory Procedure (T059), Laboratory or Test Result (T034) |
#
#
# For clarity, the concepts we'll keep from the UMLS linker are anything falling into these semantic types (which we will then categorize by type of conflict using the table above):
#
# * T047 - Disease or Syndrome
# * T121 - Pharmacologic Substance
# * T023 - Body Part, Organ, or Organ Component
# * T061 - Therapeutic or Preventive Procedure
# * T060 - Diagnostic Procedure
# * T059 - Laboratory Procedure
# * T034 - Laboratory or Test Result
# * T184 - Sign or Symptom
# * T200 - Clinical Drug
#
# We'll store this info into a dictionary now.
#
# <!-- Some useful def's
# Finding -
# That which is discovered by direct observation or measurement of an organism attribute or condition, including the clinical history of the patient. The history of the presence of a disease is a 'Finding' and is distinguished from the disease itself.  -->

# %%
SEMANTIC_TYPES = ['T047', 'T121', 'T023', 'T061', 'T060', 'T059', 'T034', 'T184', 'T200']
SEMANTIC_NAMES = ['Disease or Syndrome', 'Pharmacologic Substance', 'Body Part, Organ, or Organ Component', \
                  'Therapeutic or Preventive Procedure', 'Diagnostic Procedure', 'Laboratory Procedure', \
                  'Laboratory or Test Result', 'Sign or Symptom', 'Clinical Drug']
SEMANTIC_TYPE_TO_NAME = dict(zip(SEMANTIC_TYPES, SEMANTIC_NAMES))

SEMANTIC_TYPE_TO_NAME
# Out:
# {'T047': 'Disease or Syndrome',
#  'T121': 'Pharmacologic Substance',
#  'T023': 'Body Part, Organ, or Organ Component',
#  'T061': 'Therapeutic or Preventive Procedure',
#  'T060': 'Diagnostic Procedure',
#  'T059': 'Laboratory Procedure',
#  'T034': 'Laboratory or Test Result',
#  'T184': 'Sign or Symptom',
#  'T200': 'Clinical Drug'}

# %%
CONFLICT_TO_SEMANTIC_TYPE = {
    "diagnosis": {'T047', 'T060'},
    "med_history_symptom": {'T184'},
    "med_history_operation": {'T061'},
    "med_history_other": set(SEMANTIC_TYPES),
    "med_allergy": {'T200', 'T121'},
    "test_results": {'T059', 'T034'}
}

CONFLICT_TO_SEMANTIC_TYPE
# Out:
# {'diagnosis': {'T047', 'T060'},
#  'med_history_symptom': {'T184'},
#  'med_history_operation': {'T061'},
#  'med_history_other': {'T023',
#   'T034',
#   'T047',
#   'T059',
#   'T060',
#   'T061',
#   'T121',
#   'T184',
#   'T200'},
#  'med_allergy': {'T121', 'T200'},
#  'test_results': {'T034', 'T059'}}

# %%
from data_structures import Patient,\
                            Note, PrescriptionOrders, LabResults,\
                            Sentence, Prescription, Lab

# %%
# from importlib import reload # python 2.7 does not require this
# import data_structures
# reload(data_structures)
# from data_structures import Patient,\
#                             Note, PrescriptionOrders, LabResults,\
#                             Sentence, Prescription, Lab

# %% [markdown]
# # 3. Load and process data

# %%
# Load MIMIC tables
notes_df  = pd.read_csv('NOTEEVENTS.csv.gz',    compression='gzip', error_bad_lines=False)
drug_df   = pd.read_csv('PRESCRIPTIONS.csv.gz', compression='gzip', error_bad_lines=False)
lab_df    = pd.read_csv('LABEVENTS.csv.gz',     compression='gzip', error_bad_lines=False)
d_lab_df  = pd.read_csv('D_LABITEMS.csv.gz',    compression='gzip', error_bad_lines=False)
# Out:
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Updated script for processing HADM ID's with consecutive physician notes (does not count the autosaves)

# %%
# Load HADM ID's with consecutive physician notes
if os.path.exists("hadm_ids.pkl"):
    with open("hadm_ids.pkl", "rb") as f:
        hadm_ids = pickle.load(f)
else:
    hadm_ids = []
    for hadm_id in tqdm(notes_df.HADM_ID.unique()):
        hadm_data = notes_df.loc[notes_df.HADM_ID == hadm_id]
        hadm_phys_notes = hadm_data.loc[hadm_data.CATEGORY == "Physician "]

        if len(hadm_phys_notes.CHARTTIME.unique()) > 1: # ensure > 1 unique notes (not counting autosave)
            hadm_ids.append(hadm_id)

    with open("hadm_ids.pkl", "wb") as f:
        pickle.dump(hadm_ids, f)
        
print(f"There are {len(hadm_ids)} patients with consecutive physician notes.")
# Out:
# There are 8158 patients with consecutive physician notes.

# %% [markdown]
# # 4. Generating Contradictions
#
# Generate 25-50 examples of positive and negative contradictions, each.
#
# For lab values:
#
# * Find 50-100 total data pairs (about 2-4 per patient) and insert contradiction, or label as not a contradiction

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
pd.set_option("display.max_colwidth", -1) # prints full text
# Out:
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
from importlib import reload # python 2.7 does not require this
import data_structures
reload(data_structures)
from data_structures import Patient,\
                            Note, PrescriptionOrders, LabResults,\
                            Sentence, Prescription, Lab

# %%
def is_comparable_type(data_i, data_j):
    """ We only want to compare note-to-note OR note-to-structured data. 
    
    Comparable types:
    - sentence v. sentence
    - sentence v. prescription
    - sentence v. lab
    
    Uncomparable types:
    - lab v. lab 
    - lab v. prescription
    - prescription v. prescription
    """
    return (data_i.type == "sentence"     and data_j.type == "sentence") or \
           (data_i.type == "sentence"     and data_j.type == "prescription") or \
           (data_i.type == "prescription" and data_j.type == "sentence") or \
           (data_i.type == "sentence"     and data_j.type == "lab") or \
           (data_i.type == "lab"          and data_j.type == "sentence")

# %%
def generate_data_pairs(pat):
    processed_pairs = []  # for dataframe + csv
    data_inst_pairs = []  # for pipeline, list of tuples: ((Data 1, Data 2), label)
    pair_idx = 0

    # Iterate over all of the patient's DailyData instances (e.g. note, prescription order, lab results for same day)
    ## pat.dailydata = {[date]: [DailyData instance from that date], ...}
    for day, pat_dailydatas in pat.dailydata.items(): # pat_dailydatas is list of all DailyData instances for `day`
        print(f"********** Processing data for {day} **********")
        # Collect all the daily datas (note, prescription orders, lab results) for current day
        current_dds = []
        current_dds_features = []
        current_dds_txts = []
        current_dds_sem_types = []
        current_dds_sem_names = []
        for dd in pat_dailydatas: # iterating over DailyData instances, e.g. dd=physician note taken on `day`
            current_dds.extend(dd.datas)
            current_dds_features.extend(dd.datas_features)
            current_dds_txts.extend(dd.datas_txts)
            current_dds_sem_types.extend(dd.datas_semantic_types)
            current_dds_sem_names.extend(dd.datas_semantic_names)

        current_dds           = np.array(current_dds)
        current_dds_features  = np.array(current_dds_features)
        current_dds_txts      = np.array(current_dds_txts)
        current_dds_sem_types = np.array(current_dds_sem_types)
        current_dds_sem_names = np.array(current_dds_sem_names)

        # extract similar sentences for each semantic type
        for sem_type in SEMANTIC_TYPES:
            # data for this semantic type
            sem_type_bools   = [sem_type in x for x in current_dds_sem_types]
            sem_type_indices = np.where(sem_type_bools)[0]
            indices_map = dict(
                            zip(range(len(sem_type_indices)), 
                                sem_type_indices)
                          )  # maps regular indices in sem_type_current_dds_* lists to indices in current_dds_* lists

            sem_type_current_dds           = current_dds[sem_type_indices]
            sem_type_current_dds_features  = current_dds_features[sem_type_indices]
            sem_type_current_dds_txts      = current_dds_txts[sem_type_indices]
            sem_type_current_dds_sem_types = current_dds_sem_types[sem_type_indices]
            sem_type_current_dds_sem_names = current_dds_sem_names[sem_type_indices]

            # current_dds_featuresfor features (umls + rxnorm concepts)
            vectorizer = CountVectorizer()
            corpus = list(map(lambda x: ' '.join(x), sem_type_current_dds_features))
            if len(corpus) == 0: # skip rest if no candidate sentences exist
                continue
            X = vectorizer.fit_transform(corpus)
            X = X.toarray()

            # get cosine similarity using umls + rxnorm concepts
            similarity = cosine_similarity(X)     # larger=more similar
            sim_is, sim_js = np.where(similarity>0.5) # all pairs with at least 0.5 similarity

            for i, j in zip(sim_is, sim_js):
                data_i = sem_type_current_dds[i]
                data_j = sem_type_current_dds[j]
                # removing same sentence pairs, checking dates
                if i>j and is_comparable_type(data_i, data_j):
                    print(f"***** PAIR INDEX {pair_idx} *****")
                    print(f"Cosine similarity: {similarity[i, j]}")
                    print(f"----- Data i -----")
                    print(f">> Time: {data_i.time}\n" +\
                          f">> Type: {data_i.type}\n" +\
                          f">> Concepts: {data_i.features}\n" +\
                          f">> {data_i.txt}")
                    print(f"----- Data j -----")
                    print(f">> Time: {data_j.time}\n" +\
                          f">> Type: {data_j.type}\n" +\
                          f">> Concepts: {data_j.features}\n" +\
                          f">> {data_j.txt}")
                    print("**********************************")

                    # save
                    processed_pairs.append([data_i.txt,      data_j.txt, \
                                            data_i.time,     data_j.time, \
                                            data_i.type,     data_j.type, \
                                            data_i.features, data_j.features, \
                                            similarity[i, j], SEMANTIC_TYPE_TO_NAME[sem_type]])
            #                                 SEMANTIC_TYPE_TO_NAME[semantic_type]])

                    data_inst_pairs.append(((data_i, data_j), None))
                    pair_idx += 1

    ###############
    #### Final ####
    ###############        
    df = \
    pd.DataFrame(np.array(processed_pairs), \
                 columns=["sentence 1", "sentence 2", \
                          "time 1", "time 2", \
                          "type 1", "type 2", \
                          "concepts 1", "concepts 2", \
                          "cosine similarity", "semantic type"])
    
    return df, data_inst_pairs

# %% [markdown]
# ## README: Store generated data here

# %%
generated_data_dict = {}

# %% [markdown]
# ## Patient 1

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[0] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 155131
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2131-12-23 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.848528137423857
# ----- Data i -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Structure of left lower lobe of lung', 'Pneumonia'}
# >> CXR with LLL infiltrate, which may be    persitent radiograph manifestation of her previous pneumonia (may take    6-8 weeks to resolve).'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Structure of left lower lobe of lung', 'Pneumonia'}
# >> HPI:     [**Age over 90 382**]  year old woman hx of COPD, recent admit in early  [**Month (only) 102**]  with LLL    pneumonia.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.7442084075352509
# ----- Data i -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Lung hyperinflation', 'Structure of left lower lobe of lung'}
# >> Compared to previous CXR, LLL infiltrate not    significantly changed; right lung hyperinflation more impressive.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Structure of left lower lobe of lung', 'Pneumonia'}
# >> HPI:     [**Age over 90 382**]  year old woman hx of COPD, recent admit in early  [**Month (only) 102**]  with LLL    pneumonia.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.8770580193070292
# ----- Data i -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Lung hyperinflation', 'Structure of left lower lobe of lung'}
# >> Compared to previous CXR, LLL infiltrate not    significantly changed; right lung hyperinflation more impressive.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Structure of left lower lobe of lung', 'Pneumonia'}
# >> CXR with LLL infiltrate, which may be    persitent radiograph manifestation of her previous pneumonia (may take    6-8 weeks to resolve).'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases'}
# >> Patient with chronic renal failure.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Acute respiratory failure'}
# >> Altered mental status, acute respiratory failure,    chronic renal failure, hypotension    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.6454972243679029
# ----- Data i -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases'}
# >> Patient with chronic renal failure.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Chronic Kidney Diseases', 'Kidney', 'Dial Antibacterial', 'Infantile Neuroaxonal Dystrophy', 'Pneumonia'}
# >> Assessment and Plan  PNEUMONIA, BACTERIAL, COMMUNITY ACQUIRED (CAP)  ALTERED MENTAL STATUS (NOT DELIRIUM)  RENAL FAILURE, CHRONIC (CHRONIC RENAL FAILURE, CRF, CHRONIC KIDNEY    DISEASE)  HYPOTENSION (NOT SHOCK)    COPD    ACIDOSIS    Patient with severe COPD and recent pneumonia.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.7171371656006362
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Structure of left lower lobe of lung', 'Implantation procedure'}
# >> Recent    admission for acute on chronic renal failure with tunnelled catheter    placement, complicated by left lower lobe Moraxella pneumonia    discharged on cefpodoxime.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Structure of left lower lobe of lung', 'Pneumonia'}
# >> HPI:     [**Age over 90 382**]  year old woman hx of COPD, recent admit in early  [**Month (only) 102**]  with LLL    pneumonia.'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 0.760638829255665
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Structure of left lower lobe of lung', 'Implantation procedure'}
# >> Recent    admission for acute on chronic renal failure with tunnelled catheter    placement, complicated by left lower lobe Moraxella pneumonia    discharged on cefpodoxime.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Structure of left lower lobe of lung', 'Pneumonia'}
# >> CXR with LLL infiltrate, which may be    persitent radiograph manifestation of her previous pneumonia (may take    6-8 weeks to resolve).'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.7412493166611013
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Structure of left lower lobe of lung', 'Implantation procedure'}
# >> Recent    admission for acute on chronic renal failure with tunnelled catheter    placement, complicated by left lower lobe Moraxella pneumonia    discharged on cefpodoxime.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Lung hyperinflation', 'Structure of left lower lobe of lung'}
# >> Compared to previous CXR, LLL infiltrate not    significantly changed; right lung hyperinflation more impressive.'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.6546536707079772
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Vasculitis', 'Clostridium difficile colitis'}
# >> difficile if produces    # Chronic renal failure: Secondary to ANCA vasculitis.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases'}
# >> Patient with chronic renal failure.'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.7999999999999999
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Coumadin', 'Anticoagulation Therapy', 'Stress ulcer'}
# >>    DVT: (Systemic anticoagulation: Coumadin)    Stress ulcer: PPI'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'heparin', 'Anticoagulation Therapy', 'Stress ulcer'}
# >>    DVT: (Systemic anticoagulation: Heparin gtt)    Stress ulcer: PPI'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.6343350474165466
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Granulomatosis with polyangiitis', 'Lung diseases', 'Structure of left lower lobe of lung'}
# >> ['TITLE:', "Chief Complaint:  Altered mental status    HPI:    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (3) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Structure of left lower lobe of lung', 'Pneumonia'}
# >> HPI:     [**Age over 90 382**]  year old woman hx of COPD, recent admit in early  [**Month (only) 102**]  with LLL    pneumonia.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.6900655593423543
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Granulomatosis with polyangiitis', 'Lung diseases', 'Structure of left lower lobe of lung'}
# >> ['TITLE:', "Chief Complaint:  Altered mental status    HPI:    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (3) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Structure of left lower lobe of lung', 'Pneumonia'}
# >> CXR with LLL infiltrate, which may be    persitent radiograph manifestation of her previous pneumonia (may take    6-8 weeks to resolve).'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.726273039202563
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Granulomatosis with polyangiitis', 'Lung diseases', 'Structure of left lower lobe of lung'}
# >> ['TITLE:', "Chief Complaint:  Altered mental status    HPI:    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (3) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Lung hyperinflation', 'Structure of left lower lobe of lung'}
# >> Compared to previous CXR, LLL infiltrate not    significantly changed; right lung hyperinflation more impressive.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.5039526306789697
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Granulomatosis with polyangiitis', 'Lung diseases', 'Structure of left lower lobe of lung'}
# >> ['TITLE:', "Chief Complaint:  Altered mental status    HPI:    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (3) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases'}
# >> Patient with chronic renal failure.'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Granulomatosis with polyangiitis', 'Lung diseases', 'Structure of left lower lobe of lung'}
# >> ['TITLE:', "Chief Complaint:  Altered mental status    HPI:    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (3) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Structure of left lower lobe of lung', 'Implantation procedure'}
# >> Recent    admission for acute on chronic renal failure with tunnelled catheter    placement, complicated by left lower lobe Moraxella pneumonia    discharged on cefpodoxime.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.5050762722761053
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Urine culture', 'Hospital acquired pneumonia', 'Blood Stop'}
# >> - Vancomycin, zosyn for hospital-acquired pneumonia    - Sputum, blood, ?influenza/viral, urine cultures pending; stool    culture/C.'
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Hospital acquired pneumonia', 'albuterol', 'Blood culture', 'Ipratropium', 'Lung', 'ipratropium', 'Albuterol'}
# >> - Vancomycin, zosyn for hospital-acquired pneumonia    - Sputum, blood cultures pending    - Standing albuterol and ipratropium with additional albuterol PRN    # Bandemia/left shift: Most likely sources are pulmonary versus line    infection as above.'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.5669467095138409
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'albuterol', 'Sepsis', 'Combivent', 'Lung', 'Pneumonia', 'Albuterol'}
# >> - Wean FiO2 as possible    - Vancomycin and zosyn for pneumonia    - Combivent inhalers Q4H with albuterol Q2H:PRN    # Hypotension: Patient with likely sepsis from pulmonary source,    requiring intermittent levophed.'
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Hospital acquired pneumonia', 'albuterol', 'Blood culture', 'Ipratropium', 'Lung', 'ipratropium', 'Albuterol'}
# >> - Vancomycin, zosyn for hospital-acquired pneumonia    - Sputum, blood cultures pending    - Standing albuterol and ipratropium with additional albuterol PRN    # Bandemia/left shift: Most likely sources are pulmonary versus line    infection as above.'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Pneumonia'}
# >> Patient with pneumonia and recent hospitalization.'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Pneumonia'}
# >> Patient    started on vanco and zosyn for possible hospital acquired pneumonia.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.5198752449100363
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Chronic Kidney Diseases', 'Laboratory test finding', 'Structure of left lower lobe of lung', 'Lung diseases', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Infantile Neuroaxonal Dystrophy', 'Granulomatosis with polyangiitis'}
# >>    PTT: 57.4', "   INR: 2.0                                    [**2129-1-3**]                           2:33 A12/21/ [**2131**]   09:24 PM                                    [**2129-1-7**]                                     10:20 P                                    [**2129-1-8**]                                     1:20 P                                    [**2129-1-9**]                                     11:50 P                                    [**2129-1-10**]                                     1:20 A                                    [**2129-1-11**]                                     7:20 P                                   1//11/006                                    1:23 P                                    [**2129-2-3**]                                     1:20 P                                    [**2129-2-3**]                                     11:20 P                                    [**2129-2-3**]                                     4:20 P    TC02                                      28    Other labs: Lactic Acid:0.9 mmol/L    Assessment and Plan    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (1) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Structure of left lower lobe of lung', 'Pneumonia'}
# >> CXR with LLL infiltrate, which may be    persitent radiograph manifestation of her previous pneumonia (may take    6-8 weeks to resolve).'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 0.5471529031050639
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Chronic Kidney Diseases', 'Laboratory test finding', 'Structure of left lower lobe of lung', 'Lung diseases', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Infantile Neuroaxonal Dystrophy', 'Granulomatosis with polyangiitis'}
# >>    PTT: 57.4', "   INR: 2.0                                    [**2129-1-3**]                           2:33 A12/21/ [**2131**]   09:24 PM                                    [**2129-1-7**]                                     10:20 P                                    [**2129-1-8**]                                     1:20 P                                    [**2129-1-9**]                                     11:50 P                                    [**2129-1-10**]                                     1:20 A                                    [**2129-1-11**]                                     7:20 P                                   1//11/006                                    1:23 P                                    [**2129-2-3**]                                     1:20 P                                    [**2129-2-3**]                                     11:20 P                                    [**2129-2-3**]                                     4:20 P    TC02                                      28    Other labs: Lactic Acid:0.9 mmol/L    Assessment and Plan    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (1) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Lung hyperinflation', 'Structure of left lower lobe of lung'}
# >> Compared to previous CXR, LLL infiltrate not    significantly changed; right lung hyperinflation more impressive.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.6151246852292456
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Chronic Kidney Diseases', 'Laboratory test finding', 'Structure of left lower lobe of lung', 'Lung diseases', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Infantile Neuroaxonal Dystrophy', 'Granulomatosis with polyangiitis'}
# >>    PTT: 57.4', "   INR: 2.0                                    [**2129-1-3**]                           2:33 A12/21/ [**2131**]   09:24 PM                                    [**2129-1-7**]                                     10:20 P                                    [**2129-1-8**]                                     1:20 P                                    [**2129-1-9**]                                     11:50 P                                    [**2129-1-10**]                                     1:20 A                                    [**2129-1-11**]                                     7:20 P                                   1//11/006                                    1:23 P                                    [**2129-2-3**]                                     1:20 P                                    [**2129-2-3**]                                     11:20 P                                    [**2129-2-3**]                                     4:20 P    TC02                                      28    Other labs: Lactic Acid:0.9 mmol/L    Assessment and Plan    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (1) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Structure of left lower lobe of lung', 'Implantation procedure'}
# >> Recent    admission for acute on chronic renal failure with tunnelled catheter    placement, complicated by left lower lobe Moraxella pneumonia    discharged on cefpodoxime.'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.7533708035008839
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Chronic Kidney Diseases', 'Laboratory test finding', 'Structure of left lower lobe of lung', 'Lung diseases', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Infantile Neuroaxonal Dystrophy', 'Granulomatosis with polyangiitis'}
# >>    PTT: 57.4', "   INR: 2.0                                    [**2129-1-3**]                           2:33 A12/21/ [**2131**]   09:24 PM                                    [**2129-1-7**]                                     10:20 P                                    [**2129-1-8**]                                     1:20 P                                    [**2129-1-9**]                                     11:50 P                                    [**2129-1-10**]                                     1:20 A                                    [**2129-1-11**]                                     7:20 P                                   1//11/006                                    1:23 P                                    [**2129-2-3**]                                     1:20 P                                    [**2129-2-3**]                                     11:20 P                                    [**2129-2-3**]                                     4:20 P    TC02                                      28    Other labs: Lactic Acid:0.9 mmol/L    Assessment and Plan    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (1) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Chronic Kidney Diseases', 'Granulomatosis with polyangiitis', 'Lung diseases', 'Structure of left lower lobe of lung'}
# >> ['TITLE:', "Chief Complaint:  Altered mental status    HPI:    A  [**Age over 90 382**]  year-old female with past medical history of chronic obstructive    pulmonary disease, Wegener's granulomatosis, recent admission     [**Date range (3) 7130**]  for acute on chronic renal failure with decision to    initiate hemodialysis at that time and hospital stay complicated by    left lower lobe Moraxella pneumonia presenting with altered mental    status."
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Sea Soft'}
# >>    Abdominal: Soft, Non-tender, Bowel sounds present'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Sea Soft'}
# >>    Abdominal: Soft, Non-tender, Bowel sounds present, No(t) Distended,    No(t) Tender: , No(t) Obese'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Warm'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Warm, No(t) Rash: , No(t) Jaundice'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'S-1 Antimetabolite agent'}
# >>    Cardiovascular: (S1: Normal), (S2: Normal)'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'S-1 Antimetabolite agent'}
# >>    Cardiovascular: (PMI Normal, No(t) Hyperdynamic), (S1: Normal, No(t)    Absent), (S2: Normal, No(t) Distant, No(t) Loud, No(t) Widely split ,    No(t) Fixed), No(t) S3, No(t) S4, No(t) Rub, (Murmur: No(t) Systolic,    No(t) Diastolic)'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Oxygen'}
# >> In the ED, initial VS T 96, HR 63, BP 77/55, RR 18 SaO2 98% (oxygen not    documented).'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Factive Oral Product', 'Oxygen', 'Dyspnea'}
# >> Patient has had increased productive    cough and increased oxygen requirement (had been discharged from last    hospitalizatoin with oxygen) and increased SOB.'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.7999999999999999
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Coumadin', 'Anticoagulation Therapy', 'Stress ulcer'}
# >>    DVT: (Systemic anticoagulation: Coumadin)    Stress ulcer: PPI'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'heparin', 'Anticoagulation Therapy', 'Stress ulcer'}
# >>    DVT: (Systemic anticoagulation: Heparin gtt)    Stress ulcer: PPI'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,216 mL    PO:              TF:    IVF:    16 mL    Blood products:    Total out:                                                                       0 mL                                                                      25 mL    Urine:    25 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   1,191 mL    Respiratory    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 400 (400 - 400) mL    RR (Set): 18    RR (Spontaneous): 0'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,219 mL    PO:              TF:    IVF:    19 mL    Blood products:    Total out:                                                                       0 mL                                                                      25 mL    Urine:    25 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   1,194 mL    Respiratory    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 400 (400 - 400) mL    RR (Set): 18    RR (Spontaneous): 0'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.5050762722761053
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Urine culture', 'Hospital acquired pneumonia', 'Blood Stop'}
# >> - Vancomycin, zosyn for hospital-acquired pneumonia    - Sputum, blood, ?influenza/viral, urine cultures pending; stool    culture/C.'
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Hospital acquired pneumonia', 'albuterol', 'Blood culture', 'Ipratropium', 'Lung', 'ipratropium', 'Albuterol'}
# >> - Vancomycin, zosyn for hospital-acquired pneumonia    - Sputum, blood cultures pending    - Standing albuterol and ipratropium with additional albuterol PRN    # Bandemia/left shift: Most likely sources are pulmonary versus line    infection as above.'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'metoprolol', 'Metoprolol'}
# >> Metoprolol Tartrate 100 mg PO BID'
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Coumadin', 'Hypothyroidism', 'metoprolol', 'Metoprolol'}
# >> - Hold metoprolol for now    - Continue coumadin for goal INR  [**2-4**] ; monitor with antibiotics    # Hypothyroidism: No acute issues.'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.5669467095138409
# ----- Data i -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'albuterol', 'Sepsis', 'Combivent', 'Lung', 'Pneumonia', 'Albuterol'}
# >> - Wean FiO2 as possible    - Vancomycin and zosyn for pneumonia    - Combivent inhalers Q4H with albuterol Q2H:PRN    # Hypotension: Patient with likely sepsis from pulmonary source,    requiring intermittent levophed.'
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Hospital acquired pneumonia', 'albuterol', 'Blood culture', 'Ipratropium', 'Lung', 'ipratropium', 'Albuterol'}
# >> - Vancomycin, zosyn for hospital-acquired pneumonia    - Sputum, blood cultures pending    - Standing albuterol and ipratropium with additional albuterol PRN    # Bandemia/left shift: Most likely sources are pulmonary versus line    infection as above.'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: prescription
# >> Concepts: {'Ipratropium Bromide', 'ipratropium bromide'}
# >> Patient was prescribed Ipratropium Bromide MDI 12.9g Inhaler IH of total 2-8 PUFF
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Ipratropium Bromide', 'ipratropium bromide'}
# >> Ipratropium Bromide Inhalation Q6H'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: prescription
# >> Concepts: {'Levothyroxine Sodium', 'Levothyroxine Sodium 0.025 MG Oral Capsule'}
# >> Patient was prescribed Levothyroxine Sodium 25mcg Tablet PO of total 25 mcg
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'levothyroxine'}
# >> Levothyroxine 125 mcg PO DAILY'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: prescription
# >> Concepts: {'Nephrocaps'}
# >> Patient was prescribed Nephrocaps 1 Capsule PO of total 1 CAP
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Nephrocaps'}
# >> Nephrocaps 1 mg PO DAILY'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.6324555320336759
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: lab
# >> Concepts: {'Calcium', 'Calcium Drug Class'}
# >> Patient's Calcium, Total lab came back 7.8 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'kalium', 'Kidney', 'Anemia', 'Calcium', '1,25-dihydroxycholecalciferol', 'calcitriol', 'Nephrocaps', 'Calcium Drug Class', 'Huntington Disease'}
# >> - Renal aware    - HD MWF    - Monitor potassium; no kayexalate for K < 6.0 per renal    - Continue epogen, nephrocaps, calcitriol, calcium    # Anemia: Baseline mid-20s; at baseline.'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 5.6 mEq/L , which is abnormal.
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> Potassium up slightly.'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.22 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,219 mL    PO:              TF:    IVF:    19 mL    Blood products:    Total out:                                                                       0 mL                                                                      25 mL    Urine:    25 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   1,194 mL    Respiratory    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 400 (400 - 400) mL    RR (Set): 18    RR (Spontaneous): 0'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.22 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,216 mL    PO:              TF:    IVF:    16 mL    Blood products:    Total out:                                                                       0 mL                                                                      25 mL    Urine:    25 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   1,191 mL    Respiratory    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 400 (400 - 400) mL    RR (Set): 18    RR (Spontaneous): 0'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: lab
# >> Concepts: {'Uridine'}
# >> Patient's Urine Appearance lab came back Hazy nan.
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'Active Q', 'Uridine'}
# >> Patient took trazodone two days prior to admission,    which has caused confusion in the past - appears to be hepatically    cleared to active metabolite that is excreted in urine; patient    anuric.'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 0.6324555320336759
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: lab
# >> Concepts: {'Calcium', 'Calcium Drug Class'}
# >> Patient's Calcium, Total lab came back 7.5 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2131-12-23 22:56:00
# >> Type: sentence
# >> Concepts: {'kalium', 'Kidney', 'Anemia', 'Calcium', '1,25-dihydroxycholecalciferol', 'calcitriol', 'Nephrocaps', 'Calcium Drug Class', 'Huntington Disease'}
# >> - Renal aware    - HD MWF    - Monitor potassium; no kayexalate for K < 6.0 per renal    - Continue epogen, nephrocaps, calcitriol, calcium    # Anemia: Baseline mid-20s; at baseline.'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2131-12-23 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 5.0 mEq/L.
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> Potassium up slightly.'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.848528137423857
# ----- Data i -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Structure of left lower lobe of lung', 'Pneumonia'}
# >> CXR with LLL infiltrate, which may be    persitent radiograph manifestation of her previous pneumonia (may take    6-8 weeks to resolve).'
# ----- Data j -----
# >> Time: 2131-12-23 23:51:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Structure of left lower lobe of lung', 'Pneumonia'}
# >> HPI:     [**Age over 90 382**]  year old woman hx of COPD, recent admit in early  [**Month (only) 102**]  with LLL    pneumonia.'
# ...
# **********************************
# ***** PAIR INDEX 185 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2131-12-26 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 2.71 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                     792 mL                                                                     322 mL    PO:              TF:    IVF:                                                                     762 mL                                                                     322 mL    Blood products:    Total out:                                                                   3,015 mL                                                                      20 mL    Urine:                                                                      15 mL                                                                      20 mL    NG:    Stool:    Drains:    Balance:                                                                  -2,223 mL                                                                     302 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 450 (450 - 450) mL    Vt (Spontaneous): 483 (483 - 483) mL'
# **********************************
# ***** PAIR INDEX 186 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2131-12-26 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 2.71 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2131-12-26 10:04:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                     792 mL                                                                     444 mL    PO:              TF:    IVF:                                                                     762 mL                                                                     444 mL    Blood products:    Total out:                                                                   3,015 mL                                                                      35 mL    Urine:                                                                      15 mL                                                                      35 mL    NG:    Stool:    Drains:    Balance:                                                                  -2,223 mL                                                                     409 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 450 (450 - 450) mL    Vt (Spontaneous): 483 (483 - 483) mL'
# **********************************
# ***** PAIR INDEX 187 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar', 'Hypothyroidism'}
# >> - INR supratherapeutic, but will need heparin gtt if drifts <2    # Hypothyroidism: No acute issues.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Therapeutic brand of coal tar'}
# >>    DVT:  INR supratherapeutic.'
# **********************************
# ***** PAIR INDEX 188 *****
# Cosine similarity: 0.9428090415820634
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar'}
# >> INR currently supratherapeutic, however so holding    heparin gtt.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Therapeutic brand of coal tar'}
# >>    DVT:  INR supratherapeutic.'
# **********************************
# ***** PAIR INDEX 189 *****
# Cosine similarity: 0.9486832980505138
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar'}
# >> INR currently supratherapeutic, however so holding    heparin gtt.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar', 'Hypothyroidism'}
# >> - INR supratherapeutic, but will need heparin gtt if drifts <2    # Hypothyroidism: No acute issues.'
# **********************************
# ***** PAIR INDEX 190 *****
# Cosine similarity: 0.6859943405700353
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar', 'Coumadin', 'metoprolol', 'Metoprolol', 'Transient Ischemic Attack'}
# >> - Hold metoprolol for now as above    - Hold heparin gtt given INR supratherapeutic    - continue to follow coags    # History of transient ischemic attack: Notes state the patient had a    TIA which occurred when coumadin held during a previous admission.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Therapeutic brand of coal tar'}
# >>    DVT:  INR supratherapeutic.'
# **********************************
# ***** PAIR INDEX 191 *****
# Cosine similarity: 0.6902684899626335
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar', 'Coumadin', 'metoprolol', 'Metoprolol', 'Transient Ischemic Attack'}
# >> - Hold metoprolol for now as above    - Hold heparin gtt given INR supratherapeutic    - continue to follow coags    # History of transient ischemic attack: Notes state the patient had a    TIA which occurred when coumadin held during a previous admission.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar', 'Hypothyroidism'}
# >> - INR supratherapeutic, but will need heparin gtt if drifts <2    # Hypothyroidism: No acute issues.'
# **********************************
# ***** PAIR INDEX 192 *****
# Cosine similarity: 0.7276068751089988
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar', 'Coumadin', 'metoprolol', 'Metoprolol', 'Transient Ischemic Attack'}
# >> - Hold metoprolol for now as above    - Hold heparin gtt given INR supratherapeutic    - continue to follow coags    # History of transient ischemic attack: Notes state the patient had a    TIA which occurred when coumadin held during a previous admission.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar'}
# >> INR currently supratherapeutic, however so holding    heparin gtt.'
# **********************************
# ***** PAIR INDEX 193 *****
# Cosine similarity: 0.583383351196948
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'heparin', 'Therapeutic brand of coal tar', 'Coumadin', 'metoprolol', 'Metoprolol', 'Transient Ischemic Attack'}
# >> - Hold metoprolol for now as above    - Hold heparin gtt given INR supratherapeutic    - continue to follow coags    # History of transient ischemic attack: Notes state the patient had a    TIA which occurred when coumadin held during a previous admission.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Integrated Neuromusculoskeletal Release', 'Coumadin', 'heparin', 'metoprolol', 'Levophed', 'Metoprolol', 'Blood Coagulation Disorders', 'BPS'}
# >> - off levophed    - Hold metoprolol for now, but can restart  pending stability in BPs    # Coagulopathy:  INR continues to climb despite having been off    coumadin and heparin stopped yesterday.'
# **********************************
# ***** PAIR INDEX 194 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2131-12-26 10:04:00
# >> Type: sentence
# >> Concepts: {'mercaptopurine/methotrexate/vincristine'}
# >>    PIP: 20 cmH2O'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'mercaptopurine/methotrexate/vincristine'}
# >>    PIP: 20 cmH2O'
# **********************************
# ***** PAIR INDEX 195 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2131-12-26 10:04:00
# >> Type: sentence
# >> Concepts: {'Positive End-Expiratory Pressure'}
# >>    PEEP: 8 cmH2O    FiO2: 40%'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Positive End-Expiratory Pressure'}
# >>    PEEP: 8 cmH2O    FiO2: 40%'
# **********************************
# ***** PAIR INDEX 196 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2131-12-26 10:04:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                     792 mL                                                                     444 mL    PO:              TF:    IVF:                                                                     762 mL                                                                     444 mL    Blood products:    Total out:                                                                   3,015 mL                                                                      35 mL    Urine:                                                                      15 mL                                                                      35 mL    NG:    Stool:    Drains:    Balance:                                                                  -2,223 mL                                                                     409 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 450 (450 - 450) mL    Vt (Spontaneous): 483 (483 - 483) mL'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                     792 mL                                                                     322 mL    PO:              TF:    IVF:                                                                     762 mL                                                                     322 mL    Blood products:    Total out:                                                                   3,015 mL                                                                      20 mL    Urine:                                                                      15 mL                                                                      20 mL    NG:    Stool:    Drains:    Balance:                                                                  -2,223 mL                                                                     302 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 450 (450 - 450) mL    Vt (Spontaneous): 483 (483 - 483) mL'
# **********************************
# ***** PAIR INDEX 197 *****
# Cosine similarity: 0.7905694150420949
# ----- Data i -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Thyroid stimulating hormone measurement'}
# >> TSH 1.8 on this admission.'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Rapid Plasma Reagin Measurement', 'Thyroid stimulating hormone measurement'}
# >> TSH,    B12, RPR - normal/non-reactive    - starting ctx for moraxella    - limit sedating meds    - frequent reorientation    # Hypotension:  Currently normotensive off pressors.'
# **********************************
# ***** PAIR INDEX 198 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2131-12-26 10:04:00
# >> Type: sentence
# >> Concepts: {'PO2 measurement'}
# >>    Ve: 7.7 L/min    PaO2 / FiO2: 320    Physical Examination'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'PO2 measurement'}
# >>    Ve: 7.7 L/min    PaO2 / FiO2: 320    Physical Examination'
# **********************************
# ***** PAIR INDEX 199 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2131-12-26 10:04:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                     792 mL                                                                     444 mL    PO:              TF:    IVF:                                                                     762 mL                                                                     444 mL    Blood products:    Total out:                                                                   3,015 mL                                                                      35 mL    Urine:                                                                      15 mL                                                                      35 mL    NG:    Stool:    Drains:    Balance:                                                                  -2,223 mL                                                                     409 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 450 (450 - 450) mL    Vt (Spontaneous): 483 (483 - 483) mL'
# ----- Data j -----
# >> Time: 2131-12-26 07:42:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                     792 mL                                                                     322 mL    PO:              TF:    IVF:                                                                     762 mL                                                                     322 mL    Blood products:    Total out:                                                                   3,015 mL                                                                      20 mL    Urine:                                                                      15 mL                                                                      20 mL    NG:    Stool:    Drains:    Balance:                                                                  -2,223 mL                                                                     302 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 450 (450 - 450) mL    Vt (Spontaneous): 483 (483 - 483) mL'
# **********************************
# ********** Processing data for 2131-12-27 **********
# ********** Processing data for 2131-12-28 **********
# ********** Processing data for 2131-12-29 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                            sentence 1  \
# 31  Patient was prescribed Ipratropium Bromide MDI 12.9g Inhaler IH of total 2-8 PUFF
# 32  Patient was prescribed Levothyroxine Sodium 25mcg Tablet PO of total 25 mcg
#
#                              sentence 2     time 1              time 2  \
# 31  Ipratropium Bromide Inhalation Q6H' 2131-12-23 2131-12-23 22:56:00
# 32  Levothyroxine 125 mcg PO DAILY'     2131-12-23 2131-12-23 22:56:00
#
#           type 1    type 2  \
# 31  prescription  sentence
# 32  prescription  sentence
#
#                                                             concepts 1  \
# 31  {Ipratropium Bromide, ipratropium bromide}
# 32  {Levothyroxine Sodium, Levothyroxine Sodium 0.025 MG Oral Capsule}
#
#                                     concepts 2 cosine similarity  \
# 31  {Ipratropium Bromide, ipratropium bromide}  1.0
# 32  {levothyroxine}                             0.57735
#
#               semantic type
# 31  Pharmacologic Substance
# 32  Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                                          sentence 1  \
# 31   Patient was prescribed Ipratropium Bromide MDI 12.9g Inhaler IH of total 2-8 PUFF
# 32   Patient was prescribed Levothyroxine Sodium 25mcg Tablet PO of total 25 mcg
# 33   Patient was prescribed Nephrocaps 1 Capsule PO of total 1 CAP
# 140  Patient was prescribed Heparin Flush (10 units/ml) 10 Units/mL - 5 mL Syringe IV of total 2 mL
# 141  Patient was prescribed Levothyroxine Sodium 25mcg Tablet PO of total 25 mcg
# 142  Patient was prescribed Heparin Sodium 25,000 unit Premix Bag IV of total 25,000 UNIT
# 143  Patient was prescribed Heparin Sodium 25,000 unit Premix Bag IV of total 25,000 UNIT
# 183  Patient was prescribed Levothyroxine Sodium 25mcg Tablet PO of total 25 mcg
#
#                                 sentence 2     time 1              time 2  \
# 31   Ipratropium Bromide Inhalation Q6H'   2131-12-23 2131-12-23 22:56:00
# 32   Levothyroxine 125 mcg PO DAILY'       2131-12-23 2131-12-23 22:56:00
# 33   Nephrocaps 1 mg PO DAILY'             2131-12-23 2131-12-23 22:56:00
# 140  DC heparin today.'                    2131-12-25 2131-12-25 09:37:00
# 141  - Continue levothyroxine    ICU Care' 2131-12-25 2131-12-25 07:56:00
# 142  DC heparin today.'                    2131-12-25 2131-12-25 09:37:00
# 143  DC heparin today.'                    2131-12-25 2131-12-25 09:37:00
# 183  - Continue levothyroxine    ICU Care' 2131-12-26 2131-12-26 07:42:00
#
#            type 1    type 2  \
# 31   prescription  sentence
# 32   prescription  sentence
# 33   prescription  sentence
# 140  prescription  sentence
# 141  prescription  sentence
# 142  prescription  sentence
# 143  prescription  sentence
# 183  prescription  sentence
#
#                                                              concepts 1  \
# 31   {Ipratropium Bromide, ipratropium bromide}
# 32   {Levothyroxine Sodium, Levothyroxine Sodium 0.025 MG Oral Capsule}
# 33   {Nephrocaps}
# 140  {heparin}
# 141  {Levothyroxine Sodium, Levothyroxine Sodium 0.025 MG Oral Capsule}
# 142  {heparin sodium}
# 143  {heparin sodium}
# 183  {Levothyroxine Sodium, Levothyroxine Sodium 0.025 MG Oral Capsule}
#
#                                      concepts 2 cosine similarity  \
# 31   {Ipratropium Bromide, ipratropium bromide}  1.0
# 32   {levothyroxine}                             0.57735
# 33   {Nephrocaps}                                1.0
# 140  {heparin}                                   1.0
# 141  {levothyroxine}                             0.57735
# 142  {heparin}                                   0.707107
# 143  {heparin}                                   0.707107
# 183  {levothyroxine}                             0.57735
#
#                semantic type
# 31   Pharmacologic Substance
# 32   Pharmacologic Substance
# 33   Pharmacologic Substance
# 140  Pharmacologic Substance
# 141  Pharmacologic Substance
# 142  Pharmacologic Substance
# 143  Pharmacologic Substance
# 183  Pharmacologic Substance

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 140
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "DC heparin stopped."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Heparin Flush (10 units/ml) 10 Units/mL - 5 mL Syringe IV of total 2 mL
# sentence 2:	DC heparin today.'
#
# New contradicting sentence: DC heparin stopped.

# %%
no_contradiction_pair_idx = [32, 33]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed Levothyroxine Sodium 25mcg Tablet PO of total 25 mcg
# sentence 2:	Levothyroxine 125 mcg PO DAILY'
# *****************************
# prescription 1:	Patient was prescribed Nephrocaps 1 Capsule PO of total 1 CAP
# sentence 2:	Nephrocaps 1 mg PO DAILY'
# *****************************

# %% [markdown]
# ## Patient 2

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[1] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 129414
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2174-02-12 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.7252406676228422
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Sleep Apnea, Obstructive', 'Obesity', 'Glucose Intolerance (disease)', 'Continuous Positive Airway Pressure'}
# >> Obesity:    Glucose intolerance:    Obstructive sleep apnea: declined CPAP therapy.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Sleep Apnea, Obstructive', 'Positive pressure therapy', 'Continuous Positive Airway Pressure'}
# >> Obstructive sleep apnea:  Declined CPAP therapy in the past but    will likely benefit from positive pressure as he is desatting when he    falls asleep.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.75
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Vitamin B 12 Deficiency', 'Asthma'}
# >> Vitamin B12 deficiency:  not on b12 currently    Twin sister with asthma'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Vitamin B 12 Deficiency', 'Anemia'}
# >> #Anemia: Slightly lower than recent baseline, likely secondary to known    Vitamin B12 deficiency.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Advair', 'Spiriva', 'Asthma'}
# >>    Asthma:  on Advair and Spiriva.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Asthma'}
# >> Patient only mildly wheezing on exam    and unlikely asthma exacerbation.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.9086882225022428
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Pneumonia', 'Structure of middle lobe of right lung'}
# >> He had a CXR which was    inconclusive, possible RML pneumonia.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Pneumonia', 'Structure of right upper lobe of lung', 'Structure of right lower lobe of lung'}
# >> Got a CTA for concern of PE-but no PE, but some    increased interstitial markings in RUL and RLL, more likely chronic    process vs. pneumonia.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography', 'Sinutab Sinus'}
# >> #Tachycardia: Sinus Tach on EKG from ED, likely due to hypoxia.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography', 'Sinutab Sinus'}
# >> Also be very tachycardic, EKG    shows sinus tach.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.7396002616336388
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Hydrochlorothiazide 50 MG Oral Tablet', 'Americium', 'hydrochlorothiazide'}
# >> -urine lytes and osms, serum osms    -recheck sodium in the AM    -continue HCTZ for now    .'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Hydrochlorothiazide 50 MG Oral Tablet', 'Hyponatremia', 'Diuretics', 'Inappropriate ADH Syndrome', 'hydrochlorothiazide'}
# >> #Hyponatremia:  [**Month (only) 51**]  be  [**1-18**]  intrapulmonary process (SIADH) or to HCTZ    (salt wasting with diuretics).'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 0.6708203932499369
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Coughing', 'Pneumonia', 'Zicam Cough'}
# >> #  Hypoxia:  Increased cough, infiltrate seen on CT and CXR make    hypoxia most likely due to pneumonia in the setting of poor reserve    given righ lung abnormalities.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Wheezing', 'Coughing', 'Dyspnea', 'Zicam Cough'}
# >>    Respiratory: Cough, Dyspnea, Tachypnea, No(t) Wheeze'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Lisinopril', 'Hypertet', 'Hydrochlorothiazide', 'hydrochlorothiazide', 'lisinopril', 'Norvasc'}
# >> Hypertension:    -continue hydrochlorothiazide, lisinopril and Norvasc.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Lisinopril', 'Hypertet', 'Hydrochlorothiazide', 'hydrochlorothiazide', 'lisinopril', 'Norvasc'}
# >>    Hypertension:  on hydrochlorothiazide, lisinopril, and Norvasc.'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: No(t) Dry mouth'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Obesity', 'Sus scrofa conjunctiva preparation', 'Ear structure', 'acute stress'}
# >>    General Appearance: No acute distress, Overweight / Obese    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: prescription
# >> Concepts: {'Albuterol', 'albuterol'}
# >> Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Albuterol', 'albuterol'}
# >> He tried increasing his albuterol use but this    did not help so he came to the emergency room.'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: prescription
# >> Concepts: {'Albuterol', 'albuterol'}
# >> Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Albuterol', 'albuterol'}
# >> He tried increasing his albuterol use but this    did not help so he came to the emergency room.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 4.9 mEq/L.
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >>    Hyperkalemia:  intermittent elevations of his potassium.'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.81 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:              16 mL    PO:              TF:    IVF:    16 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                      16 mL    Respiratory    O2 Delivery Device: Venti mask    SpO2: 97%'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: lab
# >> Concepts: {'folate'}
# >> Patient's Folate lab came back 10.2 ng/mL.
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'folate', 'Folate', 'Hematocrit procedure', 'Scientific Study'}
# >> -recheck HCT    -send iron studies and b12 and folate    .'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 5.4 mEq/L , which is abnormal.
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >>    Hyperkalemia:  intermittent elevations of his potassium.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.96 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:              16 mL    PO:              TF:    IVF:    16 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                      16 mL    Respiratory    O2 Delivery Device: Venti mask    SpO2: 97%'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.9086882225022428
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Pneumonia', 'Structure of middle lobe of right lung'}
# >> He had a CXR which was    inconclusive, possible RML pneumonia.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Pneumonia', 'Structure of right upper lobe of lung', 'Structure of right lower lobe of lung'}
# >> Got a CTA for concern of PE-but no PE, but some    increased interstitial markings in RUL and RLL, more likely chronic    process vs. pneumonia.'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: No(t) Dry mouth'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Obesity', 'Sus scrofa conjunctiva preparation', 'Ear structure', 'acute stress'}
# >>    General Appearance: No acute distress, Overweight / Obese    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Continuous Positive Airway Pressure'}
# >> He is now agreeable to trialing CPAP    -CPAP autoset with respiratory consult    .'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Continuous Positive Airway Pressure', 'Pulmonary Hypertension tadalafil 20 MG Oral Tablet [Alyq]'}
# >> Patient has OSA and does not wear CPAP at home, so    progressive pulmonary hypertension could be contributing but unlikely    to be causing symptoms of 1 week.'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 0.8017837257372732
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Continuous Positive Airway Pressure'}
# >> He is now agreeable to trialing CPAP    -CPAP autoset with respiratory consult    .'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Sleep Apnea, Obstructive', 'Positive pressure therapy', 'Continuous Positive Airway Pressure'}
# >> Obstructive sleep apnea:  Declined CPAP therapy in the past but    will likely benefit from positive pressure as he is desatting when he    falls asleep.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.7252406676228422
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Sleep Apnea, Obstructive', 'Obesity', 'Glucose Intolerance (disease)', 'Continuous Positive Airway Pressure'}
# >> Obesity:    Glucose intolerance:    Obstructive sleep apnea: declined CPAP therapy.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Sleep Apnea, Obstructive', 'Positive pressure therapy', 'Continuous Positive Airway Pressure'}
# >> Obstructive sleep apnea:  Declined CPAP therapy in the past but    will likely benefit from positive pressure as he is desatting when he    falls asleep.'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Sleep Apnea, Obstructive', 'Obesity', 'Glucose Intolerance (disease)', 'Continuous Positive Airway Pressure'}
# >> Obesity:    Glucose intolerance:    Obstructive sleep apnea: declined CPAP therapy.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Continuous Positive Airway Pressure'}
# >> He is now agreeable to trialing CPAP    -CPAP autoset with respiratory consult    .'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography', 'Sinutab Sinus'}
# >> #Tachycardia: Sinus Tach on EKG from ED, likely due to hypoxia.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography', 'Sinutab Sinus'}
# >> Also be very tachycardic, EKG    shows sinus tach.'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.6708203932499369
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Coughing', 'Pneumonia', 'Zicam Cough'}
# >> #  Hypoxia:  Increased cough, infiltrate seen on CT and CXR make    hypoxia most likely due to pneumonia in the setting of poor reserve    given righ lung abnormalities.'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Wheezing', 'Coughing', 'Dyspnea', 'Zicam Cough'}
# >>    Respiratory: Cough, Dyspnea, Tachypnea, No(t) Wheeze'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.7396002616336388
# ----- Data i -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Hydrochlorothiazide 50 MG Oral Tablet', 'Americium', 'hydrochlorothiazide'}
# >> -urine lytes and osms, serum osms    -recheck sodium in the AM    -continue HCTZ for now    .'
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Hydrochlorothiazide 50 MG Oral Tablet', 'Hyponatremia', 'Diuretics', 'Inappropriate ADH Syndrome', 'hydrochlorothiazide'}
# >> #Hyponatremia:  [**Month (only) 51**]  be  [**1-18**]  intrapulmonary process (SIADH) or to HCTZ    (salt wasting with diuretics).'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.592999453328881
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: prescription
# >> Concepts: {'Hydrochlorothiazide 25 MG', 'Hydrochlorothiazide 25 MG Oral Tablet'}
# >> Patient was prescribed Hydrochlorothiazide 25mg Tablet PO/NG of total 25 mg
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Hydrochlorothiazide 50 MG Oral Tablet', 'Hyponatremia', 'Diuretics', 'Inappropriate ADH Syndrome', 'hydrochlorothiazide'}
# >> #Hyponatremia:  [**Month (only) 51**]  be  [**1-18**]  intrapulmonary process (SIADH) or to HCTZ    (salt wasting with diuretics).'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.7126966450997985
# ----- Data i -----
# >> Time: 2174-02-12 00:00:00
# >> Type: prescription
# >> Concepts: {'Hydrochlorothiazide 25 MG', 'Hydrochlorothiazide 25 MG Oral Tablet'}
# >> Patient was prescribed Hydrochlorothiazide 25mg Tablet PO/NG of total 25 mg
# ----- Data j -----
# >> Time: 2174-02-12 19:14:00
# >> Type: sentence
# >> Concepts: {'Hydrochlorothiazide 50 MG Oral Tablet', 'Americium', 'hydrochlorothiazide'}
# >> -urine lytes and osms, serum osms    -recheck sodium in the AM    -continue HCTZ for now    .'
# **********************************
# ********** Processing data for 2174-02-13 **********
# ***** PAIR INDEX 27 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2174-02-13 07:34:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Not assessed'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Not assessed'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2174-02-13 07:34:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                      75 mL    PO:              TF:    IVF:                                                                   1,068 mL                                                                      75 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -550 mL    Respiratory support    O2 Delivery Device: Bipap mask    SpO2: 99%'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                     255 mL    PO:              100 mL    TF:    IVF:                                                                   1,068 mL                                                                     155 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -370 mL    Respiratory support    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2174-02-13 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.83 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                     255 mL    PO:              100 mL    TF:    IVF:                                                                   1,068 mL                                                                     155 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -370 mL    Respiratory support    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2174-02-13 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.83 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2174-02-13 07:34:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                      75 mL    PO:              TF:    IVF:                                                                   1,068 mL                                                                      75 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -550 mL    Respiratory support    O2 Delivery Device: Bipap mask    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.7071067811865476
# ----- Data i -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Structure of middle lobe of right lung'}
# >> CT did show consolidation    in RML.'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Asthma', 'Sleep Apnea Syndromes', 'Lung diseases', 'Kcentra', 'Structure of right lower lobe of lung'}
# >> HPI:    51 yo history of asthma and hypoplasia of right lower lobe, frequent    exacerbations of lung disease, sleep apnea - both central and OSA.'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2174-02-13 07:34:00
# >> Type: sentence
# >> Concepts: {'Left radial vein'}
# >>    Peripheral Vascular: (Right radial pulse: Not assessed), (Left radial    pulse: Not assessed), (Right DP pulse: Not assessed), (Left DP pulse:    Not assessed)'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Left radial vein'}
# >>    Peripheral Vascular: (Right radial pulse: Not assessed), (Left radial    pulse: Not assessed), (Right DP pulse: Not assessed), (Left DP pulse:    Not assessed)    Respiratory / Chest: (Breath Sounds: Crackles : left side)'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2174-02-13 07:34:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                      75 mL    PO:              TF:    IVF:                                                                   1,068 mL                                                                      75 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -550 mL    Respiratory support    O2 Delivery Device: Bipap mask    SpO2: 99%'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                     255 mL    PO:              100 mL    TF:    IVF:                                                                   1,068 mL                                                                     155 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -370 mL    Respiratory support    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2174-02-13 07:34:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: Responds to: Not assessed, Movement: Not assessed, Tone:    Not assessed    Labs / Radiology    393 K/uL'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: No(t) Attentive, No(t) Follows simple commands, Responds    to: Verbal stimuli, Movement: Not assessed, Tone: Not assessed    Labs / Radiology'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Dyspnea'}
# >> Currently getting mildly SOB while talking.'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Dyspnea'}
# >> Presented with hypoxemia and SOB that has been    progressively worsening over a week.'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2174-02-13 07:34:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                      75 mL    PO:              TF:    IVF:                                                                   1,068 mL                                                                      75 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -550 mL    Respiratory support    O2 Delivery Device: Bipap mask    SpO2: 99%'
# ----- Data j -----
# >> Time: 2174-02-13 10:57:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 64 Inch              Total In:                                                                   1,068 mL                                                                     255 mL    PO:              100 mL    TF:    IVF:                                                                   1,068 mL                                                                     155 mL    Blood products:    Total out:                                                                     600 mL                                                                     625 mL    Urine:                                                                     600 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                     468 mL                                                                    -370 mL    Respiratory support    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ********** Processing data for 2174-02-14 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                             sentence 1  \
# 9   Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# 10  Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
#
#                                                                                            sentence 2  \
# 9   He tried increasing his albuterol use but this    did not help so he came to the emergency room.'
# 10  He tried increasing his albuterol use but this    did not help so he came to the emergency room.'
#
#        time 1              time 2        type 1    type 2  \
# 9  2174-02-12 2174-02-12 19:14:00  prescription  sentence
# 10 2174-02-12 2174-02-12 19:14:00  prescription  sentence
#
#                 concepts 1              concepts 2 cosine similarity  \
# 9   {Albuterol, albuterol}  {Albuterol, albuterol}  1.0
# 10  {Albuterol, albuterol}  {Albuterol, albuterol}  1.0
#
#               semantic type
# 9   Pharmacologic Substance
# 10  Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                             sentence 1  \
# 9   Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# 10  Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# 25  Patient was prescribed Hydrochlorothiazide 25mg Tablet PO/NG of total 25 mg
# 26  Patient was prescribed Hydrochlorothiazide 25mg Tablet PO/NG of total 25 mg
#
#                                                                                                                              sentence 2  \
# 9   He tried increasing his albuterol use but this    did not help so he came to the emergency room.'
# 10  He tried increasing his albuterol use but this    did not help so he came to the emergency room.'
# 25  #Hyponatremia:  [**Month (only) 51**]  be  [**1-18**]  intrapulmonary process (SIADH) or to HCTZ    (salt wasting with diuretics).'
# 26  -urine lytes and osms, serum osms    -recheck sodium in the AM    -continue HCTZ for now    .'
#
#        time 1              time 2        type 1    type 2  \
# 9  2174-02-12 2174-02-12 19:14:00  prescription  sentence
# 10 2174-02-12 2174-02-12 19:14:00  prescription  sentence
# 25 2174-02-12 2174-02-12 19:14:00  prescription  sentence
# 26 2174-02-12 2174-02-12 19:14:00  prescription  sentence
#
#                                                             concepts 1  \
# 9   {Albuterol, albuterol}
# 10  {Albuterol, albuterol}
# 25  {Hydrochlorothiazide 25 MG, Hydrochlorothiazide 25 MG Oral Tablet}
# 26  {Hydrochlorothiazide 25 MG, Hydrochlorothiazide 25 MG Oral Tablet}
#
#                                                                                                            concepts 2  \
# 9   {Albuterol, albuterol}
# 10  {Albuterol, albuterol}
# 25  {Hydrochlorothiazide 50 MG Oral Tablet, Hyponatremia, Diuretics, Inappropriate ADH Syndrome, hydrochlorothiazide}
# 26  {Hydrochlorothiazide 50 MG Oral Tablet, Americium, hydrochlorothiazide}
#
#    cosine similarity            semantic type
# 9   1.0               Pharmacologic Substance
# 10  1.0               Pharmacologic Substance
# 25  0.592999          Clinical Drug
# 26  0.712697          Clinical Drug

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 10
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "He stopped his albuterol use but this did not help so he came to the emergency room."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# sentence 2:	He tried increasing his albuterol use but this    did not help so he came to the emergency room.'
#
# New contradicting sentence: He stopped his albuterol use but this did not help so he came to the emergency room.

# %%
no_contradiction_pair_idx = [25, 26]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")

# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed Hydrochlorothiazide 25mg Tablet PO/NG of total 25 mg
# sentence 2:	#Hyponatremia:  [**Month (only) 51**]  be  [**1-18**]  intrapulmonary process (SIADH) or to HCTZ    (salt wasting with diuretics).'
# *****************************
# prescription 1:	Patient was prescribed Hydrochlorothiazide 25mg Tablet PO/NG of total 25 mg
# sentence 2:	-urine lytes and osms, serum osms    -recheck sodium in the AM    -continue HCTZ for now    .'
# *****************************

# %%
"""
Todo: ask Dr. Saenz
"""
potential_contradiction_pair_indices = [21]

print("Potential examples of contradictions")
print("*****************************")
for pair_idx in potential_contradiction_pair_indices:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
# Out:
# Potential examples of contradictions
# *****************************
# lab 1:	Patient's White Blood Cells lab came back 6.0 K/uL.
# sentence 2:	Labs notable for WBC of 5, HCT 34.5,    sodium of 131 and creatinine of 1.0.'
# *****************************

# %% [markdown]
# ## Patient 3

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[2] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 133623
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2145-11-30 **********
# ********** Processing data for 2145-12-01 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'ethanol', 'Chest Pain', 'Hepatitis C', 'Infantile Neuroaxonal Dystrophy', 'Ting AF'}
# >>    ASSESSMENT AND PLAN: 54M with hx of ETOH abuse, HCV, presenting with AF    with RVR, Chest Pain in the setting of ETOH intoxication.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'ethanol', 'Chest Pain', 'Hepatitis C'}
# >> Chest Pain, ETOH Intoxication    HPI:    54M with hx of ETOH abuse, HCV, presented to the ED this evening    intoxicated.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.6761234037828131
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Prothrombin time assay', 'Atrial Fibrillation'}
# >> Pt currently in AF with rates in 120s.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.5393598899705937
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'ethanol', 'Chest Pain', 'Hepatitis C', 'Infantile Neuroaxonal Dystrophy', 'Ting AF'}
# >>    ASSESSMENT AND PLAN: 54M with hx of ETOH abuse, HCV, presenting with AF    with RVR, Chest Pain in the setting of ETOH intoxication.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.5111012519999519
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Prothrombin time assay', 'Atrial Fibrillation'}
# >> Pt currently in AF with rates in 120s.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'ethanol', 'Chest Pain', 'Hepatitis C', 'Infantile Neuroaxonal Dystrophy', 'Ting AF'}
# >>    ASSESSMENT AND PLAN: 54M with hx of ETOH abuse, HCV, presenting with AF    with RVR, Chest Pain in the setting of ETOH intoxication.'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.5714285714285714
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.5222329678670936
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his /    her note above, including assessment and plan.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'ethanol', 'Chest Pain', 'Hepatitis C', 'Infantile Neuroaxonal Dystrophy', 'Ting AF'}
# >>    ASSESSMENT AND PLAN: 54M with hx of ETOH abuse, HCV, presenting with AF    with RVR, Chest Pain in the setting of ETOH intoxication.'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.5131423604911342
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'ethanol', 'Chest Pain', 'Hepatitis C', 'Infantile Neuroaxonal Dystrophy', 'Ting AF'}
# >>    ASSESSMENT AND PLAN: 54M with hx of ETOH abuse, HCV, presenting with AF    with RVR, Chest Pain in the setting of ETOH intoxication.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'ethanol', 'Chest Pain', 'Hepatitis C'}
# >> Chest Pain, ETOH Intoxication    HPI:    54M with hx of ETOH abuse, HCV, presented to the ED this evening    intoxicated.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'acute stress', 'Sus scrofa conjunctiva preparation', 'Ear structure', 'Mydriasis'}
# >>    General Appearance: Well nourished, No acute distress    Eyes / Conjunctiva: PERRL, Pupils dilated    Head, Ears, Nose, Throat: Normocephalic'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: Dry mouth'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.6761234037828131
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Prothrombin time assay', 'Atrial Fibrillation'}
# >> Pt currently in AF with rates in 120s.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.5393598899705937
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'ethanol', 'Chest Pain', 'Hepatitis C', 'Infantile Neuroaxonal Dystrophy', 'Ting AF'}
# >>    ASSESSMENT AND PLAN: 54M with hx of ETOH abuse, HCV, presenting with AF    with RVR, Chest Pain in the setting of ETOH intoxication.'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.5111012519999519
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.5669467095138407
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay', 'ethanol'}
# >> # ETOH Intoxication: Pt presented with ETOH level of 412.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Prothrombin time assay', 'Atrial Fibrillation'}
# >> Pt currently in AF with rates in 120s.'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.5303300858899106
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay', 'ethanol'}
# >> # ETOH Intoxication: Pt presented with ETOH level of 412.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay', 'nitroglycerin', 'aspirin', 'Nitroglycerin'}
# >> PT received ASA 325mg and Nitroglycerin x1.', "CE's x1    negative."
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Prothrombin time assay', 'Atrial Fibrillation'}
# >> Pt currently in AF with rates in 120s.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'ethanol', 'Chest Pain', 'Hepatitis C', 'Infantile Neuroaxonal Dystrophy', 'Ting AF'}
# >>    ASSESSMENT AND PLAN: 54M with hx of ETOH abuse, HCV, presenting with AF    with RVR, Chest Pain in the setting of ETOH intoxication.'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation', 'Dilt'}
# >> #: AF with RVR: HR at 110s upon arrival to the floor on Dilt gtt.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.5714285714285714
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Ting AF', 'Atrial Fibrillation'}
# >> Upon assessment the pt reportedly became    combative with a HR revealing AF with RVR with rates in 160-170s.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Sea Soft'}
# >>    Abdominal: Soft, Non-tender, Bowel sounds present'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Sea Soft'}
# >>    Abdominal: Soft, Non-tender'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Not assessed'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Not assessed'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'ethanol'}
# >> HPI:    Patient with excessive EtOH ingestion which he states is an event  [**2-3**]     times per month.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'ethanol'}
# >> ETOH heavy at times    although denies daily use.'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.6553310156079495
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Atrial Fibrillation by ECG Finding', 'Valium', 'ECHO protocol', 'Electrocardiography', 'Papain'}
# >> Will manage as follows    1)EtOH Intoxication-    -MVI/Thiamine/Folate    -Continue CIWA scale for support with valium as needed    -Social work consult in place    2)Atrial Fibrillation-    -Lopressor TID for rate control    -He does have persistent atrial fibrillation    -Will send TST and perform ECHO    3)Chest Pain--does not appear to be cardiac, is subjective patient    complaint    -MSO4 given PRN for complaint of pain    -Patient did have troponin performed which was within normal limits and    ECG was without acute injury suggested    ICU Care'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'S-1 Antimetabolite agent'}
# >>    Cardiovascular: (S1: Normal), (S2: Distant)'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'S-1 Antimetabolite agent'}
# >>    Cardiovascular: (S1: Normal), (S2: Normal)'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.5131423604911342
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.6187251285745443
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Atrial Fibrillation by ECG Finding', 'Valium', 'ECHO protocol', 'Electrocardiography', 'Papain'}
# >> Will manage as follows    1)EtOH Intoxication-    -MVI/Thiamine/Folate    -Continue CIWA scale for support with valium as needed    -Social work consult in place    2)Atrial Fibrillation-    -Lopressor TID for rate control    -He does have persistent atrial fibrillation    -Will send TST and perform ECHO    3)Chest Pain--does not appear to be cardiac, is subjective patient    complaint    -MSO4 given PRN for complaint of pain    -Patient did have troponin performed which was within normal limits and    ECG was without acute injury suggested    ICU Care'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.721020877878908
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.8610567718228918
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Atrial Fibrillation by ECG Finding', 'Valium', 'ECHO protocol', 'Electrocardiography', 'Papain'}
# >> Will manage as follows    1)EtOH Intoxication-    -MVI/Thiamine/Folate    -Continue CIWA scale for support with valium as needed    -Social work consult in place    2)Atrial Fibrillation-    -Lopressor TID for rate control    -He does have persistent atrial fibrillation    -Will send TST and perform ECHO    3)Chest Pain--does not appear to be cardiac, is subjective patient    complaint    -MSO4 given PRN for complaint of pain    -Patient did have troponin performed which was within normal limits and    ECG was without acute injury suggested    ICU Care'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.7165743639000184
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.6069327367499427
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 24 (13 - 29) insp/min    SpO2: 100%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              2,303 mL    PO:              1,200 mL    TF:    IVF:    1,103 mL    Blood products:    Total out:                                                                       0 mL                                                                     800 mL    Urine:    650 mL    NG:    Stool:    150 mL    Drains:    Balance:                                                                       0 mL                                                                   1,503 mL    Respiratory    O2 Delivery Device: None    SpO2: 100%'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Papain', 'Americium'}
# >>    Pain:  [**4-7**]  Moderate    Pain location: Chest    Flowsheet Data as of  [**2145-12-1**]  10:02 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since 12 AM'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Papain'}
# >> Cardiology    evaluated pt and felt his pain was unlikely cardiac.'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.67005939426049
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.8001976040538967
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Atrial Fibrillation by ECG Finding', 'Valium', 'ECHO protocol', 'Electrocardiography', 'Papain'}
# >> Will manage as follows    1)EtOH Intoxication-    -MVI/Thiamine/Folate    -Continue CIWA scale for support with valium as needed    -Social work consult in place    2)Atrial Fibrillation-    -Lopressor TID for rate control    -He does have persistent atrial fibrillation    -Will send TST and perform ECHO    3)Chest Pain--does not appear to be cardiac, is subjective patient    complaint    -MSO4 given PRN for complaint of pain    -Patient did have troponin performed which was within normal limits and    ECG was without acute injury suggested    ICU Care'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 0.6326308003014256
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.8804087784801331
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2145-12-01 00:00:00
# >> Type: prescription
# >> Concepts: {'metoprolol', 'Metoprolol'}
# >> Patient was prescribed Metoprolol Tartrate 25mg Tablet PO/NG of total 25 mg
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'metoprolol', 'Metoprolol'}
# >> Recommended    Metoprolol.'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2145-12-01 00:00:00
# >> Type: lab
# >> Concepts: {'Lactate', 'lactate'}
# >> Patient's Lactate lab came back 1.8 mmol/L.
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Lactate', 'lactate'}
# >> Lactate    elevated.'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2145-12-01 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.66 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 24 (13 - 29) insp/min    SpO2: 100%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              2,303 mL    PO:              1,200 mL    TF:    IVF:    1,103 mL    Blood products:    Total out:                                                                       0 mL                                                                     800 mL    Urine:    650 mL    NG:    Stool:    150 mL    Drains:    Balance:                                                                       0 mL                                                                   1,503 mL    Respiratory    O2 Delivery Device: None    SpO2: 100%'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2145-12-01 00:00:00
# >> Type: lab
# >> Concepts: {'Ethanol', 'ethanol'}
# >> Patient's Ethanol lab came back 308 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'ethanol'}
# >> ETOH heavy at times    although denies daily use.'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2145-12-01 00:00:00
# >> Type: lab
# >> Concepts: {'Ethanol', 'ethanol'}
# >> Patient's Ethanol lab came back 308 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'ethanol'}
# >> HPI:    Patient with excessive EtOH ingestion which he states is an event  [**2-3**]     times per month.'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2145-12-01 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.81 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 24 (13 - 29) insp/min    SpO2: 100%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              2,303 mL    PO:              1,200 mL    TF:    IVF:    1,103 mL    Blood products:    Total out:                                                                       0 mL                                                                     800 mL    Urine:    650 mL    NG:    Stool:    150 mL    Drains:    Balance:                                                                       0 mL                                                                   1,503 mL    Respiratory    O2 Delivery Device: None    SpO2: 100%'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'acute stress', 'Sus scrofa conjunctiva preparation', 'Ear structure', 'Mydriasis'}
# >>    General Appearance: Well nourished, No acute distress    Eyes / Conjunctiva: PERRL, Pupils dilated    Head, Ears, Nose, Throat: Normocephalic'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# ...
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 107 *****
# Cosine similarity: 0.6187251285745443
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Atrial Fibrillation by ECG Finding', 'Valium', 'ECHO protocol', 'Electrocardiography', 'Papain'}
# >> Will manage as follows    1)EtOH Intoxication-    -MVI/Thiamine/Folate    -Continue CIWA scale for support with valium as needed    -Social work consult in place    2)Atrial Fibrillation-    -Lopressor TID for rate control    -He does have persistent atrial fibrillation    -Will send TST and perform ECHO    3)Chest Pain--does not appear to be cardiac, is subjective patient    complaint    -MSO4 given PRN for complaint of pain    -Patient did have troponin performed which was within normal limits and    ECG was without acute injury suggested    ICU Care'
# **********************************
# ***** PAIR INDEX 108 *****
# Cosine similarity: 0.721020877878908
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 109 *****
# Cosine similarity: 0.8610567718228918
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Atrial Fibrillation by ECG Finding', 'Valium', 'ECHO protocol', 'Electrocardiography', 'Papain'}
# >> Will manage as follows    1)EtOH Intoxication-    -MVI/Thiamine/Folate    -Continue CIWA scale for support with valium as needed    -Social work consult in place    2)Atrial Fibrillation-    -Lopressor TID for rate control    -He does have persistent atrial fibrillation    -Will send TST and perform ECHO    3)Chest Pain--does not appear to be cardiac, is subjective patient    complaint    -MSO4 given PRN for complaint of pain    -Patient did have troponin performed which was within normal limits and    ECG was without acute injury suggested    ICU Care'
# **********************************
# ***** PAIR INDEX 110 *****
# Cosine similarity: 0.7165743639000184
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# **********************************
# ***** PAIR INDEX 111 *****
# Cosine similarity: 0.6069327367499427
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 24 (13 - 29) insp/min    SpO2: 100%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              2,303 mL    PO:              1,200 mL    TF:    IVF:    1,103 mL    Blood products:    Total out:                                                                       0 mL                                                                     800 mL    Urine:    650 mL    NG:    Stool:    150 mL    Drains:    Balance:                                                                       0 mL                                                                   1,503 mL    Respiratory    O2 Delivery Device: None    SpO2: 100%'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 112 *****
# Cosine similarity: 0.67005939426049
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 03:47:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'nitroglycerin', 'Uridine', 'Atrial Fibrillation by ECG Finding', 'Ting AF', 'Drainage procedure', 'Atrial Fibrillation', 'Blood Stop Topical Product', 'Systane Balance', 'Fertilization in Vitro', 'Blood product'}
# >>    RR: 29 (13 - 29) insp/min    SpO2: 95%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 117.4 kg (admission): 117.4 kg              Total In:              558 mL    PO:              480 mL    TF:    IVF:    78 mL    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                     558 mL    Respiratory    O2 Delivery Device: None    SpO2: 95%'
# **********************************
# ***** PAIR INDEX 113 *****
# Cosine similarity: 0.8001976040538967
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Atrial Fibrillation by ECG Finding', 'Valium', 'ECHO protocol', 'Electrocardiography', 'Papain'}
# >> Will manage as follows    1)EtOH Intoxication-    -MVI/Thiamine/Folate    -Continue CIWA scale for support with valium as needed    -Social work consult in place    2)Atrial Fibrillation-    -Lopressor TID for rate control    -He does have persistent atrial fibrillation    -Will send TST and perform ECHO    3)Chest Pain--does not appear to be cardiac, is subjective patient    complaint    -MSO4 given PRN for complaint of pain    -Patient did have troponin performed which was within normal limits and    ECG was without acute injury suggested    ICU Care'
# **********************************
# ***** PAIR INDEX 114 *****
# Cosine similarity: 0.6326308003014256
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Atrial Fibrillation by ECG Finding', 'Lactic acid', 'magnesium cation', 'glucose', 'hepatitis C vaccine', 'Antabuse', 'Infantile Neuroaxonal Dystrophy'}
# >> 27.2 %    8.4 g/dL    93 mg/dL    0.6 mg/dL    13 mg/dL    23 mEq/L    109 mEq/L    4.2 mEq/L    143 mEq/L    4.0 K/uL         [image002.jpg]                              [**2145-12-1**]   02:40 AM    WBC                                      4.0    Hct                                     27.2    Plt                                      278    Cr                                      0.6    Glucose                                      93    Other labs: Lactic Acid:1.8 mmol/L, Ca++:8.4 mg/dL, Mg++:1.9 mg/dL,    PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9    Assessment and Plan    54 yo male with history of Hep C and EtOH abuse now admitted with acute    intoxication and signfiicant atrial fibrillation to ICU for further    care.'
# **********************************
# ***** PAIR INDEX 115 *****
# Cosine similarity: 0.8804087784801331
# ----- Data i -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'cytarabine/melphalan', 'Morning After'}
# >>    Communication:  Comments:   Patient is requesting to leave AMA this    morning he states that he understands the risk of leaving include death    as relates to withdrawl and persistent atrial fibrillation.'
# ----- Data j -----
# >> Time: 2145-12-01 10:17:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation by ECG Finding', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'ethanol'}
# >> EtOH Intoxication    Atrial Fibrillation    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# **********************************

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                      sentence 1  \
# 37  Patient was prescribed Metoprolol Tartrate 25mg Tablet PO/NG of total 25 mg
#
#                      sentence 2     time 1              time 2        type 1  \
# 37  Recommended    Metoprolol.' 2145-12-01 2145-12-01 03:47:00  prescription
#
#       type 2                concepts 1                concepts 2  \
# 37  sentence  {metoprolol, Metoprolol}  {metoprolol, Metoprolol}
#
#    cosine similarity            semantic type
# 37  1.0               Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                      sentence 1  \
# 37  Patient was prescribed Metoprolol Tartrate 25mg Tablet PO/NG of total 25 mg
#
#                      sentence 2     time 1              time 2        type 1  \
# 37  Recommended    Metoprolol.' 2145-12-01 2145-12-01 03:47:00  prescription
#
#       type 2                concepts 1                concepts 2  \
# 37  sentence  {metoprolol, Metoprolol}  {metoprolol, Metoprolol}
#
#    cosine similarity            semantic type
# 37  1.0               Pharmacologic Substance

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 37
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "Metoprolol not recommended."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Metoprolol Tartrate 25mg Tablet PO/NG of total 25 mg
# sentence 2:	Recommended    Metoprolol.'
#
# New contradicting sentence: Metoprolol not recommended.

# %%
# no_contradiction_pair_idx = [48, 76]

# print("Examples of non-contradictions")
# print("*****************************")
# for pair_idx in no_contradiction_pair_idx:
#     data_1 = data_inst_pairs[pair_idx][0][0]
#     data_2 = data_inst_pairs[pair_idx][0][1]
    
#     print(f"{data_1.type} 1:\t{data_1.txt}")
#     print(f"{data_2.type} 2:\t{data_2.txt}")
#     print("*****************************")
    
# # Store negative examples
# generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx

# %% [markdown]
# ## Patient 4

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[3] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 197325
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2157-02-01 **********
# ********** Processing data for 2157-02-02 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.5477225575051662
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Acute cholangitis', 'Mapap', 'Deuteranomaly', 'Flagyl', 'Infantile Neuroaxonal Dystrophy', 'BCX 34'}
# >> Agree with plan to manage acute cholangitis with obstructing CBD stone    with broad abx coverage with vanco / zosyn / flagyl while awaiting BCx    and continuing hydration based on MAP / UOP.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> Remainder of plan as outlined    above.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Refractory anemias'}
# >> In the ER her VS were T 101.5, HR 68, BP 152/76, RR 16, SpO2 95% RA.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Refractory anemias'}
# >> Exam notable for Tm 100.7 BP 100/30 HR 67 RR with sat 97 on RA.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Diverticulosis'}
# >> Diverticulosis'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Diverticulosis', 'Hematocrit procedure'}
# >> Diverticulosis - Stable HCT, no signs of bleeding or inflammation.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.5298129428260175
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'dexamethasone', "parkinson's disease and parkinsonism", 'Gastroesophageal reflux disease', 'Pancreatic Diseases', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME'}
# >> Will    monitor FSG with RISS while in ICU; no prior hx DM but FSG >200 in the    ED in patient with chronic pancreatic disease.', "Will continue    Parkinson's and GERD meds at home doses."
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> Gastroesophageal reflux disease.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Cerebrovascular accident', 'Cholecystectomy procedure'}
# >> [**2133**]  she had a cholecystectomy performed in the Soviet  [**Hospital1 7850**]     No family of MI, stroke, son prostate cancer.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Cholelithiasis', 'Cholecystectomy procedure'}
# >> Status post cholecystectomy secondarely to gallstones.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay', 'Cholangitis', 'Tuberculosis', 'Right upper quadrant pain'}
# >> Cholangitis - Pt with RUQ pain and boas sign found to have 13 WBC    with 14% bands, AST 979, ALT 723, AP 120, TB 3.5 and direct of 2.4    found to have cholangitis on ERCP.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay', 'Cholangitis'}
# >> Elevated lactate - Pt with stable VS, cholangitis as above.'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> GERD - ASymptomatic.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> Gastroesophageal reflux disease.'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.5298129428260175
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> GERD - ASymptomatic.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'dexamethasone', "parkinson's disease and parkinsonism", 'Gastroesophageal reflux disease', 'Pancreatic Diseases', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME'}
# >> Will    monitor FSG with RISS while in ICU; no prior hx DM but FSG >200 in the    ED in patient with chronic pancreatic disease.', "Will continue    Parkinson's and GERD meds at home doses."
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Blood culture', 'Ulcerative Colitis'}
# >> - Blood cultures    - UA & UC    - Zosyn as above    .'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Ulcerative Colitis'}
# >> Getting UA and UC given urinary frequency.'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >>    Communication:  Comments: Plan discussed in detail with patient    Code status: Full code    Disposition :Transfer to floor    Total time spent: 34 minutes']
#
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> Remainder of plan as outlined    above.'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.5477225575051662
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >>    Communication:  Comments: Plan discussed in detail with patient    Code status: Full code    Disposition :Transfer to floor    Total time spent: 34 minutes']
#
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Acute cholangitis', 'Mapap', 'Deuteranomaly', 'Flagyl', 'Infantile Neuroaxonal Dystrophy', 'BCX 34'}
# >> Agree with plan to manage acute cholangitis with obstructing CBD stone    with broad abx coverage with vanco / zosyn / flagyl while awaiting BCx    and continuing hydration based on MAP / UOP.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Cholangitis'}
# >> Cholangitis    I saw and examined the patient, and was physically present with the    for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Leukocytosis', 'Cholangitis'}
# >> Leukocytosis - Most likely secondarely to cholangitis (See above.'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Cholangitis'}
# >> Cholangitis    I saw and examined the patient, and was physically present with the    for key portions of the services provided.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Cholangitis', 'Deuteranomaly'}
# >> Started on    Unasyn, taken for urgent ERCP this PM given concern for cholangitis,    which was notable for CBD stone with pus - stent placed, stone remains    in CBD.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his / her note    above, including assessment and plan.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> Remainder of plan as outlined    above.'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.5477225575051662
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his / her note    above, including assessment and plan.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Acute cholangitis', 'Mapap', 'Deuteranomaly', 'Flagyl', 'Infantile Neuroaxonal Dystrophy', 'BCX 34'}
# >> Agree with plan to manage acute cholangitis with obstructing CBD stone    with broad abx coverage with vanco / zosyn / flagyl while awaiting BCx    and continuing hydration based on MAP / UOP.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his / her note    above, including assessment and plan.'
# ----- Data j -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >>    Communication:  Comments: Plan discussed in detail with patient    Code status: Full code    Disposition :Transfer to floor    Total time spent: 34 minutes']
#
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.6141922686399943
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Bacteremia', 'Cholecystectomy procedure', 'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'glucose', 'Hypertet', 'Infantile Neuroaxonal Dystrophy', 'Vitamine E GNR'}
# >> 3.2 mEq/L    17 mg/dL    110 mEq/L    143 mEq/L    30.3 %    12.0 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM    WBC    12.0    Hct    30.3    Plt    100    Cr    0.9    Glucose    109    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:128/268, Alk Phos /    T Bili:76/3.4, Lactic Acid:1.6 mmol/L, LDH:202 IU/L, Ca++:7.3 mg/dL,    Mg++:1.7 mg/dL, PO4:2.9 mg/dL    Assessment and Plan    Mrs.  [**Known firstname 12011**]   [**Known lastname 12012**]  is an 85 year-old woman with significant past    medical history of hypertension, cholecystectomy and ampullar stenosis    here with cholangitis s/p stent placement c/b GNR bacteremia.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'carotid', 'Cholecystectomy procedure', 'Excision', 'Laboratory test finding', 'Prothrombin time assay', 'Cholangitis', 'Hypertet', 'Infantile Neuroaxonal Dystrophy', 'Femur'}
# >>    Left: Carotid 2+ Femoral 2+ Popliteal 2+ DP 2+ PT 2+    Labs / Radiology         [image002.jpg]    Other labs: Lactic Acid:4.3 mmol/L    Assessment and Plan    Mrs.  [**Known firstname 12011**]   [**Known lastname 12012**]  is a very nice 85 year-old woman with    significant past medical history of hypertension, cholecystectomy and    ampullar stenosis wh ocomes with cholangitis now s/p stent removal.'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> GERD:  Asymptomatic: Continue home-dose PPI.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> Gastroesophageal reflux disease.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.5298129428260175
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> GERD:  Asymptomatic: Continue home-dose PPI.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'dexamethasone', "parkinson's disease and parkinsonism", 'Gastroesophageal reflux disease', 'Pancreatic Diseases', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME'}
# >> Will    monitor FSG with RISS while in ICU; no prior hx DM but FSG >200 in the    ED in patient with chronic pancreatic disease.', "Will continue    Parkinson's and GERD meds at home doses."
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> GERD:  Asymptomatic: Continue home-dose PPI.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Gastroesophageal reflux disease'}
# >> GERD - ASymptomatic.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Blood culture', 'Ulcerative Colitis'}
# >> - F/U Blood cultures    - F/U UA & UC    - Antibiotics as above    #.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Ulcerative Colitis'}
# >> Getting UA and UC given urinary frequency.'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Blood culture', 'Ulcerative Colitis'}
# >> - F/U Blood cultures    - F/U UA & UC    - Antibiotics as above    #.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Blood culture', 'Ulcerative Colitis'}
# >> - Blood cultures    - UA & UC    - Zosyn as above    .'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Diverticulosis', 'Hematocrit procedure'}
# >> Diverticulosis: Stable HCT, no signs of bleeding or inflammation.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Diverticulosis', 'Hematocrit procedure'}
# >> Diverticulosis - Stable HCT, no signs of bleeding or inflammation.'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Diverticulosis', 'Hematocrit procedure'}
# >> Diverticulosis: Stable HCT, no signs of bleeding or inflammation.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Diverticulosis'}
# >> Diverticulosis'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Aspiration-action', 'Americium'}
# >> Single episode of desaturation concerning for possible    aspiration, check CXR in AM and continue broad abx as above.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> Review of systems:    Flowsheet Data as of  [**2157-2-2**]  01:36 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since  [**58**]  AM'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Already on antibiotics for    .'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> Review of systems:    Flowsheet Data as of  [**2157-2-2**]  01:36 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since  [**58**]  AM'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Already on antibiotics for    .'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Aspiration-action', 'Americium'}
# >> Single episode of desaturation concerning for possible    aspiration, check CXR in AM and continue broad abx as above.'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'ethanol', 'Pharmaceutical Preparations'}
# >> Never smoker, no alcohol, no drugs.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >> Will back up on her medications for now and re-start them    as needed.'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.6497862896539307
# ----- Data i -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 15 (12 - 24) insp/min    SpO2: 98%    Heart rhythm: SB (Sinus Bradycardia)              Total In:                                                                     564 mL                                                                   1,915 mL    PO:              TF:    IVF:                                                                     564 mL                                                                   1,915 mL    Blood products:    Total out:                                                                     160 mL                                                                     545 mL    Urine:                                                                     160 mL                                                                     545 mL    NG:    Stool:    Drains:    Balance:                                                                     404 mL                                                                   1,370 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 98%'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'nicotinamide adenine dinucleotide (NAD)', 'Refractory anemias', 'nitroglycerin', 'Uridine', 'Structure of palpebral conjunctiva', 'Lung', 'Felis catus skin extract', 'Drainage procedure', 'Heart', 'heptaarginine amide', 'Systane Balance', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Icterus', 'Comfortis', 'Neck of urinary bladder', 'Blood product'}
# >>    BP: 106/36(54) {106/30(48) - 156/58(79)} mmHg', "   RR: 18 (15 - 21) insp/min    SpO2: 97%    Heart rhythm: SB (Sinus Bradycardia)              Total In:                                                                     563 mL                                                                     351 mL    PO:              TF:    IVF:                                                                     563 mL                                                                     351 mL    Blood products:    Total out:                                                                     160 mL                                                                     390 mL    Urine:                                                                     160 mL                                                                     390 mL    NG:    Stool:    Drains:    Balance:                                                                     403 mL                                                                     -39 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 97%    Physical Examination    VITAL SIGNS - Temp 97.8 F, BP 108/30 mmHg, HR 78 BPM, RR 14 X', O2-sat    93% RA    GENERAL - well-appearing woman in NAD, comfortable, appropriate,    jaundiced (skin, mouth, conjuntiva)    HEENT - NC/AT, PERRLA, EOMI, sclerae icteric, MMM, OP clear    NECK - supple, no thyromegaly, no JVD, no carotid bruits    LUNGS - CTA bilat, no r/rh/wh, good air movement, resp unlabored, no    accessory muscle use    HEART - PMI non-displaced, RRR, no MRG, nl S1-S2    ABDOMEN - NABS, soft/NT/ND, no masses or HSM, no rebound/guarding."
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.7905694150420948
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Lactate', 'lactate', 'Americium', 'Liver Function Tests'}
# >> Lactate this AM    1.6.', "She remained hemodynamically stable and afebrile overnight and her    LFT's are significantly improved this AM."
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Lactate', 'lactate', 'Americium'}
# >> - lactate in AM    .'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.7302967433402215
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'nicotinamide adenine dinucleotide (NAD)', 'Structure of palpebral conjunctiva', 'Lung', 'Felis catus skin extract', 'Heart', 'heptaarginine amide', 'Comfortis', 'Icterus', 'Neck of urinary bladder'}
# >>    ABG: ///24/    Physical Examination    GENERAL - well-appearing woman in NAD, comfortable, appropriate,    jaundiced (skin, mouth, conjuntiva)    HEENT - NC/AT, PERRLA, EOMI, sclerae icteric, MMM, OP clear    NECK - supple, no JVD, no carotid bruits    LUNGS - CTA bilat, no r/rh/wh, good air movement    HEART - RRR, no MRG, nl S1-S2    ABDOMEN - NABS, soft/NT/ND, no masses or HSM, no rebound/guarding.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'nicotinamide adenine dinucleotide (NAD)', 'Refractory anemias', 'nitroglycerin', 'Uridine', 'Structure of palpebral conjunctiva', 'Lung', 'Felis catus skin extract', 'Drainage procedure', 'Heart', 'heptaarginine amide', 'Systane Balance', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Icterus', 'Comfortis', 'Neck of urinary bladder', 'Blood product'}
# >>    BP: 106/36(54) {106/30(48) - 156/58(79)} mmHg', "   RR: 18 (15 - 21) insp/min    SpO2: 97%    Heart rhythm: SB (Sinus Bradycardia)              Total In:                                                                     563 mL                                                                     351 mL    PO:              TF:    IVF:                                                                     563 mL                                                                     351 mL    Blood products:    Total out:                                                                     160 mL                                                                     390 mL    Urine:                                                                     160 mL                                                                     390 mL    NG:    Stool:    Drains:    Balance:                                                                     403 mL                                                                     -39 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 97%    Physical Examination    VITAL SIGNS - Temp 97.8 F, BP 108/30 mmHg, HR 78 BPM, RR 14 X', O2-sat    93% RA    GENERAL - well-appearing woman in NAD, comfortable, appropriate,    jaundiced (skin, mouth, conjuntiva)    HEENT - NC/AT, PERRLA, EOMI, sclerae icteric, MMM, OP clear    NECK - supple, no thyromegaly, no JVD, no carotid bruits    LUNGS - CTA bilat, no r/rh/wh, good air movement, resp unlabored, no    accessory muscle use    HEART - PMI non-displaced, RRR, no MRG, nl S1-S2    ABDOMEN - NABS, soft/NT/ND, no masses or HSM, no rebound/guarding."
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.6141922686399943
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Bacteremia', 'Cholecystectomy procedure', 'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'glucose', 'Hypertet', 'Infantile Neuroaxonal Dystrophy', 'Vitamine E GNR'}
# >> 3.2 mEq/L    17 mg/dL    110 mEq/L    143 mEq/L    30.3 %    12.0 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM    WBC    12.0    Hct    30.3    Plt    100    Cr    0.9    Glucose    109    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:128/268, Alk Phos /    T Bili:76/3.4, Lactic Acid:1.6 mmol/L, LDH:202 IU/L, Ca++:7.3 mg/dL,    Mg++:1.7 mg/dL, PO4:2.9 mg/dL    Assessment and Plan    Mrs.  [**Known firstname 12011**]   [**Known lastname 12012**]  is an 85 year-old woman with significant past    medical history of hypertension, cholecystectomy and ampullar stenosis    here with cholangitis s/p stent placement c/b GNR bacteremia.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'carotid', 'Cholecystectomy procedure', 'Excision', 'Laboratory test finding', 'Prothrombin time assay', 'Cholangitis', 'Hypertet', 'Infantile Neuroaxonal Dystrophy', 'Femur'}
# >>    Left: Carotid 2+ Femoral 2+ Popliteal 2+ DP 2+ PT 2+    Labs / Radiology         [image002.jpg]    Other labs: Lactic Acid:4.3 mmol/L    Assessment and Plan    Mrs.  [**Known firstname 12011**]   [**Known lastname 12012**]  is a very nice 85 year-old woman with    significant past medical history of hypertension, cholecystectomy and    ampullar stenosis wh ocomes with cholangitis now s/p stent removal.'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 0.7655318158241111
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Bacteremia', 'Cholecystectomy procedure', 'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'glucose', 'Hypertet', 'Infantile Neuroaxonal Dystrophy', 'Vitamine E GNR'}
# >> 3.2 mEq/L    17 mg/dL    110 mEq/L    143 mEq/L    30.3 %    12.0 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM    WBC    12.0    Hct    30.3    Plt    100    Cr    0.9    Glucose    109    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:128/268, Alk Phos /    T Bili:76/3.4, Lactic Acid:1.6 mmol/L, LDH:202 IU/L, Ca++:7.3 mg/dL,    Mg++:1.7 mg/dL, PO4:2.9 mg/dL    Assessment and Plan    Mrs.  [**Known firstname 12011**]   [**Known lastname 12012**]  is an 85 year-old woman with significant past    medical history of hypertension, cholecystectomy and ampullar stenosis    here with cholangitis s/p stent placement c/b GNR bacteremia.'
# ----- Data j -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'glucose', 'Glucose', 'Body fluid analysis', 'Laboratory test finding', 'Prothrombin time assay'}
# >> 3.2 mEq/L    17 mg/dL    110 mEq/L    143 mEq/L    30.3 %    12.0 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM    WBC    12.0    Hct    30.3    Plt    100    Cr    0.9    Glucose    109    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:128/268, Alk Phos /    T Bili:76/3.4, Lactic Acid:1.6 mmol/L, LDH:202 IU/L, Ca++:7.3 mg/dL,    Mg++:1.7 mg/dL, PO4:2.9 mg/dL    Fluid analysis / Other labs: AG-9'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.6324555320336759
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding', 'Limb structure', 'Felis catus skin extract', 'Exanthema'}
# >> EXTREMITIES - WWP, no c/c/e, 2+ peripheral pulses    SKIN - no rashes or lesions    Labs / Radiology    100 K/uL'
# ----- Data j -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Not assessed'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Morning After'}
# >> UOP dropped off early this    AM, but has improved this morning.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> Review of systems:    Flowsheet Data as of  [**2157-2-2**]  01:36 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since  [**58**]  AM'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Morning After'}
# >> UOP dropped off early this    AM, but has improved this morning.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Already on antibiotics for    .'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Morning After'}
# >> UOP dropped off early this    AM, but has improved this morning.'
# ----- Data j -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Morning After'}
# >>    Nutrition: NPO through to this morning'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Antibiotics as above    #.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> Review of systems:    Flowsheet Data as of  [**2157-2-2**]  01:36 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since  [**58**]  AM'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Antibiotics as above    #.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Aspiration-action', 'Americium'}
# >> Single episode of desaturation concerning for possible    aspiration, check CXR in AM and continue broad abx as above.'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Antibiotics as above    #.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Already on antibiotics for    .'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> - CXR in AM    - Antibiotics as above    #.'
# ----- Data j -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Morning After'}
# >> UOP dropped off early this    AM, but has improved this morning.'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.6497862896539307
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 24 (12 - 24) insp/min    SpO2: 98%    Heart rhythm: SB (Sinus Bradycardia)              Total In:                                                                     563 mL                                                                   1,051 mL    PO:              TF:    IVF:                                                                     563 mL                                                                   1,051 mL    Blood products:    Total out:                                                                     160 mL                                                                     475 mL    Urine:                                                                     160 mL                                                                     475 mL    NG:    Stool:    Drains:    Balance:                                                                     403 mL                                                                     576 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 98%'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'nicotinamide adenine dinucleotide (NAD)', 'Refractory anemias', 'nitroglycerin', 'Uridine', 'Structure of palpebral conjunctiva', 'Lung', 'Felis catus skin extract', 'Drainage procedure', 'Heart', 'heptaarginine amide', 'Systane Balance', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Icterus', 'Comfortis', 'Neck of urinary bladder', 'Blood product'}
# >>    BP: 106/36(54) {106/30(48) - 156/58(79)} mmHg', "   RR: 18 (15 - 21) insp/min    SpO2: 97%    Heart rhythm: SB (Sinus Bradycardia)              Total In:                                                                     563 mL                                                                     351 mL    PO:              TF:    IVF:                                                                     563 mL                                                                     351 mL    Blood products:    Total out:                                                                     160 mL                                                                     390 mL    Urine:                                                                     160 mL                                                                     390 mL    NG:    Stool:    Drains:    Balance:                                                                     403 mL                                                                     -39 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 97%    Physical Examination    VITAL SIGNS - Temp 97.8 F, BP 108/30 mmHg, HR 78 BPM, RR 14 X', O2-sat    93% RA    GENERAL - well-appearing woman in NAD, comfortable, appropriate,    jaundiced (skin, mouth, conjuntiva)    HEENT - NC/AT, PERRLA, EOMI, sclerae icteric, MMM, OP clear    NECK - supple, no thyromegaly, no JVD, no carotid bruits    LUNGS - CTA bilat, no r/rh/wh, good air movement, resp unlabored, no    accessory muscle use    HEART - PMI non-displaced, RRR, no MRG, nl S1-S2    ABDOMEN - NABS, soft/NT/ND, no masses or HSM, no rebound/guarding."
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 24 (12 - 24) insp/min    SpO2: 98%    Heart rhythm: SB (Sinus Bradycardia)              Total In:                                                                     563 mL                                                                   1,051 mL    PO:              TF:    IVF:                                                                     563 mL                                                                   1,051 mL    Blood products:    Total out:                                                                     160 mL                                                                     475 mL    Urine:                                                                     160 mL                                                                     475 mL    NG:    Stool:    Drains:    Balance:                                                                     403 mL                                                                     576 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 98%'
# ----- Data j -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 15 (12 - 24) insp/min    SpO2: 98%    Heart rhythm: SB (Sinus Bradycardia)              Total In:                                                                     564 mL                                                                   1,915 mL    PO:              TF:    IVF:                                                                     564 mL                                                                   1,915 mL    Blood products:    Total out:                                                                     160 mL                                                                     545 mL    Urine:                                                                     160 mL                                                                     545 mL    NG:    Stool:    Drains:    Balance:                                                                     404 mL                                                                   1,370 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 98%'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 0.8894991799933215
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'NIFEdipine', 'nifedipine', 'Holding patient', 'Lisinopril', 'Atenolol', 'atenolol', 'lisinopril'}
# >> - Holding Atenolol, Lisinopril and Nifedipine for now given tenuous UOP    - Will restart when UOP improves    #.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'NIFEdipine', 'nifedipine', 'Lisinopril', 'Americium', 'Atenolol', 'atenolol', 'lisinopril'}
# >> - Hold Atenolol, Lisinopril and nifedipine until able to assess BP    trend    -  [**Month (only) 8**]  restart in AM    .'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Bacteremia', 'Leukocytosis', 'Morning After'}
# >> Leukocytosis:  Downtrending to 12.6 this morning, likely  [**12-21**]     bacteremia.'
# ----- Data j -----
# >> Time: 2157-02-02 10:02:00
# >> Type: sentence
# >> Concepts: {'Morning After'}
# >>    Nutrition: NPO through to this morning'
# **********************************
# ***** PAIR INDEX 45 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Bacteremia', 'Leukocytosis', 'Morning After'}
# >> Leukocytosis:  Downtrending to 12.6 this morning, likely  [**12-21**]     bacteremia.'
# ----- Data j -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Morning After'}
# >> UOP dropped off early this    AM, but has improved this morning.'
# **********************************
# ***** PAIR INDEX 46 *****
# Cosine similarity: 0.5345224838248488
# ----- Data i -----
# >> Time: 2157-02-02 07:51:00
# >> Type: sentence
# >> Concepts: {'hepatitis serology', 'Excision', 'Sphincterotomy', 'aspirin', 'Papain', 'Blood culture', 'morphine', 'Infantile Neuroaxonal Dystrophy', 'Let Me Clarify', 'Morphine'}
# >> - F/U blood culture speciation/sensitivities    - Continue Zosyn 4.5mg q8 hrs (will need ID aproval), day 2    - Trend LFTs    - Hold ASA for possible sphincterotomy later this week as well as stent    & stone removal    - F/u hepatitis serologies    - follow UOP closely, bolus PRN    - Morphine PRN:pain    - Clarify plan for stone/stent removal with ERCP    #.'
# ----- Data j -----
# >> Time: 2157-02-02 01:37:00
# >> Type: sentence
# >> Concepts: {'hepatitis serology', 'Blood culture', 'Americium', 'Sphincterotomy', 'aspirin'}
# ...
# >> 3.7 mEq/L    17 mg/dL    114 mEq/L    142 mEq/L    30.2 %    8.6 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM                               [**2157-2-2**]   02:13 PM                               [**2157-2-3**]   03:12 AM    WBC    12.0    9.2    8.6    Hct    30.3    31.8    30.2    Plt    100    88    83    Cr    0.9    0.9    0.8    Glucose    109    89    80    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:51/120, Alk Phos /    T Bili:65/1.5, Amylase / Lipase:44/14, Fibrinogen:239 mg/dL, Lactic    Acid:1.6 mmol/L, Albumin:2.8 g/dL, LDH:170 IU/L, Ca++:6.8 mg/dL,    Mg++:1.6 mg/dL, PO4:3.0 mg/dL'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Amylases', 'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Lipase', 'glucose', 'Fibrinogen', 'amylase'}
# >> 3.7 mEq/L    17 mg/dL    114 mEq/L    142 mEq/L    30.2 %    8.6 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM                               [**2157-2-2**]   02:13 PM                               [**2157-2-3**]   03:12 AM    WBC    12.0    9.2    8.6    Hct    30.3    31.8    30.2    Plt    100    88    83    Cr    0.9    0.9    0.8    Glucose    109    89    80    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:51/120, Alk Phos /    T Bili:65/1.5, Amylase / Lipase:44/14, Fibrinogen:239 mg/dL, Lactic    Acid:1.6 mmol/L, Albumin:2.8 g/dL, LDH:170 IU/L, Ca++:6.8 mg/dL,    Mg++:1.6 mg/dL, PO4:3.0 mg/dL'
# **********************************
# ***** PAIR INDEX 105 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Lasix'}
# >> Given    another 10 IV lasix and nebs.'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Lasix'}
# >> Lasix was required with increased respiratory distress and improved    urine flow seen in that setting.'
# **********************************
# ***** PAIR INDEX 106 *****
# Cosine similarity: 0.6882472016116852
# ----- Data i -----
# >> Time: 2157-02-03 00:00:00
# >> Type: prescription
# >> Concepts: {'piperacillin-tazobactam combination', 'Piperacillin / tazobactam'}
# >> Patient was prescribed Piperacillin-Tazobactam 4.5 g Frozen Bag IV of total 4.5 g
# ----- Data j -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Piperacillin / tazobactam', 'metronidazole', 'Metronidazole', 'Pharmaceutical Preparations', 'piperacillin-tazobactam combination', 'Lasix', 'Infusion procedures'}
# >> Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Metronidazole -  [**2157-2-2**]  02:00 AM    Vancomycin -  [**2157-2-2**]  09:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-3**]  03:45 AM    Infusions:    Other ICU medications:    Furosemide (Lasix) -  [**2157-2-2**]  07:24 PM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-3**]  07:45 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM'
# **********************************
# ***** PAIR INDEX 107 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Limb structure'}
# >>    Extremities: Right lower extremity edema: Trace, Left lower extremity    edema: Trace'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Ear structure', 'Nose', 'Pharyngeal structure'}
# >>    General Appearance: Thin    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 108 *****
# Cosine similarity: 0.6324555320336758
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding', 'Limb structure'}
# >> EXTREMITIES - WWP, no c/c/e, 2+ peripheral pulses (radials, DPs)    Labs / Radiology    83 K/uL'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Limb structure'}
# >>    Extremities: Right lower extremity edema: Trace, Left lower extremity    edema: Trace'
# **********************************
# ***** PAIR INDEX 109 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'cyclophosphamide/prednisone/vincristine protocol', 'Blood product'}
# >>     CVP: 14 (11 - 14)mmHg    Total In:                                                                   6,701 mL                                                                     434 mL    PO:                                                                      60 mL    TF:    IVF:                                                                   6,641 mL                                                                     434 mL    Blood products:    Total out:                                                                   1,445 mL                                                                     650 mL    Urine:                                                                   1,445 mL                                                                     650 mL    NG:    Stool:    Drains:    Balance:                                                                   5,256 mL                                                                    -216 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 96%'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'cyclophosphamide/prednisone/vincristine protocol', 'Blood product'}
# >>    CVP: 14 (11 - 14)mmHg    Total In:                                                                   6,701 mL                                                                     481 mL    PO:                                                                      60 mL    TF:    IVF:                                                                   6,641 mL                                                                     481 mL    Blood products:    Total out:                                                                   1,445 mL                                                                   1,070 mL    Urine:                                                                   1,445 mL                                                                   1,070 mL    NG:    Stool:    Drains:    Balance:                                                                   5,256 mL                                                                    -589 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 94%'
# **********************************
# ***** PAIR INDEX 110 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Imaging Techniques', 'Americium'}
# >>    Imaging: CXR this AM pending upload.'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Imaging Techniques'}
# >>    Imaging: CXR-Obvious new right sided pleural effusion of likely    moderate size'
# **********************************
# ***** PAIR INDEX 111 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Amylases', 'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Lipase', 'glucose', 'Fibrinogen', 'amylase'}
# >> 3.7 mEq/L    17 mg/dL    114 mEq/L    142 mEq/L    30.2 %    8.6 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM                               [**2157-2-2**]   02:13 PM                               [**2157-2-3**]   03:12 AM    WBC    12.0    9.2    8.6    Hct    30.3    31.8    30.2    Plt    100    88    83    Cr    0.9    0.9    0.8    Glucose    109    89    80    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:51/120, Alk Phos /    T Bili:65/1.5, Amylase / Lipase:44/14, Fibrinogen:239 mg/dL, Lactic    Acid:1.6 mmol/L, Albumin:2.8 g/dL, LDH:170 IU/L, Ca++:6.8 mg/dL,    Mg++:1.6 mg/dL, PO4:3.0 mg/dL'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Amylases', 'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Lipase', 'glucose', 'Fibrinogen', 'amylase'}
# >> 3.7 mEq/L    17 mg/dL    114 mEq/L    142 mEq/L    30.2 %    8.6 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM                               [**2157-2-2**]   02:13 PM                               [**2157-2-3**]   03:12 AM    WBC    12.0    9.2    8.6    Hct    30.3    31.8    30.2    Plt    100    88    83    Cr    0.9    0.9    0.8    Glucose    109    89    80    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:51/120, Alk Phos /    T Bili:65/1.5, Amylase / Lipase:44/14, Fibrinogen:239 mg/dL, Lactic    Acid:1.6 mmol/L, Albumin:2.8 g/dL, LDH:170 IU/L, Ca++:6.8 mg/dL,    Mg++:1.6 mg/dL, PO4:3.0 mg/dL'
# **********************************
# ***** PAIR INDEX 112 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Amylases', 'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Lipase', 'glucose', 'Fibrinogen', 'amylase'}
# >> 3.7 mEq/L    17 mg/dL    114 mEq/L    142 mEq/L    30.2 %    8.6 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM                               [**2157-2-2**]   02:13 PM                               [**2157-2-3**]   03:12 AM    WBC    12.0    9.2    8.6    Hct    30.3    31.8    30.2    Plt    100    88    83    Cr    0.9    0.9    0.8    Glucose    109    89    80    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:51/120, Alk Phos /    T Bili:65/1.5, Amylase / Lipase:44/14, Fibrinogen:239 mg/dL, Lactic    Acid:1.6 mmol/L, Albumin:2.8 g/dL, LDH:170 IU/L, Ca++:6.8 mg/dL,    Mg++:1.6 mg/dL, PO4:3.0 mg/dL'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Glucose', 'Laboratory test finding', 'Prothrombin time assay', 'Amylases', 'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lactic acid', 'Lipase', 'glucose', 'Fibrinogen', 'amylase'}
# >> 3.7 mEq/L    17 mg/dL    114 mEq/L    142 mEq/L    30.2 %    8.6 K/uL         [image002.jpg]                               [**2157-2-2**]   04:53 AM                               [**2157-2-2**]   02:13 PM                               [**2157-2-3**]   03:12 AM    WBC    12.0    9.2    8.6    Hct    30.3    31.8    30.2    Plt    100    88    83    Cr    0.9    0.9    0.8    Glucose    109    89    80    Other labs: PT / PTT / INR:15.7/35.5/1.4, ALT / AST:51/120, Alk Phos /    T Bili:65/1.5, Amylase / Lipase:44/14, Fibrinogen:239 mg/dL, Lactic    Acid:1.6 mmol/L, Albumin:2.8 g/dL, LDH:170 IU/L, Ca++:6.8 mg/dL,    Mg++:1.6 mg/dL, PO4:3.0 mg/dL'
# **********************************
# ***** PAIR INDEX 113 *****
# Cosine similarity: 0.7745966692414835
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding', 'Limb structure'}
# >> EXTREMITIES - WWP, no c/c/e, 2+ peripheral pulses (radials, DPs)    Labs / Radiology    83 K/uL'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: Attentive, Follows simple commands, Responds to: Verbal    stimuli, Movement: Not assessed, Tone: Not assessed    Labs / Radiology'
# **********************************
# ***** PAIR INDEX 114 *****
# Cosine similarity: 0.6666666666666669
# ----- Data i -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Electrocardiography'}
# >> HPI:    24 Hour Events:  EKG - At  [**2157-2-2**]  07:39 PM    -Patient with mild increase in respiratory distress noted    -CVP at 12-13    -Some modest improvement in urine output seen across the evening.'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Lasix'}
# >> Lasix was required with increased respiratory distress and improved    urine flow seen in that setting.'
# **********************************
# ***** PAIR INDEX 115 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2157-02-03 07:46:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'cyclophosphamide/prednisone/vincristine protocol', 'Blood product'}
# >>     CVP: 14 (11 - 14)mmHg    Total In:                                                                   6,701 mL                                                                     434 mL    PO:                                                                      60 mL    TF:    IVF:                                                                   6,641 mL                                                                     434 mL    Blood products:    Total out:                                                                   1,445 mL                                                                     650 mL    Urine:                                                                   1,445 mL                                                                     650 mL    NG:    Stool:    Drains:    Balance:                                                                   5,256 mL                                                                    -216 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 96%'
# ----- Data j -----
# >> Time: 2157-02-03 10:29:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'cyclophosphamide/prednisone/vincristine protocol', 'Blood product'}
# >>    CVP: 14 (11 - 14)mmHg    Total In:                                                                   6,701 mL                                                                     481 mL    PO:                                                                      60 mL    TF:    IVF:                                                                   6,641 mL                                                                     481 mL    Blood products:    Total out:                                                                   1,445 mL                                                                   1,070 mL    Urine:                                                                   1,445 mL                                                                   1,070 mL    NG:    Stool:    Drains:    Balance:                                                                   5,256 mL                                                                    -589 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 94%'
# **********************************
# ********** Processing data for 2157-02-04 **********
# ********** Processing data for 2157-02-05 **********
# ********** Processing data for 2157-02-06 **********
# ********** Processing data for 2157-02-07 **********
# ********** Processing data for 2157-02-08 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                            sentence 1  \
# 48  Patient was prescribed Piperacillin-Tazobactam 4.5 g Frozen Bag IV of total 4.5 g
# 49  Patient was prescribed Acetaminophen 325mg Tablet PO/NG of total 325-650 mg
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    sentence 2  \
# 48  ['Chief Complaint:', "24 Hour Events:    - ERCP performed    - Blood cultures returned GNR's    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Vancomycin -  [**2157-2-2**]  12:50 AM    Metronidazole -  [**2157-2-2**]  02:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-2**]  03:38 AM    Infusions:    Other ICU medications:    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-2**]  07:50 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM"
# 49  Acetaminophen level was negative.'
#
#        time 1              time 2        type 1    type 2  \
# 48 2157-02-02 2157-02-02 07:51:00  prescription  sentence
# 49 2157-02-02 2157-02-02 01:37:00  prescription  sentence
#
#                                                           concepts 1  \
# 48  {piperacillin-tazobactam combination, Piperacillin / tazobactam}
# 49  {acetaminophen, Acetaminophen}
#
#                                                                                                                                                                     concepts 2  \
# 48  {metronidazole, Metronidazole, Blood culture, piperacillin-tazobactam combination, Americium, Pharmaceutical Preparations, Piperacillin / tazobactam, Infusion procedures}
# 49  {acetaminophen, Acetaminophen}
#
#    cosine similarity            semantic type
# 48  0.67082           Pharmacologic Substance
# 49  1.0               Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                             sentence 1  \
# 48   Patient was prescribed Piperacillin-Tazobactam 4.5 g Frozen Bag IV of total 4.5 g
# 49   Patient was prescribed Acetaminophen 325mg Tablet PO/NG of total 325-650 mg
# 50   Patient was prescribed Atenolol 50 mg Tab PO/NG of total 75 mg
# 51   Patient was prescribed Atenolol 50 mg Tab PO/NG of total 75 mg
# 52   Patient was prescribed Piperacillin-Tazobactam 4.5 g Vial IV of total 4.5 gm
# 53   Patient was prescribed Piperacillin-Tazobactam 4.5 g Vial IV of total 4.5 gm
# 75   Patient was prescribed Piperacillin-Tazobactam 4.5 g Vial IV of total 4.5 gm
# 76   Patient was prescribed Piperacillin-Tazobactam 4.5 g Vial IV of total 4.5 gm
# 106  Patient was prescribed Piperacillin-Tazobactam 4.5 g Frozen Bag IV of total 4.5 g
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     sentence 2  \
# 48   ['Chief Complaint:', "24 Hour Events:    - ERCP performed    - Blood cultures returned GNR's    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Vancomycin -  [**2157-2-2**]  12:50 AM    Metronidazole -  [**2157-2-2**]  02:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-2**]  03:38 AM    Infusions:    Other ICU medications:    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-2**]  07:50 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM"
# 49   Acetaminophen level was negative.'
# 50   - Hold Atenolol, Lisinopril and nifedipine until able to assess BP    trend    -  [**Month (only) 8**]  restart in AM    .'
# 51   - Holding Atenolol, Lisinopril and Nifedipine for now given tenuous UOP    - Will restart when UOP improves    #.'
# 52   ['Chief Complaint:', "24 Hour Events:    - ERCP performed    - Blood cultures returned GNR's    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Vancomycin -  [**2157-2-2**]  12:50 AM    Metronidazole -  [**2157-2-2**]  02:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-2**]  03:38 AM    Infusions:    Other ICU medications:    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-2**]  07:50 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM"
# 53   ['Chief Complaint:', "24 Hour Events:    - ERCP performed    - Blood cultures returned GNR's    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Vancomycin -  [**2157-2-2**]  12:50 AM    Metronidazole -  [**2157-2-2**]  02:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-2**]  03:38 AM    Infusions:    Other ICU medications:    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-2**]  07:50 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM"
# 75   ['Chief Complaint:', "24 Hour Events:    - ERCP performed    - Blood cultures returned GNR's    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Vancomycin -  [**2157-2-2**]  12:50 AM    Metronidazole -  [**2157-2-2**]  02:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-2**]  03:38 AM    Infusions:    Other ICU medications:    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-2**]  07:50 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM"
# 76   ['Chief Complaint:', "24 Hour Events:    - ERCP performed    - Blood cultures returned GNR's    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Vancomycin -  [**2157-2-2**]  12:50 AM    Metronidazole -  [**2157-2-2**]  02:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-2**]  03:38 AM    Infusions:    Other ICU medications:    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-2**]  07:50 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM"
# 106  Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Metronidazole -  [**2157-2-2**]  02:00 AM    Vancomycin -  [**2157-2-2**]  09:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-3**]  03:45 AM    Infusions:    Other ICU medications:    Furosemide (Lasix) -  [**2157-2-2**]  07:24 PM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-3**]  07:45 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM'
#
#         time 1              time 2        type 1    type 2  \
# 48  2157-02-02 2157-02-02 07:51:00  prescription  sentence
# 49  2157-02-02 2157-02-02 01:37:00  prescription  sentence
# 50  2157-02-02 2157-02-02 01:37:00  prescription  sentence
# 51  2157-02-02 2157-02-02 07:51:00  prescription  sentence
# 52  2157-02-02 2157-02-02 07:51:00  prescription  sentence
# 53  2157-02-02 2157-02-02 07:51:00  prescription  sentence
# 75  2157-02-02 2157-02-02 07:51:00  prescription  sentence
# 76  2157-02-02 2157-02-02 07:51:00  prescription  sentence
# 106 2157-02-03 2157-02-03 07:46:00  prescription  sentence
#
#                                                                                             concepts 1  \
# 48   {piperacillin-tazobactam combination, Piperacillin / tazobactam}
# 49   {acetaminophen, Acetaminophen}
# 50   {atenolol, Atenolol}
# 51   {atenolol, Atenolol}
# 52   {Intravenous infusion procedures, piperacillin-tazobactam combination, Piperacillin / tazobactam}
# 53   {Intravenous infusion procedures, piperacillin-tazobactam combination, Piperacillin / tazobactam}
# 75   {Intravenous infusion procedures, piperacillin-tazobactam combination, Piperacillin / tazobactam}
# 76   {Intravenous infusion procedures, piperacillin-tazobactam combination, Piperacillin / tazobactam}
# 106  {piperacillin-tazobactam combination, Piperacillin / tazobactam}
#
#                                                                                                                                                                      concepts 2  \
# 48   {metronidazole, Metronidazole, Blood culture, piperacillin-tazobactam combination, Americium, Pharmaceutical Preparations, Piperacillin / tazobactam, Infusion procedures}
# 49   {acetaminophen, Acetaminophen}
# 50   {NIFEdipine, nifedipine, Lisinopril, Americium, Atenolol, atenolol, lisinopril}
# 51   {NIFEdipine, nifedipine, Holding patient, Lisinopril, Atenolol, atenolol, lisinopril}
# 52   {metronidazole, Metronidazole, Blood culture, piperacillin-tazobactam combination, Americium, Pharmaceutical Preparations, Piperacillin / tazobactam, Infusion procedures}
# 53   {metronidazole, Metronidazole, Blood culture, piperacillin-tazobactam combination, Americium, Pharmaceutical Preparations, Piperacillin / tazobactam, Infusion procedures}
# 75   {metronidazole, Metronidazole, Blood culture, piperacillin-tazobactam combination, Americium, Pharmaceutical Preparations, Piperacillin / tazobactam, Infusion procedures}
# 76   {metronidazole, Metronidazole, Blood culture, piperacillin-tazobactam combination, Americium, Pharmaceutical Preparations, Piperacillin / tazobactam, Infusion procedures}
# 106  {Americium, Piperacillin / tazobactam, metronidazole, Metronidazole, Pharmaceutical Preparations, piperacillin-tazobactam combination, Lasix, Infusion procedures}
#
#     cosine similarity                        semantic type
# 48   0.67082           Pharmacologic Substance
# 49   1.0               Pharmacologic Substance
# 50   0.5547            Pharmacologic Substance
# 51   0.534522          Pharmacologic Substance
# 52   0.710047          Pharmacologic Substance
# 53   0.710047          Pharmacologic Substance
# 75   0.710047          Therapeutic or Preventive Procedure
# 76   0.710047          Therapeutic or Preventive Procedure
# 106  0.688247          Pharmacologic Substance

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 49
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "Acetaminophen not given."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Acetaminophen 325mg Tablet PO/NG of total 325-650 mg
# sentence 2:	Acetaminophen level was negative.'
#
# New contradicting sentence: Acetaminophen not given.

# %%
no_contradiction_pair_idx = [76]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed Piperacillin-Tazobactam 4.5 g Vial IV of total 4.5 gm
# sentence 2:	['Chief Complaint:', "24 Hour Events:    - ERCP performed    - Blood cultures returned GNR's    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Vancomycin -  [**2157-2-2**]  12:50 AM    Metronidazole -  [**2157-2-2**]  02:00 AM    Piperacillin/Tazobactam (Zosyn) -  [**2157-2-2**]  03:38 AM    Infusions:    Other ICU medications:    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2157-2-2**]  07:50 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since  [**58**]  AM"
# *****************************

# %% [markdown]
# ## Patient 5

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[4] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 186291
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2151-09-21 **********
# ********** Processing data for 2151-09-22 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.7385489458759966
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.5222329678670936
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.6092717958449424
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Excision', 'Papain', 'ileum', 'Antiretroviral Therapy, Highly Active', 'Pharmaceutical Preparations', 'Hypertensive disease', 'Resectisol', 'Infusion procedures'}
# >> Patient admitted from:  [**Hospital1 54**]  ER    History obtained from  [**Hospital 85**]  Medical records    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Other medications:    Past medical history:    Family history:    Social History:    HIV --> HAART; most recent CD4 count= 307    COPD, severe    HTN --> doxizocin    CRI    BACK PAIN, chronic --> narcotics    h/o SBO --> s/p partial resection of ileum  [**2136**]     HOMOCYSTEINURIA    GRANULOMATOUS DISEASE    GERD    Non-contributory'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.5000000000000001
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Ehlers-Danlos Syndrome, Type IV'}
# >> COntrol with iv meds,    and resume PO meds as tolerates.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.5477225575051662
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his /    her note above, including assessment and plan.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Imaging Techniques', 'Hypertet', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Constipation', 'Commit Lozenge'}
# >>    Imaging: CXR ( [**2151-9-21**] ) no acute infiltrates    Assessment and Plan    NAUSEA, VOMMITTING -- unclear etiology; unclear if preceeded    hypertension or whether hypertension is cause or contibuting;  Chronic    constipation may also be contributing (and evidence radiographically).'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 0.6837634587578276
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.9258200997725515
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.6546536707079772
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.5640760748177661
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Excision', 'Papain', 'ileum', 'Antiretroviral Therapy, Highly Active', 'Pharmaceutical Preparations', 'Hypertensive disease', 'Resectisol', 'Infusion procedures'}
# >> Patient admitted from:  [**Hospital1 54**]  ER    History obtained from  [**Hospital 85**]  Medical records    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Other medications:    Past medical history:    Family history:    Social History:    HIV --> HAART; most recent CD4 count= 307    COPD, severe    HTN --> doxizocin    CRI    BACK PAIN, chronic --> narcotics    h/o SBO --> s/p partial resection of ileum  [**2136**]     HOMOCYSTEINURIA    GRANULOMATOUS DISEASE    GERD    Non-contributory'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.5832118435198043
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pain management', 'Iron deficiency', 'Homocysteinemia', 'Gingi Med', 'Chronic back pain', 'Medicone Hemorrhoidal', 'Truvada', 'colonoscopy', 'Gastroesophageal reflux disease', 'Oxygen', 'Ritonavir', 'ritonavir', 'Hypertensive disease', 'Injection of therapeutic agent', 'Acquired Immunodeficiency Syndrome'}
# >> PMH:    - HIV/AIDS: CD4: 307( [**2151-9-10**] ) VL: 187 ( [**2151-9-15**] )- recently started on    Truvada and Ritonavir    - COPD: severe, on 2L oxygen at home, followed by Dr.  [**Last Name (STitle) **] , last    spirometry  [**7-26**]     - GERD    - HTN    - CRI    - h/o GI bleed    - h/o internal hemorrhoids, grade I on colonoscopy  [**2149**]     - Leukopenia    - Iron deficiency Anemia    - Inguinal hernia    - Homocysteinemia    - Chronic back pain- failed spinal cord stimulator, requires injections    from pain management.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.5399492471560389
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pain management', 'Iron deficiency', 'Homocysteinemia', 'Gingi Med', 'Chronic back pain', 'Medicone Hemorrhoidal', 'Truvada', 'colonoscopy', 'Gastroesophageal reflux disease', 'Oxygen', 'Ritonavir', 'ritonavir', 'Hypertensive disease', 'Injection of therapeutic agent', 'Acquired Immunodeficiency Syndrome'}
# >> PMH:    - HIV/AIDS: CD4: 307( [**2151-9-10**] ) VL: 187 ( [**2151-9-15**] )- recently started on    Truvada and Ritonavir    - COPD: severe, on 2L oxygen at home, followed by Dr.  [**Last Name (STitle) **] , last    spirometry  [**7-26**]     - GERD    - HTN    - CRI    - h/o GI bleed    - h/o internal hemorrhoids, grade I on colonoscopy  [**2149**]     - Leukopenia    - Iron deficiency Anemia    - Inguinal hernia    - Homocysteinemia    - Chronic back pain- failed spinal cord stimulator, requires injections    from pain management.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.6123724356957946
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Pred Mild', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Abdominal Pain'}
# >> Plan:    # Nausea w/emesis: c/b mild, diffuse abdominal pain.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his /    her note above, including assessment and plan.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.6689936080056728
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.7925939239012173
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.5604485383178051
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.5913123959890827
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Excision', 'Papain', 'ileum', 'Antiretroviral Therapy, Highly Active', 'Pharmaceutical Preparations', 'Hypertensive disease', 'Resectisol', 'Infusion procedures'}
# >> Patient admitted from:  [**Hospital1 54**]  ER    History obtained from  [**Hospital 85**]  Medical records    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Other medications:    Past medical history:    Family history:    Social History:    HIV --> HAART; most recent CD4 count= 307    COPD, severe    HTN --> doxizocin    CRI    BACK PAIN, chronic --> narcotics    h/o SBO --> s/p partial resection of ileum  [**2136**]     HOMOCYSTEINURIA    GRANULOMATOUS DISEASE    GERD    Non-contributory'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 0.7337993857053426
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.588348405414552
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Hypertensive disease'}
# >> Sister: HTN'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 0.5943216388127455
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pain management', 'Iron deficiency', 'Homocysteinemia', 'Gingi Med', 'Chronic back pain', 'Medicone Hemorrhoidal', 'Truvada', 'colonoscopy', 'Gastroesophageal reflux disease', 'Oxygen', 'Ritonavir', 'ritonavir', 'Hypertensive disease', 'Injection of therapeutic agent', 'Acquired Immunodeficiency Syndrome'}
# >> PMH:    - HIV/AIDS: CD4: 307( [**2151-9-10**] ) VL: 187 ( [**2151-9-15**] )- recently started on    Truvada and Ritonavir    - COPD: severe, on 2L oxygen at home, followed by Dr.  [**Last Name (STitle) **] , last    spirometry  [**7-26**]     - GERD    - HTN    - CRI    - h/o GI bleed    - h/o internal hemorrhoids, grade I on colonoscopy  [**2149**]     - Leukopenia    - Iron deficiency Anemia    - Inguinal hernia    - Homocysteinemia    - Chronic back pain- failed spinal cord stimulator, requires injections    from pain management.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.6446583712203042
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.7637626158259735
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 0.5400617248673217
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.5698028822981898
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Excision', 'Papain', 'ileum', 'Antiretroviral Therapy, Highly Active', 'Pharmaceutical Preparations', 'Hypertensive disease', 'Resectisol', 'Infusion procedures'}
# >> Patient admitted from:  [**Hospital1 54**]  ER    History obtained from  [**Hospital 85**]  Medical records    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Other medications:    Past medical history:    Family history:    Social History:    HIV --> HAART; most recent CD4 count= 307    COPD, severe    HTN --> doxizocin    CRI    BACK PAIN, chronic --> narcotics    h/o SBO --> s/p partial resection of ileum  [**2136**]     HOMOCYSTEINURIA    GRANULOMATOUS DISEASE    GERD    Non-contributory'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.5669467095138409
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Hypertensive disease'}
# >> Sister: HTN'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.6108828386569699
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pain management', 'Iron deficiency', 'Homocysteinemia', 'Gingi Med', 'Chronic back pain', 'Medicone Hemorrhoidal', 'Truvada', 'colonoscopy', 'Gastroesophageal reflux disease', 'Oxygen', 'Ritonavir', 'ritonavir', 'Hypertensive disease', 'Injection of therapeutic agent', 'Acquired Immunodeficiency Syndrome'}
# >> PMH:    - HIV/AIDS: CD4: 307( [**2151-9-10**] ) VL: 187 ( [**2151-9-15**] )- recently started on    Truvada and Ritonavir    - COPD: severe, on 2L oxygen at home, followed by Dr.  [**Last Name (STitle) **] , last    spirometry  [**7-26**]     - GERD    - HTN    - CRI    - h/o GI bleed    - h/o internal hemorrhoids, grade I on colonoscopy  [**2149**]     - Leukopenia    - Iron deficiency Anemia    - Inguinal hernia    - Homocysteinemia    - Chronic back pain- failed spinal cord stimulator, requires injections    from pain management.'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.8153742483272114
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Pancreatitis', 'Pancreatin'}
# >> He does not have lab evidence of pancreatitis, but does have    h/o gastritis.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Hepatitis', 'Pancreatitis', 'Pancreatin'}
# >> No evience for cholycystitis, hepatitis or    pancreatitis.'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.8980265101338747
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Structure of palpebral conjunctiva', 'Edema of sclera', 'Ear structure', 'Sus scrofa conjunctiva preparation', 'Nose', 'Pharyngeal structure', 'poor dentition', 'Eye', 'acute stress'}
# >>    General Appearance: No acute distress, Thin    Eyes / Conjunctiva: No(t) Sclera edema    Head, Ears, Nose, Throat: Normocephalic, Poor dentition'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Obesity', 'Sus scrofa conjunctiva preparation', 'Ear structure', 'acute stress'}
# >>    General Appearance: No(t) Well nourished, No acute distress, No(t)    Overweight / Obese, Thin, No(t) Anxious, No(t) Diaphoretic    Eyes / Conjunctiva: PERRL, No(t) Pupils dilated, No(t) Conjunctiva    pale, No(t) Sclera edema    Head, Ears, Nose, Throat: Normocephalic, No(t) Poor dentition, No(t)    Endotracheal tube, No(t) NG tube, No(t) OG tube'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.6123724356957946
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Pred Mild', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Abdominal Pain'}
# >> Plan:    # Nausea w/emesis: c/b mild, diffuse abdominal pain.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his /    her note above, including assessment and plan.'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.9999999999999999
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Pred Mild', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Abdominal Pain'}
# >> Plan:    # Nausea w/emesis: c/b mild, diffuse abdominal pain.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Pred Mild', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Abdominal Pain'}
# >> Plan:    # Nausea w/emesis: c/b mild, diffuse abdominal pain.'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Colitis', 'Diverticulitis', 'Abdominal Pain'}
# >> Abdominal pain is    concerning, possible pt has diverticulitis, colitis though no CT    evidence of bowel inflammation.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Colitis', 'Diverticulitis', 'Abdominal Pain'}
# >> Abdominal pain is    concerning, possible pt has diverticulitis, colitis though no CT    evidence of bowel inflammation.'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'heparin', 'albuterol', 'ranitidine', 'tiotropium', 'Hematocrit procedure', 'Iron deficiency anemia', 'Advair', 'Fertilization in Vitro', 'Albuterol', 'Ranitidine'}
# >> # COPD: severe, on 3 L oxygen outpt    - continue albuterol nebs, tiotropium, and Advair    # Iron deficiency anemia: unclear baseline HCT, appears to be b/w    34-38; guiac (-)    - continue iron supplementation    # FEN: NPO for now, IVF hydration    # Access: right fem line, trying  to place PIVs    # PPx: ranitidine, heparin sc    # Code: Full    # Dispo: ICU for now    # Comm: HCP, son,  [**First Name8 (NamePattern2) **]   [**First Name8 (NamePattern2) **]   [**Known lastname 6351**]   [**Telephone/Fax (1) 6352**]     ICU Care'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'heparin', 'albuterol', 'ranitidine', 'Doxazosin', 'tiotropium', 'doxazosin', 'hydralazine', 'Advair', 'hydrALAZINE', 'Fertilization in Vitro', 'Albuterol', 'Ranitidine'}
# >> - restart doxazosin    - hydralazine as needed for diastolic >100    - continue to monitor    # COPD: severe, on 3 L oxygen outpt    - continue albuterol nebs, tiotropium, and Advair    # FEN: NPO for now, IVF hydration    # Access: right fem line, try to place PIVs    # PPx: ranitidine, heparin sc    # Code: Full    # Dispo: ICU for now,    # Comm: HCP, son,  [**First Name8 (NamePattern2) **]   [**First Name8 (NamePattern2) **]   [**Known lastname 6351**]   [**Telephone/Fax (1) 6352**]']
#
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.9999999999999999
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'labetalol', 'All Clear', 'Blood Stop', 'Labetalol', 'Hypertensive disease'}
# >> - u/a negative    - blood cx pending    - CXR clear and no sx of PNA/bronchitis    - f/u cx and final CT read    - monitor for now, hold on Abx    # HTN: hypertensive urgency in the ED; currently well controlled w/dose    of labetalol he received in the ED.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'labetalol', 'All Clear', 'Blood Stop', 'Labetalol', 'Hypertensive disease'}
# >> - u/a negative    - blood cx pending    - CXR clear and no sx of PNA/bronchitis    - f/u cx and final CT read    - monitor for now, hold on Abx    # HTN: hypertensive urgency in the ED; currently well controlled w/dose    of labetalol he received in the ED.'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 0.6446583712203042
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.7637626158259735
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses'}
# >> COPD -- no evidence for significant COPD exacerbation.'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 0.5400617248673217
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.5698028822981898
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Excision', 'Papain', 'ileum', 'Antiretroviral Therapy, Highly Active', 'Pharmaceutical Preparations', 'Hypertensive disease', 'Resectisol', 'Infusion procedures'}
# >> Patient admitted from:  [**Hospital1 54**]  ER    History obtained from  [**Hospital 85**]  Medical records    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Other medications:    Past medical history:    Family history:    Social History:    HIV --> HAART; most recent CD4 count= 307    COPD, severe    HTN --> doxizocin    CRI    BACK PAIN, chronic --> narcotics    h/o SBO --> s/p partial resection of ileum  [**2136**]     HOMOCYSTEINURIA    GRANULOMATOUS DISEASE    GERD    Non-contributory'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Diagnosis'}
# >> Diagnosis: COPD Length of need - one year.'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 0.5669467095138409
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Hypertensive disease'}
# >> Sister: HTN'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.6108828386569699
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pain management', 'Iron deficiency', 'Homocysteinemia', 'Gingi Med', 'Chronic back pain', 'Medicone Hemorrhoidal', 'Truvada', 'colonoscopy', 'Gastroesophageal reflux disease', 'Oxygen', 'Ritonavir', 'ritonavir', 'Hypertensive disease', 'Injection of therapeutic agent', 'Acquired Immunodeficiency Syndrome'}
# >> PMH:    - HIV/AIDS: CD4: 307( [**2151-9-10**] ) VL: 187 ( [**2151-9-15**] )- recently started on    Truvada and Ritonavir    - COPD: severe, on 2L oxygen at home, followed by Dr.  [**Last Name (STitle) **] , last    spirometry  [**7-26**]     - GERD    - HTN    - CRI    - h/o GI bleed    - h/o internal hemorrhoids, grade I on colonoscopy  [**2149**]     - Leukopenia    - Iron deficiency Anemia    - Inguinal hernia    - Homocysteinemia    - Chronic back pain- failed spinal cord stimulator, requires injections    from pain management.'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.8153742483272114
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Pancreatitis', 'Pancreatin'}
# >> He does not have lab evidence of pancreatitis, but does have    h/o gastritis.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Hepatitis', 'Pancreatitis', 'Pancreatin'}
# >> No evience for cholycystitis, hepatitis or    pancreatitis.'
# **********************************
# ***** PAIR INDEX 45 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Pancreatitis', 'Pancreatin'}
# >> He does not have lab evidence of pancreatitis, but does have    h/o gastritis.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Pancreatitis', 'Pancreatin'}
# >> He does not have lab evidence of pancreatitis, but does have    h/o gastritis.'
# **********************************
# ***** PAIR INDEX 46 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Warm, No(t) Rash: , No(t) Jaundice'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Arthralgia'}
# >>    Musculoskeletal: No(t) Joint pain, No(t) Myalgias    Integumentary (skin): No(t) Jaundice, No(t) Rash'
# **********************************
# ***** PAIR INDEX 47 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >>    Drugs: Remote'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'Hypertet'}
# >> HYPERTENSION -- unclear whether due to consequence of poor PO intake    (medications) or primary problem.'
# **********************************
# ***** PAIR INDEX 48 *****
# Cosine similarity: 0.5163977794943223
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 20 (16 - 20) insp/min    SpO2: 98%    Heart rhythm: SR (Sinus Rhythm)              Total In:              243 mL    PO:              100 mL    TF:    IVF:    143 mL    Blood products:    Total out:                                                                       0 mL                                                                     500 mL    Urine:    100 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                    -257 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 98%'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Blood Stop', 'Uridine'}
# >> Cultures obtained (including blood, stool, urine).'
# **********************************
# ***** PAIR INDEX 49 *****
# Cosine similarity: 0.5222329678670936
# ----- Data i -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Microbicides'}
# >> Continue usual    meds, and low threshold for antimicrobials if evidence for COPD    exacerbation.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ...
# >>    General Appearance: No acute distress, Thin    Eyes / Conjunctiva: No(t) Sclera edema    Head, Ears, Nose, Throat: Normocephalic, Poor dentition'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Obesity', 'Sus scrofa conjunctiva preparation', 'Ear structure', 'acute stress'}
# >>    General Appearance: No(t) Well nourished, No acute distress, No(t)    Overweight / Obese, Thin, No(t) Anxious, No(t) Diaphoretic    Eyes / Conjunctiva: PERRL, No(t) Pupils dilated, No(t) Conjunctiva    pale, No(t) Sclera edema    Head, Ears, Nose, Throat: Normocephalic, No(t) Poor dentition, No(t)    Endotracheal tube, No(t) NG tube, No(t) OG tube'
# **********************************
# ***** PAIR INDEX 153 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Nausea', 'Abdominal Pain'}
# >>    Gastrointestinal: Abdominal pain, Nausea, No(t) Emesis, Constipation    Integumentary (skin): No(t) Rash'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Constipation', 'Nausea', 'Vomiting', 'Abdominal Pain'}
# >>    Gastrointestinal: Abdominal pain, Nausea, Emesis, No(t) Diarrhea,    Constipation'
# **********************************
# ***** PAIR INDEX 154 *****
# Cosine similarity: 0.6761234037828131
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Nausea', 'Abdominal Pain'}
# >>    Gastrointestinal: Abdominal pain, Nausea, No(t) Emesis, Constipation    Integumentary (skin): No(t) Rash'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Arthralgia'}
# >>    Musculoskeletal: No(t) Joint pain, No(t) Myalgias    Integumentary (skin): No(t) Jaundice, No(t) Rash'
# **********************************
# ***** PAIR INDEX 155 *****
# Cosine similarity: 0.5714285714285713
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Nausea', 'Abdominal Pain'}
# >>    Gastrointestinal: Abdominal pain, Nausea, No(t) Emesis, Constipation    Integumentary (skin): No(t) Rash'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Icterus', 'Dermatitis', 'Cyanosis', 'Felis catus skin extract'}
# >>    SKIN: No jaundice, cyanosis, or gross dermatitis.'
# **********************************
# ***** PAIR INDEX 156 *****
# Cosine similarity: 0.5669467095138407
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Nausea', 'Abdominal Pain'}
# >>    Gastrointestinal: Abdominal pain, Nausea, No(t) Emesis, Constipation    Integumentary (skin): No(t) Rash'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Nausea', 'Constipation', 'Abdominal Pain'}
# >> He feels that his nausea and abdominal pain is c/w    severe constipation, "I know it\'s my constipation."'
# **********************************
# ***** PAIR INDEX 157 *****
# Cosine similarity: 0.5039526306789696
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Nausea', 'Abdominal Pain'}
# >>    Gastrointestinal: Abdominal pain, Nausea, No(t) Emesis, Constipation    Integumentary (skin): No(t) Rash'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Acute abdominal pain', 'Abdominal Pain'}
# >>    Laboratories: See below    Imaging:    CT abdomen/pelvis(prelim read): No obstruction or acute abdominal    issues to explain abdominal pain.'
# **********************************
# ***** PAIR INDEX 158 *****
# Cosine similarity: 0.5303300858899106
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Pred Mild', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Abdominal Pain'}
# >> Plan:    # Nausea w/emesis: c/b mild, diffuse abdominal pain.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Nausea', 'Constipation', 'Abdominal Pain'}
# >> He feels that his nausea and abdominal pain is c/w    severe constipation, "I know it\'s my constipation."'
# **********************************
# ***** PAIR INDEX 159 *****
# Cosine similarity: 0.9999999999999999
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Pred Mild', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Abdominal Pain'}
# >> Plan:    # Nausea w/emesis: c/b mild, diffuse abdominal pain.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Pred Mild', 'Infantile Neuroaxonal Dystrophy', 'Nausea', 'Abdominal Pain'}
# >> Plan:    # Nausea w/emesis: c/b mild, diffuse abdominal pain.'
# **********************************
# ***** PAIR INDEX 160 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'ranitidine', 'Feverall', 'Lipase', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Ranitidine', 'Zofran'}
# >> - LFTs, lipase normal    - monitor abdominal exam    - f/u final CT read    - zofran for nausea    - continue ranitidine, cannot have PPI due to ART    # Fever: without a clear source in HIV+ pt.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'ranitidine', 'Feverall', 'Lipase', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Ranitidine', 'Zofran'}
# >> - LFTs, lipase normal    - monitor abdominal exam    - f/u final CT read    - zofran for nausea    - continue ranitidine, cannot have PPI due to ART    # Fever: without a clear source in HIV+ pt.'
# **********************************
# ***** PAIR INDEX 161 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Colitis', 'Diverticulitis', 'Abdominal Pain'}
# >> Abdominal pain is    concerning, possible pt has diverticulitis, colitis though no CT    evidence of bowel inflammation.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Acute abdominal pain', 'Abdominal Pain'}
# >>    Laboratories: See below    Imaging:    CT abdomen/pelvis(prelim read): No obstruction or acute abdominal    issues to explain abdominal pain.'
# **********************************
# ***** PAIR INDEX 162 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Colitis', 'Diverticulitis', 'Abdominal Pain'}
# >> Abdominal pain is    concerning, possible pt has diverticulitis, colitis though no CT    evidence of bowel inflammation.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Colitis', 'Diverticulitis', 'Abdominal Pain'}
# >> Abdominal pain is    concerning, possible pt has diverticulitis, colitis though no CT    evidence of bowel inflammation.'
# **********************************
# ***** PAIR INDEX 163 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Dyspnea'}
# >>    Respiratory: No(t) Cough, Dyspnea'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Wheezing', 'Dyspnea'}
# >>    Respiratory: No(t) Cough, Dyspnea, No(t) Tachypnea, No(t) Wheeze'
# **********************************
# ***** PAIR INDEX 164 *****
# Cosine similarity: 0.5163977794943223
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Dyspnea', 'Americium', 'Nausea', 'Vomiting', 'Papain'}
# >> abd pain, nausea    24 Hour Events:  MULTI LUMEN - START  [**2151-9-22**]  02:18 AM    After admission o/n, pt remained with stable VS but c/o SOB and feeling    need to vomit.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Vomiting', 'Nausea', 'Constipation'}
# >> He notes that he had been feeling    generally well but with constipation when he had sudden onset of nausea    and emesis 2 nights ago.'
# **********************************
# ***** PAIR INDEX 165 *****
# Cosine similarity: 0.5892556509887895
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Acute abdominal pain', 'Radiography of kidney-ureter-bladder'}
# >> CT abdomen w/o evidence of any acute abdominal process    and KUB w/o evidence of SBO.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Acute abdominal pain', 'Abdominal Pain'}
# >>    Laboratories: See below    Imaging:    CT abdomen/pelvis(prelim read): No obstruction or acute abdominal    issues to explain abdominal pain.'
# **********************************
# ***** PAIR INDEX 166 *****
# Cosine similarity: 0.9999999999999999
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Acute abdominal pain', 'Radiography of kidney-ureter-bladder'}
# >> CT abdomen w/o evidence of any acute abdominal process    and KUB w/o evidence of SBO.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Acute abdominal pain', 'Radiography of kidney-ureter-bladder'}
# >> CT abdomen w/o evidence of any acute abdominal process    and KUB w/o evidence of SBO.'
# **********************************
# ***** PAIR INDEX 167 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Constipation'}
# >> Constipation likely contributing.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Vomiting', 'Nausea', 'Constipation'}
# >> He notes that he had been feeling    generally well but with constipation when he had sudden onset of nausea    and emesis 2 nights ago.'
# **********************************
# ***** PAIR INDEX 168 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Constipation'}
# >> Constipation likely contributing.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Constipation'}
# >> Constipation likely contributing.'
# **********************************
# ***** PAIR INDEX 169 *****
# Cosine similarity: 0.6446583712203042
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'HIV Seropositivity', 'Nausea', 'hiVETIC', 'Vomiting'}
# >> HPI:    66 yom HIV+ COPD (severe) in USOH until day of addmission when    developed nausea and emesis (non-bloody).'
# **********************************
# ***** PAIR INDEX 170 *****
# Cosine similarity: 0.6108828386569699
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pain management', 'Iron deficiency', 'Homocysteinemia', 'Gingi Med', 'Chronic back pain', 'Medicone Hemorrhoidal', 'Truvada', 'colonoscopy', 'Gastroesophageal reflux disease', 'Oxygen', 'Ritonavir', 'ritonavir', 'Hypertensive disease', 'Injection of therapeutic agent', 'Acquired Immunodeficiency Syndrome'}
# >> PMH:    - HIV/AIDS: CD4: 307( [**2151-9-10**] ) VL: 187 ( [**2151-9-15**] )- recently started on    Truvada and Ritonavir    - COPD: severe, on 2L oxygen at home, followed by Dr.  [**Last Name (STitle) **] , last    spirometry  [**7-26**]     - GERD    - HTN    - CRI    - h/o GI bleed    - h/o internal hemorrhoids, grade I on colonoscopy  [**2149**]     - Leukopenia    - Iron deficiency Anemia    - Inguinal hernia    - Homocysteinemia    - Chronic back pain- failed spinal cord stimulator, requires injections    from pain management.'
# **********************************
# ***** PAIR INDEX 171 *****
# Cosine similarity: 0.8153742483272114
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Oxygen', 'ASP2151', 'Hypertensive disease', 'Vomiting'}
# >>    HPI: This is a 66 yo M w/h/o HIV(last CD4 307  [**2151-9-10**] , VL 187     [**2151-9-15**] ), HTN, and severe COPD on 3L oxygen at home who presents    w/nausea and emesis x 2 days.'
# **********************************
# ***** PAIR INDEX 172 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assessment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED tot 101.5.'
# ----- Data j -----
# >> Time: 2151-09-22 03:58:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Feverall', 'Hypertensive disease', 'Vomiting', 'Abdominal Pain'}
# >>    Assesment: This is a 66 yo M w/h/o HIV, HTN, and severe COPD who    presents w/nausea, emesis, diffuse abdominal pain x 2 days and fever in    the ED.'
# **********************************
# ***** PAIR INDEX 173 *****
# Cosine similarity: 0.9271050693011064
# ----- Data i -----
# >> Time: 2151-09-22 08:03:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Sinus Tachycardia', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 28 (13 - 28) insp/min    SpO2: 100%    Heart rhythm: ST (Sinus Tachycardia)              Total In:              578 mL    PO:              100 mL    TF:    IVF:    478 mL    Blood products:    Total out:                                                                       0 mL                                                                     750 mL    Urine:    350 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                    -172 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 100%'
# ----- Data j -----
# >> Time: 2151-09-22 05:00:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 20 (16 - 20) insp/min    SpO2: 98%    Heart rhythm: SR (Sinus Rhythm)              Total In:              243 mL    PO:              100 mL    TF:    IVF:    143 mL    Blood products:    Total out:                                                                       0 mL                                                                     500 mL    Urine:    100 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                    -257 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 98%'
# **********************************
# ********** Processing data for 2151-09-23 **********
# ********** Processing data for 2151-09-24 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                  sentence 1  \
# 101  Patient was prescribed Doxazosin 1mg Tablet PO of total 2 mg
# 102  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
#
#                                                                                                                                                                                                                  sentence 2  \
# 101  - restart doxazosin    - hydralazine as needed for diastolic >100    - continue to monitor    # HIV: last CD4 307, VL 187; per ID fellow overnight recommendations,    continue pt on abacavir/lamivudine/atazanavir.'
# 102  Received morphine and    dilaudid for pain (back and abd).'
#
#         time 1              time 2        type 1    type 2  \
# 101 2151-09-22 2151-09-22 08:03:00  prescription  sentence
# 102 2151-09-22 2151-09-22 05:00:00  prescription  sentence
#
#                                   concepts 1  \
# 101  {Doxazosin 1 MG Oral Tablet, Doxazosin}
# 102  {Morphine Sulfate, morphine sulfate}
#
#                                            concepts 2 cosine similarity  \
# 101  {doxazosin, Doxazosin, hydralazine, hydrALAZINE}  0.534522
# 102  {morphine, Dilaudid, Morphine, Papain}            0.57735
#
#                semantic type
# 101  Pharmacologic Substance
# 102  Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                  sentence 1  \
# 101  Patient was prescribed Doxazosin 1mg Tablet PO of total 2 mg
# 102  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# 103  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# 104  Patient was prescribed Doxazosin 1mg Tablet PO of total 2 mg
#
#                                                                                                                                                                                                                  sentence 2  \
# 101  - restart doxazosin    - hydralazine as needed for diastolic >100    - continue to monitor    # HIV: last CD4 307, VL 187; per ID fellow overnight recommendations,    continue pt on abacavir/lamivudine/atazanavir.'
# 102  Received morphine and    dilaudid for pain (back and abd).'
# 103  A right femoral line was placed and he received    Morphine Sulfate 4mg IV x 1, dilaudid 1mg IV x 3, tylenol, and zofran    for nausea.'
# 104  - restart doxazosin    - hydralazine as needed for diastolic >100    - continue to monitor    # HIV: last CD4 307, VL 187; per ID fellow overnight recommendations,    continue pt on abacavir/lamivudine/atazanavir.'
#
#         time 1              time 2        type 1    type 2  \
# 101 2151-09-22 2151-09-22 08:03:00  prescription  sentence
# 102 2151-09-22 2151-09-22 05:00:00  prescription  sentence
# 103 2151-09-22 2151-09-22 03:58:00  prescription  sentence
# 104 2151-09-22 2151-09-22 08:03:00  prescription  sentence
#
#                                   concepts 1  \
# 101  {Doxazosin 1 MG Oral Tablet, Doxazosin}
# 102  {Morphine Sulfate, morphine sulfate}
# 103  {Morphine Sulfate, morphine sulfate}
# 104  {Doxazosin 1 MG Oral Tablet, Doxazosin}
#
#                                                                   concepts 2  \
# 101  {doxazosin, Doxazosin, hydralazine, hydrALAZINE}
# 102  {morphine, Dilaudid, Morphine, Papain}
# 103  {Dilaudid, morphine sulfate, Tylenol, Nausea, Morphine Sulfate, Zofran}
# 104  {doxazosin, Doxazosin, hydralazine, hydrALAZINE}
#
#     cosine similarity            semantic type
# 101  0.534522          Pharmacologic Substance
# 102  0.57735           Pharmacologic Substance
# 103  0.816497          Pharmacologic Substance
# 104  0.534522          Pharmacologic Substance

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 101
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "- stop doxazosin - hydralazine as needed for diastolic >100 - continue to monitor # HIV: last CD4 307, VL 187; per ID fellow overnight recommendations, continue pt on abacavir/lamivudine/atazanavir."

sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Doxazosin 1mg Tablet PO of total 2 mg
# sentence 2:	- restart doxazosin    - hydralazine as needed for diastolic >100    - continue to monitor    # HIV: last CD4 307, VL 187; per ID fellow overnight recommendations,    continue pt on abacavir/lamivudine/atazanavir.'
#
# New contradicting sentence: - stop doxazosin - hydralazine as needed for diastolic >100 - continue to monitor # HIV: last CD4 307, VL 187; per ID fellow overnight recommendations, continue pt on abacavir/lamivudine/atazanavir.

# %%
no_contradiction_pair_idx = [102, 103]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# sentence 2:	Received morphine and    dilaudid for pain (back and abd).'
# *****************************
# prescription 1:	Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# sentence 2:	A right femoral line was placed and he received    Morphine Sulfate 4mg IV x 1, dilaudid 1mg IV x 3, tylenol, and zofran    for nausea.'
# *****************************

# %% [markdown]
# ## Patient 6

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[5] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 180836
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2152-02-15 **********
# ********** Processing data for 2152-02-16 **********
# ********** Processing data for 2152-02-17 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.5669467095138409
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Respiratory distress', 'Blood culture', 'Rhinorrhea', 'Infantile Neuroaxonal Dystrophy'}
# >>    Microbiology: Blood cultures x 2 from  [**2152-2-15**]  - no growth to date    Assessment and Plan    Assessment/Plan:  Mr.  [**Known lastname **]  is a 67 year old male with HIV and end    stage COPD who presented  [**2152-2-15**]  with worsening shortness of breath in    the setting of rhinorrhea and productive cough now transferred to the    MICU for worsening respiratory distress.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.618718433538229
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.618718433538229
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Chronic obstructive pulmonary disease of horses'}
# >> Respiratory Distress    HPI:    Mr.  [**Known lastname **]  is a 67M with HIV (Cd4 183, VL 96 copies/mL) and end stage    COPD on 3-4L home O2 with a FEV1 of 0.5 who presented to the emergency    room on  [**2152-2-15**]  with increased shortness of breath.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.6013377943029549
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Chronic obstructive pulmonary disease of horses'}
# >> Respiratory Distress    HPI:    Mr.  [**Known lastname **]  is a 67M with HIV (Cd4 183, VL 96 copies/mL) and end stage    COPD on 3-4L home O2 with a FEV1 of 0.5 who presented to the emergency    room on  [**2152-2-15**]  with increased shortness of breath.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Respiratory distress', 'Blood culture', 'Rhinorrhea', 'Infantile Neuroaxonal Dystrophy'}
# >>    Microbiology: Blood cultures x 2 from  [**2152-2-15**]  - no growth to date    Assessment and Plan    Assessment/Plan:  Mr.  [**Known lastname **]  is a 67 year old male with HIV and end    stage COPD who presented  [**2152-2-15**]  with worsening shortness of breath in    the setting of rhinorrhea and productive cough now transferred to the    MICU for worsening respiratory distress.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.875
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Chronic obstructive pulmonary disease of horses'}
# >> Respiratory Distress    HPI:    Mr.  [**Known lastname **]  is a 67M with HIV (Cd4 183, VL 96 copies/mL) and end stage    COPD on 3-4L home O2 with a FEV1 of 0.5 who presented to the emergency    room on  [**2152-2-15**]  with increased shortness of breath.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.5802588531856595
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids', 'Biphasic Positive Airway Pressure', 'Ipratropium', 'Sliding scale insulin regime', 'ipratropium', 'Noninvasive positive pressure ventilation'}
# >> - continue high dose steroids with methylprednisolone 135 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - sputum gram stain and culture if produces sample    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  transfer to MICU for non-invasive positive pressure ventilation    - repeat ABG on BIPAP'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure', 'Holding patient', 'Ipratropium', 'Spiriva', 'ipratropium'}
# >> - holding spiriva    - receiving ipratropium and albuterol nebluizers    - azithromycin day 3    - pulse dose solumedrol    - BIPAP'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Oxygen'}
# >> He is on  [**12-21**]  liters home oxygen.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Oxygen'}
# >> He was feeling more    short of breath despite increasing oxygen use.'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Refractory anemias'}
# >>    RR: 22 O2: 100% on RA.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Oxygen'}
# >> He was feeling more    short of breath despite increasing oxygen use.'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Refractory anemias'}
# >>    RR: 22 O2: 100% on RA.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Oxygen'}
# >> He is on  [**12-21**]  liters home oxygen.'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2152-02-17 00:00:00
# >> Type: prescription
# >> Concepts: {'Albuterol', 'albuterol'}
# >> Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Albuterol', 'Intravenous infusion procedures', 'albuterol', 'Solu-Medrol'}
# >> While on the floor he was started on azithromycin, solumedrol 125 mg IV    TID, albuterol and ipratropium nebulizers.'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2152-02-17 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Patient was prescribed Aspirin 81mg Tab PO of total 81 mg
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Solu-Medrol', 'DuoNeb', 'Aspirin', 'aspirin'}
# >> He received    levofloxacin 750 mg IV x 1, duonebs, solumedrol 125 mg IV x 1 and    aspirin 81 mg.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-17 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'heparin'}
# >>    Prophylaxis: heparin SQ'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2152-02-17 00:00:00
# >> Type: prescription
# >> Concepts: {'Albuterol', 'albuterol'}
# >> Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Albuterol', 'Intravenous infusion procedures', 'albuterol', 'Solu-Medrol'}
# >> While on the floor he was started on azithromycin, solumedrol 125 mg IV    TID, albuterol and ipratropium nebulizers.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-17 00:00:00
# >> Type: lab
# >> Concepts: {'oxygen', 'Oxygen'}
# >> Patient's Oxygen lab came back 100 %.
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Oxygen'}
# >> He was feeling more    short of breath despite increasing oxygen use.'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-17 00:00:00
# >> Type: lab
# >> Concepts: {'oxygen', 'Oxygen'}
# >> Patient's Oxygen lab came back 100 %.
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Oxygen'}
# >> He is on  [**12-21**]  liters home oxygen.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-17 00:00:00
# >> Type: lab
# >> Concepts: {'oxygen', 'Oxygen'}
# >> Patient's Oxygen lab came back 100 %.
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Refractory anemias'}
# >>    RR: 22 O2: 100% on RA.'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Lung', 'Pulmonary Emphysema'}
# >> Marked hyperinflation of the lungs and    flattening of the diaphragm indicate severe emphysema, also unchanged,    compatible with severe emphysema.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Lung'}
# >> The lungs are clear.'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Lung', 'medical air'}
# >>    Pulmonary:  Poor air movement bilaterally, scarce wheezes bilaterally,    mild inspiratory crackles at bases, hyperexpansion'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Lung'}
# >> The lungs are clear.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure', 'Holding patient', 'Ipratropium', 'Spiriva', 'ipratropium'}
# >> - holding spiriva    - receiving ipratropium and albuterol nebluizers    - azithromycin day 3    - pulse dose solumedrol    - BIPAP'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    Comments: NPO while on BIPAP'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 0.5773502691896257
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids', 'Biphasic Positive Airway Pressure', 'Ipratropium', 'Sliding scale insulin regime', 'ipratropium', 'Noninvasive positive pressure ventilation'}
# >> - continue high dose steroids with methylprednisolone 135 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - sputum gram stain and culture if produces sample    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  transfer to MICU for non-invasive positive pressure ventilation    - repeat ABG on BIPAP'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    Comments: NPO while on BIPAP'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.5802588531856595
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids', 'Biphasic Positive Airway Pressure', 'Ipratropium', 'Sliding scale insulin regime', 'ipratropium', 'Noninvasive positive pressure ventilation'}
# >> - continue high dose steroids with methylprednisolone 135 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - sputum gram stain and culture if produces sample    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  transfer to MICU for non-invasive positive pressure ventilation    - repeat ABG on BIPAP'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure', 'Holding patient', 'Ipratropium', 'Spiriva', 'ipratropium'}
# >> - holding spiriva    - receiving ipratropium and albuterol nebluizers    - azithromycin day 3    - pulse dose solumedrol    - BIPAP'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Structure of palpebral conjunctiva', 'Biphasic Positive Airway Pressure'}
# >>    Vitals T: 97.0 HR: 113 BP: 153/96  RR: 19 O2: 100% on BIPAP    General Thin elderly man, tachypneic, using accessory muscles for    respiration    HEENT sclera anicteric, conjunctiva pink, mucous membranes moist, no    lymphadenopathy'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    Comments: NPO while on BIPAP'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    FEN:  NPO while on BIPAP, otherwise regular diet    Access Peripherals'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    Comments: NPO while on BIPAP'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    FEN:  NPO while on BIPAP, otherwise regular diet    Access Peripherals'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure', 'Holding patient', 'Ipratropium', 'Spiriva', 'ipratropium'}
# >> - holding spiriva    - receiving ipratropium and albuterol nebluizers    - azithromycin day 3    - pulse dose solumedrol    - BIPAP'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.5773502691896257
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    FEN:  NPO while on BIPAP, otherwise regular diet    Access Peripherals'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids', 'Biphasic Positive Airway Pressure', 'Ipratropium', 'Sliding scale insulin regime', 'ipratropium', 'Noninvasive positive pressure ventilation'}
# >> - continue high dose steroids with methylprednisolone 135 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - sputum gram stain and culture if produces sample    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  transfer to MICU for non-invasive positive pressure ventilation    - repeat ABG on BIPAP'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    FEN:  NPO while on BIPAP, otherwise regular diet    Access Peripherals'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Structure of palpebral conjunctiva', 'Biphasic Positive Airway Pressure'}
# >>    Vitals T: 97.0 HR: 113 BP: 153/96  RR: 19 O2: 100% on BIPAP    General Thin elderly man, tachypneic, using accessory muscles for    respiration    HEENT sclera anicteric, conjunctiva pink, mucous membranes moist, no    lymphadenopathy'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.875
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Chronic obstructive pulmonary disease of horses'}
# >> Respiratory Distress    HPI:    Mr.  [**Known lastname **]  is a 67M with HIV (Cd4 183, VL 96 copies/mL) and end stage    COPD on 3-4L home O2 with a FEV1 of 0.5 who presented to the emergency    room on  [**2152-2-15**]  with increased shortness of breath.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.6013377943029549
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Chronic obstructive pulmonary disease of horses'}
# >> Respiratory Distress    HPI:    Mr.  [**Known lastname **]  is a 67M with HIV (Cd4 183, VL 96 copies/mL) and end stage    COPD on 3-4L home O2 with a FEV1 of 0.5 who presented to the emergency    room on  [**2152-2-15**]  with increased shortness of breath.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Respiratory distress', 'Blood culture', 'Rhinorrhea', 'Infantile Neuroaxonal Dystrophy'}
# >>    Microbiology: Blood cultures x 2 from  [**2152-2-15**]  - no growth to date    Assessment and Plan    Assessment/Plan:  Mr.  [**Known lastname **]  is a 67 year old male with HIV and end    stage COPD who presented  [**2152-2-15**]  with worsening shortness of breath in    the setting of rhinorrhea and productive cough now transferred to the    MICU for worsening respiratory distress.'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress'}
# >>    Respiratory Distress:  Oxygenating well on nasal canula.'
# ----- Data j -----
# >> Time: 2152-02-17 10:25:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Hypertet'}
# >>    Hypertension:  Blood pressures elevated currently in the setting of    respiratory distress.'
# **********************************
# ********** Processing data for 2152-02-18 **********
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.618718433538229
# ----- Data i -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.5802588531856595
# ----- Data i -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids', 'Biphasic Positive Airway Pressure', 'Ipratropium', 'Sliding scale insulin regime', 'ipratropium', 'Noninvasive positive pressure ventilation'}
# >> - continue high dose steroids with methylprednisolone 135 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - sputum gram stain and culture if produces sample    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  transfer to MICU for non-invasive positive pressure ventilation    - repeat ABG on BIPAP'
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure', 'Holding patient', 'Ipratropium', 'Spiriva', 'ipratropium'}
# >> - holding spiriva    - receiving ipratropium and albuterol nebluizers    - azithromycin day 3    - pulse dose solumedrol    - BIPAP'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-18 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'heparin'}
# >>    Prophylaxis: heparin SQ'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2152-02-18 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.58 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 15 (11 - 33) insp/min    SpO2: 94%    Heart rhythm: SR (Sinus Rhythm)              Total In:                                                                     190 mL                                                                     584 mL    PO:              TF:    IVF:                                                                      40 mL                                                                     584 mL    Blood products:    Total out:                                                                     800 mL                                                                     230 mL    Urine:                                                                     800 mL                                                                     230 mL    NG:    Stool:    Drains:    Balance:                                                                    -610 mL                                                                     354 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 400 (400 - 400) mL    Vt (Spontaneous): 653 (653 - 653) mL'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    FEN:  NPO while on BIPAP, otherwise regular diet    Access Peripherals'
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'oxygen', 'Structure of palpebral conjunctiva', 'Biphasic Positive Airway Pressure'}
# >>    Vitals T: 97.0 HR: 113 BP: 153/96  RR: 19 O2: 100% on BIPAP    General Thin elderly man, tachypneic, using accessory muscles for    respiration    HEENT sclera anicteric, conjunctiva pink, mucous membranes moist, no    lymphadenopathy'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure', 'Holding patient', 'Ipratropium', 'Spiriva', 'ipratropium'}
# >> - holding spiriva    - receiving ipratropium and albuterol nebluizers    - azithromycin day 3    - pulse dose solumedrol    - BIPAP'
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    FEN:  NPO while on BIPAP, otherwise regular diet    Access Peripherals'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 0.5773502691896257
# ----- Data i -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids', 'Biphasic Positive Airway Pressure', 'Ipratropium', 'Sliding scale insulin regime', 'ipratropium', 'Noninvasive positive pressure ventilation'}
# >> - continue high dose steroids with methylprednisolone 135 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - sputum gram stain and culture if produces sample    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  transfer to MICU for non-invasive positive pressure ventilation    - repeat ABG on BIPAP'
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure'}
# >>    FEN:  NPO while on BIPAP, otherwise regular diet    Access Peripherals'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.5802588531856595
# ----- Data i -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids', 'Biphasic Positive Airway Pressure', 'Ipratropium', 'Sliding scale insulin regime', 'ipratropium', 'Noninvasive positive pressure ventilation'}
# >> - continue high dose steroids with methylprednisolone 135 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - sputum gram stain and culture if produces sample    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  transfer to MICU for non-invasive positive pressure ventilation    - repeat ABG on BIPAP'
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Biphasic Positive Airway Pressure', 'Holding patient', 'Ipratropium', 'Spiriva', 'ipratropium'}
# >> - holding spiriva    - receiving ipratropium and albuterol nebluizers    - azithromycin day 3    - pulse dose solumedrol    - BIPAP'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress'}
# >>    Respiratory Distress:  Oxygenating well on nasal canula.'
# ----- Data j -----
# >> Time: 2152-02-18 07:24:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Hypertet'}
# >>    Hypertension:  Blood pressures elevated currently in the setting of    respiratory distress.'
# **********************************
# ********** Processing data for 2152-02-19 **********
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.6831300510639731
# ----- Data i -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids'}
# >> End stage COPD with exacerbation: IV steroids and antibiotics.'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Dyspnea'}
# >> Attending    67M HIV (CD4 183/VL 96), severe COPD c FEV1 0.5 on 3-4L at home p/w    cough, SOB and rising oxygen requirements.'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 0.9036961141150637
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Dyspnea'}
# >> Attending    67M HIV (CD4 183/VL 96), severe COPD c FEV1 0.5 on 3-4L at home p/w    cough, SOB and rising oxygen requirements.'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 0.6614378277661477
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids'}
# >> End stage COPD with exacerbation: IV steroids and antibiotics.'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.5714285714285713
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', "2-phenyl-6-(2'-(4'-(ethoxycarbonyl)thiazolyl))thiazolo(3,2-b)(1,2,4)triazole", 'Steroids', 'Ipratropium', 'Microbial culture of sputum', 'Chest CT', 'Sliding scale insulin regime', 'ipratropium'}
# >> Was sedated well with fentanyl/versed    - continue high dose steroids with methylprednisolone 125 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - will do sputum culture gm stain/cx/PCP/fungal cx today from ETT    aspirate    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  cont to follow ABG s while intubated    - will hold off on CT chest for now    .'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids'}
# >> End stage COPD with exacerbation: IV steroids and antibiotics.'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.6390096504226936
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Pulmonary Function Test/Forced Expiratory Volume 1', 'Dyspnea'}
# >> Attending    67M HIV (CD4 183/VL 96), severe COPD c FEV1 0.5 on 3-4L at home p/w    cough, SOB and rising oxygen requirements.'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 0.801783725737273
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids'}
# >> End stage COPD with exacerbation: IV steroids and antibiotics.'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 0.618718433538229
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# ----- Data j -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# **********************************
# ***** PAIR INDEX 45 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Morning After'}
# >>    Hypotension:  Found to be hypotensive on morning  [**Name Initial (PRE) 939**] .'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Morning After'}
# >> Transferred for increased    WOB, had been hypertensive but hypotensive yesterday morning, responded    to IV fluids and decreased sedation.'
# **********************************
# ***** PAIR INDEX 46 *****
# Cosine similarity: 0.5714285714285713
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', "2-phenyl-6-(2'-(4'-(ethoxycarbonyl)thiazolyl))thiazolo(3,2-b)(1,2,4)triazole", 'Steroids', 'Ipratropium', 'Microbial culture of sputum', 'Chest CT', 'Sliding scale insulin regime', 'ipratropium'}
# >> Was sedated well with fentanyl/versed    - continue high dose steroids with methylprednisolone 125 mg IV TID    - insulin sliding scale while on steroids    - continue azithromycin for COPD exacerbation    - ipratropium and albuterol nebulizers    - will do sputum culture gm stain/cx/PCP/fungal cx today from ETT    aspirate    - will check LDH given concern for PCP     [**Name Initial (PRE) **]  cont to follow ABG s while intubated    - will hold off on CT chest for now    .'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Steroids'}
# >> End stage COPD with exacerbation: IV steroids and antibiotics.'
# **********************************
# ***** PAIR INDEX 47 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Sea Soft'}
# >>    Abdominal: Soft, non-tender, non-distended, +BS'
# ----- Data j -----
# >> Time: 2152-02-19 14:04:00
# >> Type: sentence
# >> Concepts: {'Scaphoid bone', 'Sea Soft'}
# >> Soft, scaphoid.'
# **********************************
# ***** PAIR INDEX 48 *****
# Cosine similarity: 0.6201736729460423
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'ALBON BOLUSES', 'Fertilization in Vitro'}
# >> - IVF boluses, assess for response.'
# ----- Data j -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'Fertilization in Vitro', 'Morning After', 'heparin sodium', 'ALBON BOLUSES', 'Infusion procedures'}
# >> 24 Hour Events:    - Hypotensive in morning of  [**2152-2-18**]  and responsive to IVF boluses and    decrease in sedation    - Right IJ central line placed in the afternoon of  [**2152-2-18**]     - Evening ABG was 7.32/54/104, with no change in vent settings    following  MULTI LUMEN - START  [**2152-2-18**]  02:00 PM    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Azithromycin -  [**2152-2-17**]  11:30 PM    Infusions:    Midazolam (Versed) - 1 mg/hour    Other ICU medications:    Heparin Sodium (Prophylaxis) -  [**2152-2-18**]  11:11 PM    Ranitidine (Prophylaxis) -  [**2152-2-18**]  11:12 PM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2152-2-19**]  07:02 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# **********************************
# ***** PAIR INDEX 49 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-19 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'heparin'}
# >>    Prophylaxis: heparin SQ'
# **********************************
# ***** PAIR INDEX 50 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2152-02-19 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.47 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 70 Inch              Total In:                                                                   2,699 mL                                                                      80 mL    PO:              TF:    IVF:                                                                   2,699 mL                                                                      80 mL    Blood products:    Total out:                                                                     755 mL                                                                     625 mL    Urine:                                                                     755 mL                                                                     625 mL    NG:    Stool:    Drains:    Balance:                                                                   1,944 mL                                                                    -545 mL    Respiratory support    O2 Delivery Device: Endotracheal tube    Ventilator mode: CMV/ASSIST/AutoFlow    Vt (Set): 400 (400 - 400) mL    RR (Set): 15    RR (Spontaneous): 0'
# **********************************
# ***** PAIR INDEX 51 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-19 00:00:00
# >> Type: lab
# >> Concepts: {'oxygen', 'Oxygen'}
# >> Patient's Oxygen lab came back 30 %.
# ----- Data j -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Oxygen'}
# >> He is on  [**12-21**]  liters home oxygen.'
# **********************************
# ***** PAIR INDEX 52 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> He is transferred to the MICU for a    trial of non-invasive positive pressure ventilation and possible    intubation.'
# ...
# >> Type: sentence
# >> Concepts: {'Respiratory distress'}
# >>    Respiratory Distress:  Oxygenating well on nasal canula.'
# ----- Data j -----
# >> Time: 2152-02-19 07:02:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Hypertet'}
# >>    Hypertension:  Blood pressures elevated currently in the setting of    respiratory distress.'
# **********************************
# ********** Processing data for 2152-02-20 **********
# ***** PAIR INDEX 68 *****
# Cosine similarity: 0.8660254037844388
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy', 'Intubation'}
# >>    Disposition:  plan call-out to floor today, much improved after short    course intubatin.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his    note above, including assessment and plan.'
# **********************************
# ***** PAIR INDEX 69 *****
# Cosine similarity: 0.618718433538229
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Terminal illness', 'Pulmonary Function Test/Forced Expiratory Volume 1'}
# >>    COPD:  As above, end stage disease with FEV1 of 0.5 which is 20%    predicted.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Chronic obstructive pulmonary disease of horses', 'Virus Diseases'}
# >> The    most likely etiology of his symptoms is COPD exacerbation in the    setting of viral infection.'
# **********************************
# ***** PAIR INDEX 70 *****
# Cosine similarity: 0.5547001962252291
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Tylenol', 'morphine', 'Morphine', 'Codeine', 'Codeine Measurement', 'Chronic back pain'}
# >> - continue to monitor    Chronic back pain: Stable    - morphine PRN    - home tylenol with codeine as needed'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Morphine', 'morphine'}
# >> Initially patient appeared in stress but later was doing    well after small dose IV morphine.'
# **********************************
# ***** PAIR INDEX 71 *****
# Cosine similarity: 0.6488856845230501
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Morphine Sulfate', 'morphine sulfate'}
# >> Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2 mg
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'ranitidine', 'Americium', 'morphine sulfate', 'Pharmaceutical Preparations', 'heparin sodium', 'Morphine Sulfate', 'Ranitidine', 'Infusion procedures'}
# >> Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Azithromycin -  [**2152-2-17**]  11:30 PM    Infusions:    Other ICU medications:    Heparin Sodium (Prophylaxis) -  [**2152-2-19**]  10:22 PM    Ranitidine (Prophylaxis) -  [**2152-2-19**]  10:23 PM    Morphine Sulfate -  [**2152-2-20**]  06:00 AM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2152-2-20**]  07:22 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# **********************************
# ***** PAIR INDEX 72 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Morphine Sulfate', 'morphine sulfate'}
# >> Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2 mg
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Morphine', 'morphine'}
# >> Initially patient appeared in stress but later was doing    well after small dose IV morphine.'
# **********************************
# ***** PAIR INDEX 73 *****
# Cosine similarity: 0.8366600265340755
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Methylprednisolone', 'Intravenous infusion procedures', 'methylprednisolone'}
# >> Patient was prescribed MethylPREDNISolone Sodium Succ 40mg Vial IV of total 60 mg
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Arteries', 'Methylprednisolone', 'Intravenous infusion procedures', 'methylprednisolone', 'Tracheal Extubation'}
# >> 24 Hour Events:  INVASIVE VENTILATION - STOP  [**2152-2-19**]  05:00 PM  ARTERIAL LINE - STOP  [**2152-2-20**]  06:18 AM    - Decreased methylprednisolone to 60mg IV BID    - Extubated.'
# **********************************
# ***** PAIR INDEX 74 *****
# Cosine similarity: 0.6488856845230501
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Morphine Sulfate', 'morphine sulfate'}
# >> Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'ranitidine', 'Americium', 'morphine sulfate', 'Pharmaceutical Preparations', 'heparin sodium', 'Morphine Sulfate', 'Ranitidine', 'Infusion procedures'}
# >> Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Azithromycin -  [**2152-2-17**]  11:30 PM    Infusions:    Other ICU medications:    Heparin Sodium (Prophylaxis) -  [**2152-2-19**]  10:22 PM    Ranitidine (Prophylaxis) -  [**2152-2-19**]  10:23 PM    Morphine Sulfate -  [**2152-2-20**]  06:00 AM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2152-2-20**]  07:22 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# **********************************
# ***** PAIR INDEX 75 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Morphine Sulfate', 'morphine sulfate'}
# >> Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Morphine', 'morphine'}
# >> Initially patient appeared in stress but later was doing    well after small dose IV morphine.'
# **********************************
# ***** PAIR INDEX 76 *****
# Cosine similarity: 0.6172133998483676
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Doxazosin 1 MG Oral Tablet', 'Doxazosin'}
# >> Patient was prescribed Doxazosin 1mg Tablet PO of total 2 mg
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'doxazosin', 'Pharmaceutical Preparations', 'Doxazosin'}
# >> - will continue doxazosin, can consider other medications in future is    BP remains elevated.'
# **********************************
# ***** PAIR INDEX 77 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'heparin'}
# >>    Prophylaxis: heparin SQ'
# **********************************
# ***** PAIR INDEX 78 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.37 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 70 Inch              Total In:                                                                     509 mL                                                                      74 mL    PO:              TF:    IVF:                                                                     269 mL                                                                      74 mL    Blood products:    Total out:                                                                   1,225 mL                                                                     595 mL    Urine:                                                                   1,225 mL                                                                     595 mL    NG:    Stool:    Drains:    Balance:                                                                    -716 mL                                                                    -522 mL    Respiratory support    O2 Delivery Device: Nasal cannula    Ventilator mode: PSV/SBT    Vt (Set): 400 (400 - 400) mL    Vt (Spontaneous): 520 (520 - 520) mL'
# **********************************
# ***** PAIR INDEX 79 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >>    Code: DNR, wants short course intubation.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> No complications of intubation.'
# **********************************
# ***** PAIR INDEX 80 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Recombinate', 'Intubation'}
# >> With combination of UOP decreasing as well as sedation for    intubation and overall positive pressure ventilation, likely related to    hypovolemia.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> No complications of intubation.'
# **********************************
# ***** PAIR INDEX 81 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Recombinate', 'Intubation'}
# >> With combination of UOP decreasing as well as sedation for    intubation and overall positive pressure ventilation, likely related to    hypovolemia.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >>    Code: DNR, wants short course intubation.'
# **********************************
# ***** PAIR INDEX 82 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Intubation'}
# >> Decision made to intubate pt in PM of  [**2-17**]  for increasing    respiratory distress.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> No complications of intubation.'
# **********************************
# ***** PAIR INDEX 83 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Intubation'}
# >> Decision made to intubate pt in PM of  [**2-17**]  for increasing    respiratory distress.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >>    Code: DNR, wants short course intubation.'
# **********************************
# ***** PAIR INDEX 84 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> He was transferred to the MICU for a    trial of non-invasive positive pressure ventilation and possible    intubation.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> No complications of intubation.'
# **********************************
# ***** PAIR INDEX 85 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> He was transferred to the MICU for a    trial of non-invasive positive pressure ventilation and possible    intubation.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >>    Code: DNR, wants short course intubation.'
# **********************************
# ***** PAIR INDEX 86 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> He was transferred to the MICU for a    trial of non-invasive positive pressure ventilation and possible    intubation.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Recombinate', 'Intubation'}
# >> With combination of UOP decreasing as well as sedation for    intubation and overall positive pressure ventilation, likely related to    hypovolemia.'
# **********************************
# ***** PAIR INDEX 87 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Intubation'}
# >> He was transferred to the MICU for a    trial of non-invasive positive pressure ventilation and possible    intubation.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Intubation'}
# >> Decision made to intubate pt in PM of  [**2-17**]  for increasing    respiratory distress.'
# **********************************
# ***** PAIR INDEX 88 *****
# Cosine similarity: 0.8366600265340755
# ----- Data i -----
# >> Time: 2152-02-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Methylprednisolone', 'Intravenous infusion procedures', 'methylprednisolone'}
# >> Patient was prescribed MethylPREDNISolone Sodium Succ 40mg Vial IV of total 60 mg
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Arteries', 'Methylprednisolone', 'Intravenous infusion procedures', 'methylprednisolone', 'Tracheal Extubation'}
# >> 24 Hour Events:  INVASIVE VENTILATION - STOP  [**2152-2-19**]  05:00 PM  ARTERIAL LINE - STOP  [**2152-2-20**]  06:18 AM    - Decreased methylprednisolone to 60mg IV BID    - Extubated.'
# **********************************
# ***** PAIR INDEX 89 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Intubation'}
# >> Decision made to intubate pt in PM of  [**2-17**]  for increasing    respiratory distress.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress'}
# >> Patient intubated on  [**2-17**]  for worsening    respiratory distress and extubated on  [**2-19**]  without complications.'
# **********************************
# ***** PAIR INDEX 90 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress'}
# >>    Respiratory Distress:  Oxygenating well on nasal canula.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress'}
# >> Patient intubated on  [**2-17**]  for worsening    respiratory distress and extubated on  [**2-19**]  without complications.'
# **********************************
# ***** PAIR INDEX 91 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress'}
# >>    Respiratory Distress:  Oxygenating well on nasal canula.'
# ----- Data j -----
# >> Time: 2152-02-20 07:22:00
# >> Type: sentence
# >> Concepts: {'Respiratory distress', 'Intubation'}
# >> Decision made to intubate pt in PM of  [**2-17**]  for increasing    respiratory distress.'
# **********************************
# ********** Processing data for 2152-02-21 **********
# ********** Processing data for 2152-02-22 **********
# ********** Processing data for 2152-02-23 **********
# ********** Processing data for 2152-02-24 **********
# ********** Processing data for 2152-02-25 **********
# ********** Processing data for 2152-02-26 **********
# ********** Processing data for 2152-02-27 **********
# ********** Processing data for 2152-02-28 **********
# ********** Processing data for 2152-02-29 **********
# ********** Processing data for 2152-03-01 **********
# ********** Processing data for 2152-03-02 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                             sentence 1  \
# 9   Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# 10  Patient was prescribed Aspirin 81mg Tab PO of total 81 mg
#
#                                                                                                                 sentence 2  \
# 9   While on the floor he was started on azithromycin, solumedrol 125 mg IV    TID, albuterol and ipratropium nebulizers.'
# 10  He received    levofloxacin 750 mg IV x 1, duonebs, solumedrol 125 mg IV x 1 and    aspirin 81 mg.'
#
#        time 1              time 2        type 1    type 2  \
# 9  2152-02-17 2152-02-17 10:25:00  prescription  sentence
# 10 2152-02-17 2152-02-17 10:25:00  prescription  sentence
#
#                 concepts 1  \
# 9   {Albuterol, albuterol}
# 10  {Aspirin, aspirin}
#
#                                                               concepts 2  \
# 9   {Albuterol, Intravenous infusion procedures, albuterol, Solu-Medrol}
# 10  {Solu-Medrol, DuoNeb, Aspirin, aspirin}
#
#    cosine similarity            semantic type
# 9   0.666667          Pharmacologic Substance
# 10  0.755929          Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                             sentence 1  \
# 9   Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# 10  Patient was prescribed Aspirin 81mg Tab PO of total 81 mg
# 11  Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# 12  Patient was prescribed Albuterol 0.083% Neb Soln 0.083%;3mL Vial IH of total 1 NEB
# 31  Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# 49  Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# 71  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2 mg
# 72  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2 mg
# 73  Patient was prescribed MethylPREDNISolone Sodium Succ 40mg Vial IV of total 60 mg
# 74  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# 75  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2-4 mg
# 76  Patient was prescribed Doxazosin 1mg Tablet PO of total 2 mg
# 77  Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# 88  Patient was prescribed MethylPREDNISolone Sodium Succ 40mg Vial IV of total 60 mg
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           sentence 2  \
# 9   While on the floor he was started on azithromycin, solumedrol 125 mg IV    TID, albuterol and ipratropium nebulizers.'
# 10  He received    levofloxacin 750 mg IV x 1, duonebs, solumedrol 125 mg IV x 1 and    aspirin 81 mg.'
# 11     Prophylaxis: heparin SQ'
# 12  While on the floor he was started on azithromycin, solumedrol 125 mg IV    TID, albuterol and ipratropium nebulizers.'
# 31     Prophylaxis: heparin SQ'
# 49     Prophylaxis: heparin SQ'
# 71  Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Azithromycin -  [**2152-2-17**]  11:30 PM    Infusions:    Other ICU medications:    Heparin Sodium (Prophylaxis) -  [**2152-2-19**]  10:22 PM    Ranitidine (Prophylaxis) -  [**2152-2-19**]  10:23 PM    Morphine Sulfate -  [**2152-2-20**]  06:00 AM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2152-2-20**]  07:22 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# 72  Initially patient appeared in stress but later was doing    well after small dose IV morphine.'
# 73  24 Hour Events:  INVASIVE VENTILATION - STOP  [**2152-2-19**]  05:00 PM  ARTERIAL LINE - STOP  [**2152-2-20**]  06:18 AM    - Decreased methylprednisolone to 60mg IV BID    - Extubated.'
# 74  Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Azithromycin -  [**2152-2-17**]  11:30 PM    Infusions:    Other ICU medications:    Heparin Sodium (Prophylaxis) -  [**2152-2-19**]  10:22 PM    Ranitidine (Prophylaxis) -  [**2152-2-19**]  10:23 PM    Morphine Sulfate -  [**2152-2-20**]  06:00 AM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2152-2-20**]  07:22 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# 75  Initially patient appeared in stress but later was doing    well after small dose IV morphine.'
# 76  - will continue doxazosin, can consider other medications in future is    BP remains elevated.'
# 77     Prophylaxis: heparin SQ'
# 88  24 Hour Events:  INVASIVE VENTILATION - STOP  [**2152-2-19**]  05:00 PM  ARTERIAL LINE - STOP  [**2152-2-20**]  06:18 AM    - Decreased methylprednisolone to 60mg IV BID    - Extubated.'
#
#        time 1              time 2        type 1    type 2  \
# 9  2152-02-17 2152-02-17 10:25:00  prescription  sentence
# 10 2152-02-17 2152-02-17 10:25:00  prescription  sentence
# 11 2152-02-17 2152-02-17 10:25:00  prescription  sentence
# 12 2152-02-17 2152-02-17 10:25:00  prescription  sentence
# 31 2152-02-18 2152-02-18 07:24:00  prescription  sentence
# 49 2152-02-19 2152-02-19 07:02:00  prescription  sentence
# 71 2152-02-20 2152-02-20 07:22:00  prescription  sentence
# 72 2152-02-20 2152-02-20 07:22:00  prescription  sentence
# 73 2152-02-20 2152-02-20 07:22:00  prescription  sentence
# 74 2152-02-20 2152-02-20 07:22:00  prescription  sentence
# 75 2152-02-20 2152-02-20 07:22:00  prescription  sentence
# 76 2152-02-20 2152-02-20 07:22:00  prescription  sentence
# 77 2152-02-20 2152-02-20 07:22:00  prescription  sentence
# 88 2152-02-20 2152-02-20 07:22:00  prescription  sentence
#
#                                                                    concepts 1  \
# 9   {Albuterol, albuterol}
# 10  {Aspirin, aspirin}
# 11  {heparin}
# 12  {Albuterol, albuterol}
# 31  {heparin}
# 49  {heparin}
# 71  {Morphine Sulfate, morphine sulfate}
# 72  {Morphine Sulfate, morphine sulfate}
# 73  {Methylprednisolone, Intravenous infusion procedures, methylprednisolone}
# 74  {Morphine Sulfate, morphine sulfate}
# 75  {Morphine Sulfate, morphine sulfate}
# 76  {Doxazosin 1 MG Oral Tablet, Doxazosin}
# 77  {heparin}
# 88  {Methylprednisolone, Intravenous infusion procedures, methylprednisolone}
#
#                                                                                                                                    concepts 2  \
# 9   {Albuterol, Intravenous infusion procedures, albuterol, Solu-Medrol}
# 10  {Solu-Medrol, DuoNeb, Aspirin, aspirin}
# 11  {heparin}
# 12  {Albuterol, Intravenous infusion procedures, albuterol, Solu-Medrol}
# 31  {heparin}
# 49  {heparin}
# 71  {ranitidine, Americium, morphine sulfate, Pharmaceutical Preparations, heparin sodium, Morphine Sulfate, Ranitidine, Infusion procedures}
# 72  {Morphine, morphine}
# 73  {Arteries, Methylprednisolone, Intravenous infusion procedures, methylprednisolone, Tracheal Extubation}
# 74  {ranitidine, Americium, morphine sulfate, Pharmaceutical Preparations, heparin sodium, Morphine Sulfate, Ranitidine, Infusion procedures}
# 75  {Morphine, morphine}
# 76  {doxazosin, Pharmaceutical Preparations, Doxazosin}
# 77  {heparin}
# 88  {Arteries, Methylprednisolone, Intravenous infusion procedures, methylprednisolone, Tracheal Extubation}
#
#    cosine similarity                        semantic type
# 9   0.666667          Pharmacologic Substance
# 10  0.755929          Pharmacologic Substance
# 11  1.0               Pharmacologic Substance
# 12  0.666667          Pharmacologic Substance
# 31  1.0               Pharmacologic Substance
# 49  1.0               Pharmacologic Substance
# 71  0.648886          Pharmacologic Substance
# 72  0.707107          Pharmacologic Substance
# 73  0.83666           Pharmacologic Substance
# 74  0.648886          Pharmacologic Substance
# 75  0.707107          Pharmacologic Substance
# 76  0.617213          Pharmacologic Substance
# 77  1.0               Pharmacologic Substance
# 88  0.83666           Therapeutic or Preventive Procedure

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 72
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "Initially patient appeared in stress but later was doing well and did not require Morphine."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 2 mg
# sentence 2:	Initially patient appeared in stress but later was doing    well after small dose IV morphine.'
#
# New contradicting sentence: Initially patient appeared in stress but later was doing well and did not require Morphine.

# %%
no_contradiction_pair_idx = [31, 88]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# sentence 2:	   Prophylaxis: heparin SQ'
# *****************************
# prescription 1:	Patient was prescribed MethylPREDNISolone Sodium Succ 40mg Vial IV of total 60 mg
# sentence 2:	24 Hour Events:  INVASIVE VENTILATION - STOP  [**2152-2-19**]  05:00 PM  ARTERIAL LINE - STOP  [**2152-2-20**]  06:18 AM    - Decreased methylprednisolone to 60mg IV BID    - Extubated.'
# *****************************

# %% [markdown]
# ## Patient 7

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[6] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 154802
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2121-03-31 **********
# ********** Processing data for 2121-04-01 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Right Extremities: (Edema: Trace), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Left Extremities: (Edema: Trace), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Hydroxymethylglutaryl-CoA Reductase Inhibitors', 'Aspirin', 'Adrenergic beta-Antagonists', 'aspirin'}
# >>    Cardiovascular: Aspirin, Beta-blocker, Statins'
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Aspirin EC5.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Patient was prescribed 5% Dextrose 250mL Bag IV DRIP of total 250 mL
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.6172133998483676
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Morphine Sulfate', 'morphine sulfate'}
# >> Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 0.5-5.0 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'ranitidine', 'Americium', 'Feverall', 'morphine sulfate', 'Pharmaceutical Preparations', 'Arteries', 'Electrocardiography', 'Morphine Sulfate', 'Ranitidine', 'Intubation', 'Infusion procedures'}
# >> Ranitidine    24 Hour Events:  INTUBATION - At  [**2121-3-31**]  01:45 PM    received intubated from or  OR RECEIVED - At  [**2121-3-31**]  01:45 PM  ARTERIAL LINE - START  [**2121-3-31**]  01:45 PM  PA CATHETER - START  [**2121-3-31**]  02:00 PM  EKG - At  [**2121-3-31**]  02:00 PM  FEVER - 101.3 C -  [**2121-4-1**]  12:00 AM    Post operative day:    POD#1 - Cabg    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Morphine Sulfate -  [**2121-4-1**]  03:16 AM    Other medications:    Flowsheet Data as of   [**2121-4-1**]  09:27 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.6172133998483676
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Morphine Sulfate', 'morphine sulfate'}
# >> Patient was prescribed Morphine Sulfate 10mg Syringe IV of total 0.5-5.0 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'ranitidine', 'Americium', 'Feverall', 'morphine sulfate', 'Pharmaceutical Preparations', 'Arteries', 'Electrocardiography', 'Morphine Sulfate', 'Ranitidine', 'Intubation', 'Infusion procedures'}
# >> Ranitidine    24 Hour Events:  INTUBATION - At  [**2121-3-31**]  01:45 PM    received intubated from or  OR RECEIVED - At  [**2121-3-31**]  01:45 PM  ARTERIAL LINE - START  [**2121-3-31**]  01:45 PM  PA CATHETER - START  [**2121-3-31**]  02:00 PM  EKG - At  [**2121-3-31**]  02:00 PM  FEVER - 101.3 C -  [**2121-4-1**]  12:00 AM    Post operative day:    POD#1 - Cabg    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Morphine Sulfate -  [**2121-4-1**]  03:16 AM    Other medications:    Flowsheet Data as of   [**2121-4-1**]  09:27 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.5520524474738834
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Morphine Sulfate 4 MG/ML', 'morphine sulfate'}
# >> Patient was prescribed Morphine Sulfate 4mg Syringe IV of total 0.5-5.0 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'ranitidine', 'Americium', 'Feverall', 'morphine sulfate', 'Pharmaceutical Preparations', 'Arteries', 'Electrocardiography', 'Morphine Sulfate', 'Ranitidine', 'Intubation', 'Infusion procedures'}
# >> Ranitidine    24 Hour Events:  INTUBATION - At  [**2121-3-31**]  01:45 PM    received intubated from or  OR RECEIVED - At  [**2121-3-31**]  01:45 PM  ARTERIAL LINE - START  [**2121-3-31**]  01:45 PM  PA CATHETER - START  [**2121-3-31**]  02:00 PM  EKG - At  [**2121-3-31**]  02:00 PM  FEVER - 101.3 C -  [**2121-4-1**]  12:00 AM    Post operative day:    POD#1 - Cabg    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Morphine Sulfate -  [**2121-4-1**]  03:16 AM    Other medications:    Flowsheet Data as of   [**2121-4-1**]  09:27 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 0.7844645405527361
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Magnesium Sulfate', 'magnesium sulfate'}
# >> Patient was prescribed Magnesium Sulfate 2 g / 50 mL Premix Bag IV of total 2 gm
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'ketorolac', 'Magnesium Sulfate', 'Vaccines', 'Ketorolac', 'magnesium sulfate'}
# >> Influenza Virus Vaccine    Ketorolac  Magnesium Sulfate .'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'brain-derived neurotrophic factor, human', 'insulin glulisine'}
# >> Patient was prescribed Insulin Human Regular 100Units/mL; 10mL Vial IV DRIP of total 100 UNIT
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'insulin glulisine'}
# >> Insulin .'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Patient was prescribed 5% Dextrose 250mL Bag IV of total 250 mL
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2 gm
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate6.'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Metoclopramide', 'metoclopramide'}
# >> Patient was prescribed Metoclopramide 5mg/mL-2mL Vial IV of total 10 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Metoclopramide', 'metoclopramide'}
# >> Metoclopramide .'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Acetaminophen / Oxycodone'}
# >> Patient was prescribed Oxycodone-Acetaminophen 5mg/325mg Tablet PO of total 1-2 TAB
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Acetaminophen / Oxycodone'}
# >> Oxycodone-Acetaminophen .'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Patient was prescribed Acetaminophen 325mg Tablet PO of total 650 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Acetaminophen / Oxycodone'}
# >> Oxycodone-Acetaminophen .'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Patient was prescribed Acetaminophen 650mg Supp PR of total 650 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Acetaminophen / Oxycodone'}
# >> Oxycodone-Acetaminophen .'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Patient was prescribed Dextrose 50% 50mL Syringe IV of total 12.5 gm
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'nitroglycerin', 'aspirin'}
# >> Patient was prescribed Aspirin 81mg Tab NG of total 81 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Aspirin EC5.'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.5393598899705937
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'nitroglycerin', 'aspirin'}
# >> Patient was prescribed Aspirin 81mg Tab NG of total 81 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Hydroxymethylglutaryl-CoA Reductase Inhibitors', 'Aspirin', 'Adrenergic beta-Antagonists', 'aspirin'}
# >>    Cardiovascular: Aspirin, Beta-blocker, Statins'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'metoprolol', 'Metoprolol'}
# >> Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 12.5 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'metoprolol', 'Metoprolol', 'tartrate'}
# >> Metoprolol Tartrate .'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'metoprolol', 'Metoprolol'}
# >> Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 25 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'metoprolol', 'Metoprolol', 'tartrate'}
# >> Metoprolol Tartrate .'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Aspirin EC5.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Hydroxymethylglutaryl-CoA Reductase Inhibitors', 'Aspirin', 'Adrenergic beta-Antagonists', 'aspirin'}
# >>    Cardiovascular: Aspirin, Beta-blocker, Statins'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Furosemide', 'furosemide'}
# >> Patient was prescribed Furosemide 40mg/4mL Vial IV of total 20 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Furosemide', 'furosemide'}
# >> Furosemide .'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Furosemide', 'furosemide'}
# >> Patient was prescribed Furosemide 40mg/4mL Vial IV of total 20 mg
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Furosemide', 'furosemide'}
# >> Furosemide .'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: lab
# >> Concepts: {'glucose', 'Glucose'}
# >> Patient's Glucose lab came back 135 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.00 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Uridine', 'Tube feeding of patient', 'Blood product'}
# >>    SVI: 46 mL/m2    Total In:                                                                   5,094 mL                                                                     140 mL    PO:    Tube feeding:    IV Fluid:                                                                   4,694 mL                                                                     140 mL    Blood products:                                                                     400 mL    Total out:                                                                   1,715 mL                                                                     545 mL    Urine:                                                                   1,025 mL                                                                     455 mL    NG:                                                                      25 mL    Stool:    Drains:    Balance:                                                                   3,379 mL                                                                    -405 mL    Respiratory support    O2 Delivery Device: Nasal cannula    Ventilator mode: Standby    Vt (Set): 600 (600 - 600) mL    Vt (Spontaneous): 664 (664 - 664) mL'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: lab
# >> Concepts: {'glucose', 'Glucose'}
# >> Patient's Glucose lab came back 102 mg/dL.
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: lab
# >> Concepts: {'Calcium', 'Calcium Drug Class'}
# >> Patient's Calcium, Total lab came back 7.8 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate6.'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.6666666666666666
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: lab
# >> Concepts: {'glucose', 'Glucose'}
# >> Patient's Glucose lab came back 425 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 2.75 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Uridine', 'Tube feeding of patient', 'Blood product'}
# >>    SVI: 46 mL/m2    Total In:                                                                   5,094 mL                                                                     140 mL    PO:    Tube feeding:    IV Fluid:                                                                   4,694 mL                                                                     140 mL    Blood products:                                                                     400 mL    Total out:                                                                   1,715 mL                                                                     545 mL    Urine:                                                                   1,025 mL                                                                     455 mL    NG:                                                                      25 mL    Stool:    Drains:    Balance:                                                                   3,379 mL                                                                    -405 mL    Respiratory support    O2 Delivery Device: Nasal cannula    Ventilator mode: Standby    Vt (Set): 600 (600 - 600) mL    Vt (Spontaneous): 664 (664 - 664) mL'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Right Extremities: (Edema: Trace), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Left Extremities: (Edema: Trace), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Imaging Techniques'}
# >>    Imaging: CXR today'
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Imaging Techniques', 'Excision'}
# >>    Imaging: CXR pending after CT removal'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.5443310539518175
# ----- Data i -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Primed lymphocyte test', 'Laboratory test finding', 'Prothrombin time assay', 'Activated Partial Thromboplastin Time measurement'}
# >> 12.7    Hct    24    24    29.1    28.6    27.0    Plt    215    189    Creatinine    0.7    0.8    TCO2    29    28    26    22    Glucose    119    182    89    139    135    Other labs: PT / PTT / INR:14.2/35.5/1.2'
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: (Awake / Alert / Oriented: x 3), Follows simple commands,    Moves all extremities    Labs / Radiology    189 K/uL'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Patient was prescribed 5% Dextrose 250mL Bag IV DRIP of total 250 mL
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Patient was prescribed 5% Dextrose 250mL Bag IV of total 250 mL
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.9999999999999997
# ----- Data i -----
# >> Time: 2121-04-01 00:00:00
# >> Type: prescription
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Patient was prescribed Dextrose 50% 50mL Syringe IV of total 12.5 gm
# ----- Data j -----
# >> Time: 2121-04-01 09:29:00
# >> Type: sentence
# >> Concepts: {'Glucose 50 MG/ML Oral Solution', 'glucose'}
# >> Dextrose    50% .'
# **********************************
# ********** Processing data for 2121-04-02 **********
# ***** PAIR INDEX 35 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Left Extremities: (Edema: 1+), (Temperature: Warm), (Pulse - Dorsalis    pedis: Present), (Pulse - Posterior tibial: Present)'
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Right Extremities: (Edema: 1+), (Temperature: Warm), (Pulse - Dorsalis    pedis: Present), (Pulse - Posterior tibial: Present)'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.6324555320336759
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: prescription
# >> Concepts: {'metoprolol', 'Metoprolol'}
# >> Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 12.5 mg
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Lasix', 'Pharmaceutical Preparations', 'Americium', 'metoprolol', 'Metoprolol', 'Infusion procedures'}
# >> uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 0.7171371656006361
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: prescription
# >> Concepts: {'metoprolol', 'Intravenous infusion procedures', 'Metoprolol'}
# >> Patient was prescribed Metoprolol Tartrate 5mg/5mL Vial IV of total 1 mg
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Lasix', 'Pharmaceutical Preparations', 'Americium', 'metoprolol', 'Metoprolol', 'Infusion procedures'}
# >> uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.6324555320336759
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: prescription
# >> Concepts: {'metoprolol', 'Metoprolol'}
# >> Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 12.5 mg
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Lasix', 'Pharmaceutical Preparations', 'Americium', 'metoprolol', 'Metoprolol', 'Infusion procedures'}
# >> uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Hydroxymethylglutaryl-CoA Reductase Inhibitors', 'Aspirin', 'Adrenergic beta-Antagonists', 'aspirin'}
# >>    Cardiovascular: Aspirin, Beta-blocker, Statins, start betablockers,    monitor rhythm'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Hydroxymethylglutaryl-CoA Reductase Inhibitors', 'Aspirin', 'Adrenergic beta-Antagonists', 'aspirin'}
# >>    Cardiovascular: Aspirin, Beta-blocker, Statins, start betablockers,    monitor rhythm'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.29 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Uridine', 'Tube feeding of patient', 'Blood product'}
# >>    Height: 66 Inch             Total In:                                                                   2,515 mL                                                                     648 mL    PO:                                                                     480 mL                                                                     360 mL    Tube feeding:    IV Fluid:                                                                   1,611 mL                                                                     146 mL    Blood products:                                                                     425 mL                                                                     142 mL    Total out:                                                                   1,424 mL                                                                   2,080 mL    Urine:                                                                   1,334 mL                                                                   2,080 mL    NG:    Stool:    Drains:    Balance:                                                                   1,091 mL                                                                  -1,432 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SPO2: 97%'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 3.22 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Uridine', 'Tube feeding of patient', 'Blood product'}
# >>    Height: 66 Inch             Total In:                                                                   2,515 mL                                                                     648 mL    PO:                                                                     480 mL                                                                     360 mL    Tube feeding:    IV Fluid:                                                                   1,611 mL                                                                     146 mL    Blood products:                                                                     425 mL                                                                     142 mL    Total out:                                                                   1,424 mL                                                                   2,080 mL    Urine:                                                                   1,334 mL                                                                   2,080 mL    NG:    Stool:    Drains:    Balance:                                                                   1,091 mL                                                                  -1,432 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SPO2: 97%'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Left Extremities: (Edema: 1+), (Temperature: Warm), (Pulse - Dorsalis    pedis: Present), (Pulse - Posterior tibial: Present)'
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Right Extremities: (Edema: 1+), (Temperature: Warm), (Pulse - Dorsalis    pedis: Present), (Pulse - Posterior tibial: Present)'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 0.7171371656006361
# ----- Data i -----
# >> Time: 2121-04-02 00:00:00
# >> Type: prescription
# >> Concepts: {'metoprolol', 'Intravenous infusion procedures', 'Metoprolol'}
# >> Patient was prescribed Metoprolol Tartrate 5mg/5mL Vial IV of total 1 mg
# ----- Data j -----
# >> Time: 2121-04-02 21:24:00
# >> Type: sentence
# >> Concepts: {'Lasix', 'Pharmaceutical Preparations', 'Americium', 'metoprolol', 'Metoprolol', 'Infusion procedures'}
# >> uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# **********************************
# ********** Processing data for 2121-04-03 **********
# ********** Processing data for 2121-04-04 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                    sentence 1  \
# 2  Patient was prescribed 5% Dextrose 250mL Bag IV DRIP of total 250 mL
# 3  Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 0.5-5.0 mg
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         sentence 2  \
# 2  Dextrose    50% .'
# 3  Ranitidine    24 Hour Events:  INTUBATION - At  [**2121-3-31**]  01:45 PM    received intubated from or  OR RECEIVED - At  [**2121-3-31**]  01:45 PM  ARTERIAL LINE - START  [**2121-3-31**]  01:45 PM  PA CATHETER - START  [**2121-3-31**]  02:00 PM  EKG - At  [**2121-3-31**]  02:00 PM  FEVER - 101.3 C -  [**2121-4-1**]  12:00 AM    Post operative day:    POD#1 - Cabg    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Morphine Sulfate -  [**2121-4-1**]  03:16 AM    Other medications:    Flowsheet Data as of   [**2121-4-1**]  09:27 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
#
#       time 1              time 2        type 1    type 2  \
# 2 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 3 2121-04-01 2121-04-01 09:29:00  prescription  sentence
#
#                                   concepts 1  \
# 2  {Glucose 50 MG/ML Oral Solution, glucose}
# 3  {Morphine Sulfate, morphine sulfate}
#
#                                                                                                                                                                        concepts 2  \
# 2  {Glucose 50 MG/ML Oral Solution, glucose}
# 3  {ranitidine, Americium, Feverall, morphine sulfate, Pharmaceutical Preparations, Arteries, Electrocardiography, Morphine Sulfate, Ranitidine, Intubation, Infusion procedures}
#
#   cosine similarity            semantic type
# 2  1.0               Pharmacologic Substance
# 3  0.617213          Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                                        sentence 1  \
# 2   Patient was prescribed 5% Dextrose 250mL Bag IV DRIP of total 250 mL
# 3   Patient was prescribed Morphine Sulfate 2mg Syringe IV of total 0.5-5.0 mg
# 4   Patient was prescribed Morphine Sulfate 10mg Syringe IV of total 0.5-5.0 mg
# 5   Patient was prescribed Morphine Sulfate 4mg Syringe IV of total 0.5-5.0 mg
# 6   Patient was prescribed Magnesium Sulfate 2 g / 50 mL Premix Bag IV of total 2 gm
# 7   Patient was prescribed Insulin Human Regular 100Units/mL; 10mL Vial IV DRIP of total 100 UNIT
# 8   Patient was prescribed 5% Dextrose 250mL Bag IV of total 250 mL
# 9   Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2 gm
# 10  Patient was prescribed Metoclopramide 5mg/mL-2mL Vial IV of total 10 mg
# 11  Patient was prescribed Oxycodone-Acetaminophen 5mg/325mg Tablet PO of total 1-2 TAB
# 12  Patient was prescribed Acetaminophen 325mg Tablet PO of total 650 mg
# 13  Patient was prescribed Acetaminophen 650mg Supp PR of total 650 mg
# 14  Patient was prescribed Dextrose 50% 50mL Syringe IV of total 12.5 gm
# 15  Patient was prescribed Aspirin 81mg Tab NG of total 81 mg
# 16  Patient was prescribed Aspirin 81mg Tab NG of total 81 mg
# 17  Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 12.5 mg
# 18  Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 25 mg
# 19  Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# 20  Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# 21  Patient was prescribed Furosemide 40mg/4mL Vial IV of total 20 mg
# 22  Patient was prescribed Furosemide 40mg/4mL Vial IV of total 20 mg
# 32  Patient was prescribed 5% Dextrose 250mL Bag IV DRIP of total 250 mL
# 33  Patient was prescribed 5% Dextrose 250mL Bag IV of total 250 mL
# 34  Patient was prescribed Dextrose 50% 50mL Syringe IV of total 12.5 gm
# 36  Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 12.5 mg
# 37  Patient was prescribed Metoprolol Tartrate 5mg/5mL Vial IV of total 1 mg
# 38  Patient was prescribed Metoprolol Tartrate 25mg Tablet PO of total 12.5 mg
# 39  Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# 40  Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# 44  Patient was prescribed Metoprolol Tartrate 5mg/5mL Vial IV of total 1 mg
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          sentence 2  \
# 2   Dextrose    50% .'
# 3   Ranitidine    24 Hour Events:  INTUBATION - At  [**2121-3-31**]  01:45 PM    received intubated from or  OR RECEIVED - At  [**2121-3-31**]  01:45 PM  ARTERIAL LINE - START  [**2121-3-31**]  01:45 PM  PA CATHETER - START  [**2121-3-31**]  02:00 PM  EKG - At  [**2121-3-31**]  02:00 PM  FEVER - 101.3 C -  [**2121-4-1**]  12:00 AM    Post operative day:    POD#1 - Cabg    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Morphine Sulfate -  [**2121-4-1**]  03:16 AM    Other medications:    Flowsheet Data as of   [**2121-4-1**]  09:27 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# 4   Ranitidine    24 Hour Events:  INTUBATION - At  [**2121-3-31**]  01:45 PM    received intubated from or  OR RECEIVED - At  [**2121-3-31**]  01:45 PM  ARTERIAL LINE - START  [**2121-3-31**]  01:45 PM  PA CATHETER - START  [**2121-3-31**]  02:00 PM  EKG - At  [**2121-3-31**]  02:00 PM  FEVER - 101.3 C -  [**2121-4-1**]  12:00 AM    Post operative day:    POD#1 - Cabg    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Morphine Sulfate -  [**2121-4-1**]  03:16 AM    Other medications:    Flowsheet Data as of   [**2121-4-1**]  09:27 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# 5   Ranitidine    24 Hour Events:  INTUBATION - At  [**2121-3-31**]  01:45 PM    received intubated from or  OR RECEIVED - At  [**2121-3-31**]  01:45 PM  ARTERIAL LINE - START  [**2121-3-31**]  01:45 PM  PA CATHETER - START  [**2121-3-31**]  02:00 PM  EKG - At  [**2121-3-31**]  02:00 PM  FEVER - 101.3 C -  [**2121-4-1**]  12:00 AM    Post operative day:    POD#1 - Cabg    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Infusions:    Other ICU medications:    Morphine Sulfate -  [**2121-4-1**]  03:16 AM    Other medications:    Flowsheet Data as of   [**2121-4-1**]  09:27 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# 6   Influenza Virus Vaccine    Ketorolac  Magnesium Sulfate .'
# 7   Insulin .'
# 8   Dextrose    50% .'
# 9   Calcium Gluconate6.'
# 10  Metoclopramide .'
# 11  Oxycodone-Acetaminophen .'
# 12  Oxycodone-Acetaminophen .'
# 13  Oxycodone-Acetaminophen .'
# 14  Dextrose    50% .'
# 15  Aspirin EC5.'
# 16     Cardiovascular: Aspirin, Beta-blocker, Statins'
# 17  Metoprolol Tartrate .'
# 18  Metoprolol Tartrate .'
# 19  Aspirin EC5.'
# 20     Cardiovascular: Aspirin, Beta-blocker, Statins'
# 21  Furosemide .'
# 22  Furosemide .'
# 32  Dextrose    50% .'
# 33  Dextrose    50% .'
# 34  Dextrose    50% .'
# 36  uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# 37  uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# 38  uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# 39     Cardiovascular: Aspirin, Beta-blocker, Statins, start betablockers,    monitor rhythm'
# 40     Cardiovascular: Aspirin, Beta-blocker, Statins, start betablockers,    monitor rhythm'
# 44  uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
#
#        time 1              time 2        type 1    type 2  \
# 2  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 3  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 4  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 5  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 6  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 7  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 8  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 9  2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 10 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 11 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 12 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 13 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 14 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 15 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 16 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 17 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 18 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 19 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 20 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 21 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 22 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 32 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 33 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 34 2121-04-01 2121-04-01 09:29:00  prescription  sentence
# 36 2121-04-02 2121-04-02 21:24:00  prescription  sentence
# 37 2121-04-02 2121-04-02 21:24:00  prescription  sentence
# 38 2121-04-02 2121-04-02 21:24:00  prescription  sentence
# 39 2121-04-02 2121-04-02 21:24:00  prescription  sentence
# 40 2121-04-02 2121-04-02 21:24:00  prescription  sentence
# 44 2121-04-02 2121-04-02 21:24:00  prescription  sentence
#
#                                                                  concepts 1  \
# 2   {Glucose 50 MG/ML Oral Solution, glucose}
# 3   {Morphine Sulfate, morphine sulfate}
# 4   {Morphine Sulfate, morphine sulfate}
# 5   {Morphine Sulfate 4 MG/ML, morphine sulfate}
# 6   {Magnesium Sulfate, magnesium sulfate}
# 7   {brain-derived neurotrophic factor, human, insulin glulisine}
# 8   {Glucose 50 MG/ML Oral Solution, glucose}
# 9   {Intravenous infusion procedures, Calcium Gluconate, calcium gluconate}
# 10  {Intravenous infusion procedures, Metoclopramide, metoclopramide}
# 11  {Acetaminophen / Oxycodone}
# 12  {acetaminophen, Acetaminophen}
# 13  {acetaminophen, Acetaminophen}
# 14  {Glucose 50 MG/ML Oral Solution, glucose}
# 15  {Aspirin, nitroglycerin, aspirin}
# 16  {Aspirin, nitroglycerin, aspirin}
# 17  {metoprolol, Metoprolol}
# 18  {metoprolol, Metoprolol}
# 19  {Aspirin, aspirin}
# 20  {Aspirin, aspirin}
# 21  {Intravenous infusion procedures, Furosemide, furosemide}
# 22  {Intravenous infusion procedures, Furosemide, furosemide}
# 32  {Glucose 50 MG/ML Oral Solution, glucose}
# 33  {Glucose 50 MG/ML Oral Solution, glucose}
# 34  {Glucose 50 MG/ML Oral Solution, glucose}
# 36  {metoprolol, Metoprolol}
# 37  {metoprolol, Intravenous infusion procedures, Metoprolol}
# 38  {metoprolol, Metoprolol}
# 39  {Aspirin, aspirin}
# 40  {Aspirin, aspirin}
# 44  {metoprolol, Intravenous infusion procedures, Metoprolol}
#
#                                                                                                                                                                         concepts 2  \
# 2   {Glucose 50 MG/ML Oral Solution, glucose}
# 3   {ranitidine, Americium, Feverall, morphine sulfate, Pharmaceutical Preparations, Arteries, Electrocardiography, Morphine Sulfate, Ranitidine, Intubation, Infusion procedures}
# 4   {ranitidine, Americium, Feverall, morphine sulfate, Pharmaceutical Preparations, Arteries, Electrocardiography, Morphine Sulfate, Ranitidine, Intubation, Infusion procedures}
# 5   {ranitidine, Americium, Feverall, morphine sulfate, Pharmaceutical Preparations, Arteries, Electrocardiography, Morphine Sulfate, Ranitidine, Intubation, Infusion procedures}
# 6   {ketorolac, Magnesium Sulfate, Vaccines, Ketorolac, magnesium sulfate}
# 7   {insulin glulisine}
# 8   {Glucose 50 MG/ML Oral Solution, glucose}
# 9   {Calcium Gluconate, calcium gluconate}
# 10  {Metoclopramide, metoclopramide}
# 11  {Acetaminophen / Oxycodone}
# 12  {Acetaminophen / Oxycodone}
# 13  {Acetaminophen / Oxycodone}
# 14  {Glucose 50 MG/ML Oral Solution, glucose}
# 15  {Aspirin, aspirin}
# 16  {Hydroxymethylglutaryl-CoA Reductase Inhibitors, Aspirin, Adrenergic beta-Antagonists, aspirin}
# 17  {metoprolol, Metoprolol, tartrate}
# 18  {metoprolol, Metoprolol, tartrate}
# 19  {Aspirin, aspirin}
# 20  {Hydroxymethylglutaryl-CoA Reductase Inhibitors, Aspirin, Adrenergic beta-Antagonists, aspirin}
# 21  {Furosemide, furosemide}
# 22  {Furosemide, furosemide}
# 32  {Glucose 50 MG/ML Oral Solution, glucose}
# 33  {Glucose 50 MG/ML Oral Solution, glucose}
# 34  {Glucose 50 MG/ML Oral Solution, glucose}
# 36  {Lasix, Pharmaceutical Preparations, Americium, metoprolol, Metoprolol, Infusion procedures}
# 37  {Lasix, Pharmaceutical Preparations, Americium, metoprolol, Metoprolol, Infusion procedures}
# 38  {Lasix, Pharmaceutical Preparations, Americium, metoprolol, Metoprolol, Infusion procedures}
# 39  {Hydroxymethylglutaryl-CoA Reductase Inhibitors, Aspirin, Adrenergic beta-Antagonists, aspirin}
# 40  {Hydroxymethylglutaryl-CoA Reductase Inhibitors, Aspirin, Adrenergic beta-Antagonists, aspirin}
# 44  {Lasix, Pharmaceutical Preparations, Americium, metoprolol, Metoprolol, Infusion procedures}
#
#    cosine similarity                        semantic type
# 2   1.0               Pharmacologic Substance
# 3   0.617213          Pharmacologic Substance
# 4   0.617213          Pharmacologic Substance
# 5   0.552052          Pharmacologic Substance
# 6   0.784465          Pharmacologic Substance
# 7   0.534522          Pharmacologic Substance
# 8   1.0               Pharmacologic Substance
# 9   0.852803          Pharmacologic Substance
# 10  0.755929          Pharmacologic Substance
# 11  1.0               Pharmacologic Substance
# 12  0.707107          Pharmacologic Substance
# 13  0.707107          Pharmacologic Substance
# 14  1.0               Pharmacologic Substance
# 15  0.894427          Pharmacologic Substance
# 16  0.53936           Pharmacologic Substance
# 17  0.894427          Pharmacologic Substance
# 18  0.894427          Pharmacologic Substance
# 19  1.0               Pharmacologic Substance
# 20  0.603023          Pharmacologic Substance
# 21  0.755929          Pharmacologic Substance
# 22  0.755929          Pharmacologic Substance
# 32  1.0               Clinical Drug
# 33  1.0               Clinical Drug
# 34  1.0               Clinical Drug
# 36  0.632456          Pharmacologic Substance
# 37  0.717137          Pharmacologic Substance
# 38  0.632456          Pharmacologic Substance
# 39  0.603023          Pharmacologic Substance
# 40  0.603023          Pharmacologic Substance
# 44  0.717137          Therapeutic or Preventive Procedure

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 10
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "Metoclopramide held."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Metoclopramide 5mg/mL-2mL Vial IV of total 10 mg
# sentence 2:	Metoclopramide .'
#
# New contradicting sentence: Metoclopramide held.

# %%
no_contradiction_pair_idx = [13, 14, 39, 44]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed Acetaminophen 650mg Supp PR of total 650 mg
# sentence 2:	Oxycodone-Acetaminophen .'
# *****************************
# prescription 1:	Patient was prescribed Dextrose 50% 50mL Syringe IV of total 12.5 gm
# sentence 2:	Dextrose    50% .'
# *****************************
# prescription 1:	Patient was prescribed Aspirin EC 81mg  EC Tab PO of total 81 mg
# sentence 2:	   Cardiovascular: Aspirin, Beta-blocker, Statins, start betablockers,    monitor rhythm'
# *****************************
# prescription 1:	Patient was prescribed Metoprolol Tartrate 5mg/5mL Vial IV of total 1 mg
# sentence 2:	uneventful or out on    neo/prop    Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2121-4-1**]  10:32 PM    Infusions:    Other ICU medications:    Metoprolol -  [**2121-4-2**]  05:09 AM    Furosemide (Lasix) -  [**2121-4-2**]  11:30 AM    Other medications:    Flowsheet Data as of   [**2121-4-2**]  09:23 PM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**24**]  a.m.'
# *****************************

# %% [markdown]
# ## Patient 8

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[7] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 133857
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2175-03-12 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.6123724356957946
# ----- Data i -----
# >> Time: 2175-03-12 22:31:00
# >> Type: sentence
# >> Concepts: {'Nimodipine', 'nimodipine', 'Infantile Neuroaxonal Dystrophy', 'Dilantin'}
# >>    Neurologic: Goal SBP < 140, Plan for angio tommorow, Nimodipine,    Dilantin, Hob >30 degrees.'
# ----- Data j -----
# >> Time: 2175-03-12 22:31:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >>    Assessment And Plan: 69 year old male admitted with SAH'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-12 00:00:00
# >> Type: prescription
# >> Concepts: {'niCARdipine', 'nicardipine'}
# >> Patient was prescribed NiCARdipine IV 2.5mg/mL;10mL Amp IV DRIP of total 125 mg
# ----- Data j -----
# >> Time: 2175-03-12 22:31:00
# >> Type: sentence
# >> Concepts: {'niCARdipine', 'nicardipine'}
# >> Nicardipine gtt'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2175-03-12 00:00:00
# >> Type: prescription
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
# ----- Data j -----
# >> Time: 2175-03-12 22:31:00
# >> Type: sentence
# >> Concepts: {'Nimodipine', 'nimodipine', 'Infantile Neuroaxonal Dystrophy', 'Dilantin'}
# >>    Neurologic: Goal SBP < 140, Plan for angio tommorow, Nimodipine,    Dilantin, Hob >30 degrees.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2175-03-12 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.63 m/uL.
# ----- Data j -----
# >> Time: 2175-03-12 22:31:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    ICP: 7 (7 - 16) mmHg    Total In:                                                                     952 mL    PO:    TF:    IVF:                                                                     252 mL    Blood products:    Total out:                                                                       0 mL                                                                     640 mL    Urine:                                                                     620 mL    NG:    Stool:    Drains:                                                                      20 mL    Balance:                                                                       0 mL                                                                     312 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2175-03-12 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.87 m/uL.
# ----- Data j -----
# >> Time: 2175-03-12 22:31:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    ICP: 7 (7 - 16) mmHg    Total In:                                                                     952 mL    PO:    TF:    IVF:                                                                     252 mL    Blood products:    Total out:                                                                       0 mL                                                                     640 mL    Urine:                                                                     620 mL    NG:    Stool:    Drains:                                                                      20 mL    Balance:                                                                       0 mL                                                                     312 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 99%'
# **********************************
# ********** Processing data for 2175-03-13 **********
# ***** PAIR INDEX 5 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Left Extremities: (Edema: Absent), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Right Extremities: (Edema: Absent), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin 16.'
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Pain management', 'Ventriculostomy', 'Nimodipine', 'nimodipine', 'Infantile Neuroaxonal Dystrophy', 'Dilantin'}
# >>    Neurologic: Neuro checks Q: 1 hr, ICP monitor, Ventriculostomy, Pain    controlled, Goal SBP < 140, Plan for angio today, Nimodipine, Dilantin,    Hob >30 degrees.'
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Nimodipine 13.'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride'
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride    20.'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.7071067811865476
# ----- Data i -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'fentaNYL', 'Infusion procedures', 'Fentanyl measurement', 'Dilantin'}
# >> Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2175-3-13**]  05:00 AM    Infusions:    Other ICU medications:    Fentanyl -  [**2175-3-12**]  07:45 PM    Midazolam (Versed) -  [**2175-3-12**]  07:55 PM    Dilantin -  [**2175-3-13**]  04:00 AM    Other medications:    Flowsheet Data as of   [**2175-3-13**]  05:13 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**78**]  a.m.'
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'fentaNYL', 'Fentanyl measurement'}
# >> Fentanyl Citrate 10.'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Phenytoin sodium'}
# >> Patient was prescribed Phenytoin Sodium 250mg/5mL Vial IV of total 1000 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Phenytoin sodium'}
# >> Patient was prescribed Phenytoin Sodium 250mg/5mL Vial IV of total 1000 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin 16.'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Patient was prescribed Potassium Chloride 20mEq Packet PO of total 40 mEq
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride    20.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Patient was prescribed Potassium Chloride 20mEq Packet PO of total 40 mEq
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'niCARdipine', 'nicardipine'}
# >> Patient was prescribed NiCARdipine IV 2.5mg/mL;10mL Amp IV DRIP of total 125 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'niCARdipine'}
# >>    Cardiovascular: Goal SBP 100-140.Nicardipine gtt prn'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Patient was prescribed Potassium Chloride 20mEq Packet PO of total 80 mEq
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride    20.'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Patient was prescribed Potassium Chloride 20mEq Packet PO of total 80 mEq
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Patient was prescribed Potassium Chloride 20mEq Packet PO of total 60 mEq
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride    20.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Patient was prescribed Potassium Chloride 20mEq Packet PO of total 60 mEq
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Potassium Chloride'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 0.7559289460184544
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'midazolam', 'Midazolam'}
# >> Patient was prescribed Midazolam 2mg/2mL Vial IV of total 0.5-2 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'midazolam', 'Midazolam'}
# >> Midazolam 12.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.6324555320336758
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Fentanyl Citrate'}
# >> Patient was prescribed Fentanyl Citrate 100mcg/2mL Amp IV of total 25-100 mcg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'fentaNYL', 'Fentanyl measurement'}
# >> Fentanyl Citrate 10.'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'famotidine', 'Famotidine'}
# >> Patient was prescribed Famotidine 20mg Tablet PO of total 20 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'famotidine', 'Famotidine'}
# >> Famotidine 9.'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2-4 gm
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2 gm
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium phosphate'}
# >> Patient was prescribed Potassium Phosphate 3mM/mL-15mL IV of total 30 mmol
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium phosphate'}
# >> Potassium Phosphate 19.'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium phosphate'}
# >> Patient was prescribed Potassium Phosphate 3mM/mL-15mL IV of total 15 mmol
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'potassium phosphate'}
# >> Potassium Phosphate 19.'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2 gm
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Nimodipine 13.'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Pain management', 'Ventriculostomy', 'Nimodipine', 'nimodipine', 'Infantile Neuroaxonal Dystrophy', 'Dilantin'}
# >>    Neurologic: Neuro checks Q: 1 hr, ICP monitor, Ventriculostomy, Pain    controlled, Goal SBP < 140, Plan for angio today, Nimodipine, Dilantin,    Hob >30 degrees.'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Patient was prescribed Acetaminophen 325mg Tablet PO of total 325-650 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Acetaminophen 4.'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Polyvalent pneumococcal vaccine'}
# >> Patient was prescribed Pneumococcal Vac Polyvalent 25mcg/0.5mL Vial IM of total 0.5 mL
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Polyvalent pneumococcal vaccine'}
# >> Pneumococcal Vac Polyvalent 17.'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.7905694150420948
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Bisacodyl 0.333 MG/ML Enema', 'Bisacodyl'}
# >> Patient was prescribed Bisacodyl 10mg Suppository PR of total 10 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'bisacodyl', 'Bisacodyl 5 MG'}
# >> Bisacodyl 5.'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Phenytoin sodium', 'phenytoin sodium'}
# >> Patient was prescribed Phenytoin Sodium 100mg/2mL Vial IV of total 100 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Phenytoin sodium', 'phenytoin sodium'}
# >> Patient was prescribed Phenytoin Sodium 100mg/2mL Vial IV of total 100 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin 16.'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'niCARdipine', 'nicardipine'}
# >> Patient was prescribed NiCARdipine IV 2.5mg/mL;10mL Amp IV DRIP of total 125 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'niCARdipine'}
# >>    Cardiovascular: Goal SBP 100-140.Nicardipine gtt prn'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: lab
# >> Concepts: {'Calcium', 'Calcium Drug Class'}
# >> Patient's Calcium, Total lab came back 8.7 mg/dL.
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: lab
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Patient's Phenytoin lab came back 9.9 ug/mL , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: lab
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Patient's Phenytoin lab came back 9.9 ug/mL , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin 16.'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.42 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Uridine', 'Tube feeding of patient', 'Blood product'}
# >>    ICP: 5 (5 - 16) mmHg    Total In:                                                                   1,105 mL                                                                     499 mL    PO:                                                                     100 mL    Tube feeding:    IV Fluid:                                                                     405 mL                                                                     399 mL    Blood products:    Total out:                                                                     943 mL                                                                   1,241 mL    Urine:                                                                     910 mL                                                                   1,170 mL    NG:    Stool:    Drains:                                                                      33 mL                                                                      71 mL    Balance:                                                                     162 mL                                                                    -742 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SPO2: 100%'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: lab
# >> Concepts: {'Calcium', 'Calcium Drug Class'}
# >> Patient's Calcium, Total lab came back 8.6 mg/dL.
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 6.'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.17 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Uridine', 'Tube feeding of patient', 'Blood product'}
# >>    ICP: 5 (5 - 16) mmHg    Total In:                                                                   1,105 mL                                                                     499 mL    PO:                                                                     100 mL    Tube feeding:    IV Fluid:                                                                     405 mL                                                                     399 mL    Blood products:    Total out:                                                                     943 mL                                                                   1,241 mL    Urine:                                                                     910 mL                                                                   1,170 mL    NG:    Stool:    Drains:                                                                      33 mL                                                                      71 mL    Balance:                                                                     162 mL                                                                    -742 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SPO2: 100%'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Left Extremities: (Edema: Absent), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Bone structure of tibia', 'Limb structure', 'Posterior pituitary disease'}
# >>    Right Extremities: (Edema: Absent), (Temperature: Warm), (Pulse -    Dorsalis pedis: Present), (Pulse - Posterior tibial: Present)'
# **********************************
# ***** PAIR INDEX 45 *****
# Cosine similarity: 0.7071067811865476
# ----- Data i -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'fentaNYL', 'Infusion procedures', 'Fentanyl measurement', 'Dilantin'}
# >> Allergies:    No Known Drug Allergies    Last dose of Antibiotics:    Cefazolin -  [**2175-3-13**]  05:00 AM    Infusions:    Other ICU medications:    Fentanyl -  [**2175-3-12**]  07:45 PM    Midazolam (Versed) -  [**2175-3-12**]  07:55 PM    Dilantin -  [**2175-3-13**]  04:00 AM    Other medications:    Flowsheet Data as of   [**2175-3-13**]  05:13 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                              Since  [**78**]  a.m.'
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'fentaNYL', 'Fentanyl measurement'}
# >> Fentanyl Citrate 10.'
# **********************************
# ***** PAIR INDEX 46 *****
# Cosine similarity: 0.5262348115842176
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: lab
# >> Concepts: {'Activated Partial Thromboplastin Time measurement'}
# >> Patient's PTT lab came back 28.2 sec.
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Infantile Neuroaxonal Dystrophy', 'Improvest', 'glucose', 'Glucose', 'Laboratory test finding', 'Prothrombin time assay'}
# >> improved since admission    Labs / Radiology    122 K/uL    14.2 g/dL    126 mg/dL    0.9 mg/dL    26 mEq/L    3.8 mEq/L    15 mg/dL    106 mEq/L    139 mEq/L    39.8 %    47.8 K/uL         [image002.jpg]                               [**2175-3-12**]   09:32 PM                               [**2175-3-13**]   03:14 AM    WBC    37.1    47.8    Hct    45.5    39.8    Plt    109    122    Creatinine    0.9    0.9    Glucose    145    126    Other labs: PT / PTT / INR:13.6/28.2/1.2, Albumin:4.1 g/dL, Ca:8.7    mg/dL, Mg:1.8 mg/dL, PO4:3.6 mg/dL    Assessment and Plan    ANEURYSM, OTHER    Assessment and Plan: 69 year old male admitted with SAH'
# **********************************
# ***** PAIR INDEX 47 *****
# Cosine similarity: 0.9486832980505137
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Bisacodyl 5 MG'}
# >> Patient was prescribed Bisacodyl 5 mg Tab PO of total 10 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'bisacodyl', 'Bisacodyl 5 MG'}
# >> Bisacodyl 5.'
# **********************************
# ***** PAIR INDEX 48 *****
# Cosine similarity: 0.7905694150420948
# ----- Data i -----
# >> Time: 2175-03-13 00:00:00
# >> Type: prescription
# >> Concepts: {'Bisacodyl 0.333 MG/ML Enema', 'Bisacodyl'}
# >> Patient was prescribed Bisacodyl 10mg Suppository PR of total 10 mg
# ----- Data j -----
# >> Time: 2175-03-13 05:13:00
# >> Type: sentence
# >> Concepts: {'bisacodyl', 'Bisacodyl 5 MG'}
# >> Bisacodyl 5.'
# **********************************
# ********** Processing data for 2175-03-14 **********
# ***** PAIR INDEX 49 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Will discuss with neurosurgery team    liberalizing blood pressure more    Neuro checks Q:1 hour    Pain:controlled (acetaminophen) .'
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Acetaminophen 4.'
# **********************************
# ***** PAIR INDEX 50 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Patient was prescribed Phenytoin 100mg Capsule PO of total 100 mg
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin 15.'
# **********************************
# ***** PAIR INDEX 51 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'famotidine', 'Famotidine'}
# >> Patient was prescribed Famotidine 20mg Premix Bag IV of total 20 mg
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'famotidine', 'Famotidine'}
# >> Famotidine 10.'
# **********************************
# ***** PAIR INDEX 52 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'famotidine', 'Famotidine'}
# >> Patient was prescribed Famotidine 20mg Tablet PO of total 20 mg
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'famotidine', 'Famotidine'}
# >> Famotidine 10.'
# **********************************
# ***** PAIR INDEX 53 *****
# Cosine similarity: 0.6837634587578276
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Calcium', 'Calcium Drug Class', 'gluconate'}
# >> Calcium    Gluconate 7.'
# **********************************
# ***** PAIR INDEX 54 *****
# Cosine similarity: 0.6837634587578276
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2-4 gm
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Calcium', 'Calcium Drug Class', 'gluconate'}
# >> Calcium    Gluconate 7.'
# **********************************
# ***** PAIR INDEX 55 *****
# Cosine similarity: 0.6837634587578276
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2 gm
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Calcium', 'Calcium Drug Class', 'gluconate'}
# >> Calcium    Gluconate 7.'
# **********************************
# ***** PAIR INDEX 56 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium phosphate'}
# >> Patient was prescribed Potassium Phosphate 3mM/mL-15mL IV of total 30 mmol
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'potassium phosphate'}
# >> Potassium Phosphate 17.'
# **********************************
# ***** PAIR INDEX 57 *****
# Cosine similarity: 0.6837634587578276
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Calcium', 'Calcium Drug Class', 'gluconate'}
# >> Calcium    Gluconate 7.'
# **********************************
# ***** PAIR INDEX 58 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium phosphate'}
# >> Patient was prescribed Potassium Phosphate 3mM/mL-15mL IV of total 15 mmol
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'potassium phosphate'}
# >> Potassium Phosphate 17.'
# **********************************
# ***** PAIR INDEX 59 *****
# Cosine similarity: 0.6837634587578276
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Calcium', 'Calcium Drug Class', 'gluconate'}
# >> Calcium    Gluconate 7.'
# **********************************
# ***** PAIR INDEX 60 *****
# Cosine similarity: 0.6837634587578276
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2 gm
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Calcium', 'Calcium Drug Class', 'gluconate'}
# >> Calcium    Gluconate 7.'
# **********************************
# ***** PAIR INDEX 61 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Nimodipine 13.    nicardipine14.'
# **********************************
# ***** PAIR INDEX 62 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Patient was prescribed Acetaminophen 325mg Tablet PO of total 325-650 mg
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Acetaminophen 4.'
# **********************************
# ***** PAIR INDEX 63 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Patient was prescribed Acetaminophen 325mg Tablet PO of total 325-650 mg
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Will discuss with neurosurgery team    liberalizing blood pressure more    Neuro checks Q:1 hour    Pain:controlled (acetaminophen) .'
# **********************************
# ***** PAIR INDEX 64 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Polyvalent pneumococcal vaccine'}
# >> Patient was prescribed Pneumococcal Vac Polyvalent 25mcg/0.5mL Vial IM of total 0.5 mL
# ----- Data j -----
# >> Time: 2175-03-14 07:13:00
# >> Type: sentence
# >> Concepts: {'Polyvalent pneumococcal vaccine'}
# >> Pneumococcal Vac Polyvalent'
# **********************************
# ***** PAIR INDEX 65 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2175-03-14 00:00:00
# >> Type: prescription
# ...
# **********************************
# ***** PAIR INDEX 283 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 7.'
# **********************************
# ***** PAIR INDEX 284 *****
# Cosine similarity: 0.8528028654224417
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Intravenous infusion procedures', 'Calcium Gluconate', 'calcium gluconate'}
# >> Patient was prescribed Calcium Gluconate 1g/10mL Vial IV of total 2 gm
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 7.'
# **********************************
# ***** PAIR INDEX 285 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Nimodipine for vasospam prophylaxis.'
# **********************************
# ***** PAIR INDEX 286 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Nimodipine', 'nimodipine'}
# >> Nimodipine'
# **********************************
# ***** PAIR INDEX 287 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Patient was prescribed Acetaminophen 325mg Tablet PO of total 325-650 mg
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'acetaminophen', 'Acetaminophen'}
# >> Acetaminophen 4.'
# **********************************
# ***** PAIR INDEX 288 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Flushing', 'T8 Keto Flush'}
# >> Patient was prescribed Sodium Chloride 0.9%  Flush Syringe IV of total 3 mL
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Flushing', 'T8 Keto Flush'}
# >> Sodium Chloride 0.9% Flush 23.'
# **********************************
# ***** PAIR INDEX 289 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Polyvalent pneumococcal vaccine'}
# >> Patient was prescribed Pneumococcal Vac Polyvalent 25mcg/0.5mL Vial IM of total 0.5 mL
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Polyvalent pneumococcal vaccine'}
# >> Pneumococcal Vac Polyvalent 18.'
# **********************************
# ***** PAIR INDEX 290 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Bisacodyl 0.333 MG/ML Enema', 'Bisacodyl'}
# >> Patient was prescribed Bisacodyl 10mg Suppository PR of total 10 mg
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'bisacodyl', 'Bisacodyl'}
# >> Bisacodyl 6.'
# **********************************
# ***** PAIR INDEX 291 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Magnesium Sulfate', 'magnesium sulfate'}
# >> Patient was prescribed Magnesium Sulfate 2 g / 50 mL Premix Bag IV of total 2 gm
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Magnesium Sulfate', 'magnesium sulfate'}
# >> Magnesium Sulfate 14.'
# **********************************
# ***** PAIR INDEX 292 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Magnesium Sulfate', 'magnesium sulfate'}
# >> Patient was prescribed Magnesium Sulfate 2 g / 50 mL Premix Bag IV of total 2-4 gm
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Magnesium Sulfate', 'magnesium sulfate'}
# >> Magnesium Sulfate 14.'
# **********************************
# ***** PAIR INDEX 293 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Magnesium Sulfate', 'magnesium sulfate'}
# >> Patient was prescribed Magnesium Sulfate 2 g / 50 mL Premix Bag IV of total 4 gm
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Magnesium Sulfate', 'magnesium sulfate'}
# >> Magnesium Sulfate 14.'
# **********************************
# ***** PAIR INDEX 294 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Patient was prescribed Aspirin 325mg Tablet PO of total 325 mg
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Aspirin 5.'
# **********************************
# ***** PAIR INDEX 295 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Aspirin', 'aspirin'}
# >> Patient was prescribed Aspirin 325mg Tablet PO of total 325 mg
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'aspirin'}
# >>    CVS: ASA.'
# **********************************
# ***** PAIR INDEX 296 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: lab
# >> Concepts: {'Calcium', 'Calcium Drug Class'}
# >> Patient's Calcium, Total lab came back 8.9 mg/dL.
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 7.'
# **********************************
# ***** PAIR INDEX 297 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: lab
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Patient's Phenytoin lab came back 7.4 ug/mL , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin 17.'
# **********************************
# ***** PAIR INDEX 298 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: lab
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Patient's Phenytoin lab came back 7.4 ug/mL , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Phenytoin', 'phenytoin'}
# >> Phenytoin 16.'
# **********************************
# ***** PAIR INDEX 299 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.23 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Uridine', 'Tube feeding of patient', 'Blood product'}
# >>    ICP: 5 (1 - 22) mmHg    Total In:                                                                   1,380 mL                                                                     100 mL    PO:                                                                     830 mL    Tube feeding:    IV Fluid:                                                                     550 mL                                                                     100 mL    Blood products:    Total out:                                                                   1,453 mL                                                                     737 mL    Urine:                                                                   1,220 mL                                                                     645 mL    NG:    Stool:    Drains:                                                                     233 mL                                                                      92 mL    Balance:                                                                     -73 mL                                                                    -637 mL    Respiratory support    O2 Delivery Device: None    SPO2: 99%'
# **********************************
# ***** PAIR INDEX 300 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: lab
# >> Concepts: {'Calcium', 'Calcium Drug Class'}
# >> Patient's Calcium, Total lab came back 8.7 mg/dL.
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Calcium Gluconate', 'calcium gluconate'}
# >> Calcium Gluconate 7.'
# **********************************
# ***** PAIR INDEX 301 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Ventriculostomy'}
# >>    ID: Ancef while ventriculostomy in.'
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Ventriculostomy'}
# >>    HEENT: PERRL, ventriculostomy drain in place (unclamped)'
# **********************************
# ***** PAIR INDEX 302 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Ventriculostomy'}
# >>    TLD: Foley, PIV, ventriculostomy'
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Ventriculostomy'}
# >>    HEENT: PERRL, ventriculostomy drain in place (unclamped)'
# **********************************
# ***** PAIR INDEX 303 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Ventriculostomy'}
# >>    TLD: Foley, PIV, ventriculostomy'
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Ventriculostomy'}
# >>    ID: Ancef while ventriculostomy in.'
# **********************************
# ***** PAIR INDEX 304 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: lab
# >> Concepts: {'Activated Partial Thromboplastin Time measurement'}
# >> Patient's PTT lab came back 38.5 sec , which is abnormal.
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding', 'Prothrombin time assay', 'evening primrose oil', 'Feverall', 'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Fever', 'Infantile Neuroaxonal Dystrophy', 'hyperthermia treatment'}
# >> 44.3    53.9    45.0    Hct    39.4    37.8    40.8    39.3    41.1    38.9    37.5    Plt    101    105    107    111    98    112    95    Creatinine    1.0    1.0    1.0    0.9    0.9    1.0    0.8    Glucose    119    127    114    174    112    119    129    133    122    118    Other labs: PT / PTT / INR:14.5/38.5/1.3, Differential-Neuts:33.0 %,    Band:0.0 %, Lymph:57.0 %, Mono:0.0 %, Eos:0.0 %, Albumin:4.0 g/dL,    Ca:8.9 mg/dL, Mg:2.0 mg/dL, PO4:2.7 mg/dL    Assessment and Plan    FEVER (HYPERTHERMIA, PYREXIA, NOT FEVER OF UNKNOWN ORIGIN), ANEURYSM,    OTHER    Assessment and Plan: 69M with ACA aneurysm s/p ventriculostomy drain,    s/p angio/coiling.'
# **********************************
# ***** PAIR INDEX 305 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Flushing', 'T8 Keto Flush'}
# >> Patient was prescribed Sodium Chloride 0.9%  Flush Syringe IV of total 3 mL
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Flushing', 'T8 Keto Flush'}
# >> Sodium Chloride 0.9% Flush 23.'
# **********************************
# ***** PAIR INDEX 306 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Flushing', 'T8 Keto Flush'}
# >> Patient was prescribed Sodium Chloride 0.9%  Flush Syringe IV of total 3 mL
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'Flushing', 'T8 Keto Flush'}
# >> Sodium Chloride 0.9% Flush 23.'
# **********************************
# ***** PAIR INDEX 307 *****
# Cosine similarity: 0.7139328934618736
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'kalium', 'Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution'}
# >> Patient was prescribed Potassium Chl 20 mEq / 1000 mL NS 1000 mL Bag IV of total 1000 mL
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'sodium chloride 0.124 MEQ/ML Oral Solution'}
# >> ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# **********************************
# ***** PAIR INDEX 308 *****
# Cosine similarity: 0.5773502691896257
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection', 'Potassium Chloride 2 MEQ/ML'}
# >> Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 40 mEq
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'sodium chloride 0.124 MEQ/ML Oral Solution'}
# >> ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# **********************************
# ***** PAIR INDEX 309 *****
# Cosine similarity: 0.5773502691896257
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection', 'Potassium Chloride 2 MEQ/ML'}
# >> Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 60 mEq
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'sodium chloride 0.124 MEQ/ML Oral Solution'}
# >> ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# **********************************
# ***** PAIR INDEX 310 *****
# Cosine similarity: 0.6896665621656937
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution', '100 ML Potassium Chloride 0.1 MEQ/ML Injection', 'Potassium Chloride 2 MEQ/ML'}
# >> Patient was prescribed Potassium Chloride 10mEq/100mL Premix IV of total 20 mEq
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'sodium chloride 0.124 MEQ/ML Oral Solution'}
# >> ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# **********************************
# ***** PAIR INDEX 311 *****
# Cosine similarity: 0.5773502691896257
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection', 'Potassium Chloride 2 MEQ/ML'}
# >> Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 40 mEq
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'sodium chloride 0.124 MEQ/ML Oral Solution'}
# >> ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# **********************************
# ***** PAIR INDEX 312 *****
# Cosine similarity: 0.5039526306789696
# ----- Data i -----
# >> Time: 2175-03-20 00:00:00
# >> Type: prescription
# >> Concepts: {'1000 ML Sodium Chloride 9 MG/ML Injection'}
# >> Patient was prescribed 0.9% Sodium Chloride 1000mL Bag IV of total 1000 mL
# ----- Data j -----
# >> Time: 2175-03-20 06:58:00
# >> Type: sentence
# >> Concepts: {'sodium chloride 0.124 MEQ/ML Oral Solution'}
# >> ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# **********************************
# ********** Processing data for 2175-03-21 **********
# ********** Processing data for 2175-03-22 **********
# ********** Processing data for 2175-03-23 **********
# ********** Processing data for 2175-03-24 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                         sentence 1  \
# 1  Patient was prescribed NiCARdipine IV 2.5mg/mL;10mL Amp IV DRIP of total 125 mg
# 2  Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
#
#                                                                                            sentence 2  \
# 1  Nicardipine gtt'
# 2     Neurologic: Goal SBP < 140, Plan for angio tommorow, Nimodipine,    Dilantin, Hob >30 degrees.'
#
#       time 1              time 2        type 1    type 2  \
# 1 2175-03-12 2175-03-12 22:31:00  prescription  sentence
# 2 2175-03-12 2175-03-12 22:31:00  prescription  sentence
#
#                    concepts 1  \
# 1  {niCARdipine, nicardipine}
# 2  {Nimodipine, nimodipine}
#
#                                                             concepts 2  \
# 1  {niCARdipine, nicardipine}
# 2  {Nimodipine, nimodipine, Infantile Neuroaxonal Dystrophy, Dilantin}
#
#   cosine similarity            semantic type
# 1  1.0               Pharmacologic Substance
# 2  0.707107          Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                           sentence 1  \
# 1    Patient was prescribed NiCARdipine IV 2.5mg/mL;10mL Amp IV DRIP of total 125 mg
# 2    Patient was prescribed Nimodipine 30mg Capsule PO of total 60 mg
# 10   Patient was prescribed Phenytoin Sodium 250mg/5mL Vial IV of total 1000 mg
# 11   Patient was prescribed Phenytoin Sodium 250mg/5mL Vial IV of total 1000 mg
# 12   Patient was prescribed Potassium Chloride 20mEq Packet PO of total 40 mEq
# ..                                                                         ...
# 308  Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 40 mEq
# 309  Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 60 mEq
# 310  Patient was prescribed Potassium Chloride 10mEq/100mL Premix IV of total 20 mEq
# 311  Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 40 mEq
# 312  Patient was prescribed 0.9% Sodium Chloride 1000mL Bag IV of total 1000 mL
#
#                                                                                              sentence 2  \
# 1    Nicardipine gtt'
# 2       Neurologic: Goal SBP < 140, Plan for angio tommorow, Nimodipine,    Dilantin, Hob >30 degrees.'
# 10   Phenytoin'
# 11   Phenytoin 16.'
# 12   Potassium Chloride    20.'
# ..                          ...
# 308  ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# 309  ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# 310  ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# 311  ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# 312  ?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
#
#         time 1              time 2        type 1    type 2  \
# 1   2175-03-12 2175-03-12 22:31:00  prescription  sentence
# 2   2175-03-12 2175-03-12 22:31:00  prescription  sentence
# 10  2175-03-13 2175-03-13 05:13:00  prescription  sentence
# 11  2175-03-13 2175-03-13 05:13:00  prescription  sentence
# 12  2175-03-13 2175-03-13 05:13:00  prescription  sentence
# ..         ...                 ...           ...       ...
# 308 2175-03-20 2175-03-20 06:58:00  prescription  sentence
# 309 2175-03-20 2175-03-20 06:58:00  prescription  sentence
# 310 2175-03-20 2175-03-20 06:58:00  prescription  sentence
# 311 2175-03-20 2175-03-20 06:58:00  prescription  sentence
# 312 2175-03-20 2175-03-20 06:58:00  prescription  sentence
#
#                                                                                                                                                                                                                                                       concepts 1  \
# 1    {niCARdipine, nicardipine}
# 2    {Nimodipine, nimodipine}
# 10   {Phenytoin sodium}
# 11   {Phenytoin sodium}
# 12   {potassium chloride, Potassium Chloride}
# ..                                        ...
# 308  {Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection, Potassium Chloride 2 MEQ/ML}
# 309  {Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection, Potassium Chloride 2 MEQ/ML}
# 310  {Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution, 100 ML Potassium Chloride 0.1 MEQ/ML Injection, Potassium Chloride 2 MEQ/ML}
# 311  {Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection, Potassium Chloride 2 MEQ/ML}
# 312  {1000 ML Sodium Chloride 9 MG/ML Injection}
#
#                                                               concepts 2  \
# 1    {niCARdipine, nicardipine}
# 2    {Nimodipine, nimodipine, Infantile Neuroaxonal Dystrophy, Dilantin}
# 10   {Phenytoin, phenytoin}
# 11   {Phenytoin, phenytoin}
# 12   {potassium chloride, Potassium Chloride}
# ..                                        ...
# 308  {sodium chloride 0.124 MEQ/ML Oral Solution}
# 309  {sodium chloride 0.124 MEQ/ML Oral Solution}
# 310  {sodium chloride 0.124 MEQ/ML Oral Solution}
# 311  {sodium chloride 0.124 MEQ/ML Oral Solution}
# 312  {sodium chloride 0.124 MEQ/ML Oral Solution}
#
#     cosine similarity            semantic type
# 1    1.0               Pharmacologic Substance
# 2    0.707107          Pharmacologic Substance
# 10   0.707107          Pharmacologic Substance
# 11   0.707107          Pharmacologic Substance
# 12   1.0               Pharmacologic Substance
# ..   ...                                   ...
# 308  0.57735           Clinical Drug
# 309  0.57735           Clinical Drug
# 310  0.689667          Clinical Drug
# 311  0.57735           Clinical Drug
# 312  0.503953          Clinical Drug
#
# [226 rows x 10 columns]

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 10
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "Phenytoin not given."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Phenytoin Sodium 250mg/5mL Vial IV of total 1000 mg
# sentence 2:	Phenytoin'
#
# New contradicting sentence: Phenytoin not given.

# %%
no_contradiction_pair_idx = [1, 309]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed NiCARdipine IV 2.5mg/mL;10mL Amp IV DRIP of total 125 mg
# sentence 2:	Nicardipine gtt'
# *****************************
# prescription 1:	Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 60 mEq
# sentence 2:	?Cerebral Salt wasting, NaCl started,    sodium mildly improved today.'
# *****************************

# %% [markdown]
# ## Patient 9

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[8] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 166389
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2196-10-13 **********
# ********** Processing data for 2196-10-14 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> # Hyponatremia: No clear baseline.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'Hyponatremia'}
# >> Hyponatremia    HPI:    89 yo M admitted to medicine for hyponatremia of 114.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> Given hyponatremia, this is concerning for    new mental status changes, however, attention intact.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'Hyponatremia'}
# >> Hyponatremia    HPI:    89 yo M admitted to medicine for hyponatremia of 114.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> Given hyponatremia, this is concerning for    new mental status changes, however, attention intact.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> # Hyponatremia: No clear baseline.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Infusion procedures'}
# >> A PICC was    placed; he is transferred to the MICU for hypertonic saline infusion.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Line of Therapy', 'Kidney'}
# >> Discussed with Renal again as Na 119 prior to starting tx with    3% saline and concern for indication for hypertonic saline; given pt    ongoing confusion Renal attending recommends initiating hypertonic    saline therapy at this time.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >>    Drugs: None'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'Hyponatremia'}
# >> Hyponatremia    HPI:    89 yo M admitted to medicine for hyponatremia of 114.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >> He is alert and oriented, but unable to describe his medical conditions    or recount his medications.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations', 'Hyponatremia'}
# >> Hyponatremia    HPI:    89 yo M admitted to medicine for hyponatremia of 114.'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >> He is alert and oriented, but unable to describe his medical conditions    or recount his medications.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >>    Drugs: None'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin Flush (10 units/ml) 10 Units/mL - 5 mL Syringe IV of total 2 mL
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'subcutaneous heparin'}
# >> # Prophylaxis: Subutaneous heparin    .'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'subcutaneous heparin'}
# >> # Prophylaxis: Subutaneous heparin    .'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.5078333750770082
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: prescription
# >> Concepts: {'potassium chloride', 'Potassium Chloride'}
# >> Patient was prescribed Potassium Chloride 20mEq Packet PO of total 60 mEq
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution', 'Fertilization in Vitro'}
# >> He received IVF, 60    mEq of KCL, and was free water restricted.'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'subcutaneous heparin'}
# >> # Prophylaxis: Subutaneous heparin    .'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 2.9 mEq/L , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> TTKG -    (39 x 234) / (2.9 x 346) is 9 - suggesting significant renal loss of    potassium.'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 3.1 mEq/L , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> TTKG -    (39 x 234) / (2.9 x 346) is 9 - suggesting significant renal loss of    potassium.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.14 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 22 (19 - 22) insp/min    SpO2: 99%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 73 kg (admission): 73 kg                   Total In:                   PO:                   TF:    IVF:    Blood products:    Total out:                                                                       0 mL                                                                   1,080 mL    Urine:    80 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                  -1,080 mL    Respiratory    O2 Delivery Device: None    SpO2: 99%    Physical Examination'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.14 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Blood Stop'}
# >> Denies any blood    in his stool.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.6324555320336759
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'folate'}
# >> Patient's Folate lab came back 11.2 ng/mL.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'folate', 'Folate', 'iron', 'Scientific Study', 'Iron'}
# >> - Guaiac all stools    - Iron, B12, folate, TSh studies    - Continue to follow    .'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 4.0 mEq/L.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> TTKG -    (39 x 234) / (2.9 x 346) is 9 - suggesting significant renal loss of    potassium.'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 3.8 mEq/L.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> TTKG -    (39 x 234) / (2.9 x 346) is 9 - suggesting significant renal loss of    potassium.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.23 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 22 (19 - 22) insp/min    SpO2: 99%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 73 kg (admission): 73 kg                   Total In:                   PO:                   TF:    IVF:    Blood products:    Total out:                                                                       0 mL                                                                   1,080 mL    Urine:    80 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                  -1,080 mL    Respiratory    O2 Delivery Device: None    SpO2: 99%    Physical Examination'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.23 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Blood Stop'}
# >> Denies any blood    in his stool.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 0.5103103630798288
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Fatigue', 'Nose', 'Pharyngeal structure'}
# >>    Constitutional: Fatigue    Ear, Nose, Throat: Dry mouth'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'acute stress', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Well nourished, No acute distress    Eyes / Conjunctiva: PERRL, EOMI no nystagmus    Head, Ears, Nose, Throat: Normocephalic, dry MM'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Infusion procedures'}
# >> A PICC was    placed; he is transferred to the MICU for hypertonic saline infusion.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Line of Therapy', 'Kidney'}
# >> Discussed with Renal again as Na 119 prior to starting tx with    3% saline and concern for indication for hypertonic saline; given pt    ongoing confusion Renal attending recommends initiating hypertonic    saline therapy at this time.'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 0.75
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Prothrombin time assay'}
# >> Pt evaluated by Renal, recs for 3%    saline.'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Hematuria', 'Prothrombin time assay'}
# >> # Hematuria: Pt was pulling on his foley catheter earlier.'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'Phosphate measurement'}
# >> Patient's Phosphate lab came back 2.9 mg/dL.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Phosphate measurement'}
# >> - Replete prn to K of 4, Mag of 2    - Replete phos    .'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'Phosphate measurement'}
# >> Patient's Phosphate lab came back 1.5 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Phosphate measurement'}
# >> - Replete prn to K of 4, Mag of 2    - Replete phos    .'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: lab
# >> Concepts: {'Phosphate measurement'}
# >> Patient's Phosphate lab came back 1.6 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Phosphate measurement'}
# >> - Replete prn to K of 4, Mag of 2    - Replete phos    .'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding', 'Denorex Extra Strength'}
# >>    Neurologic: Attentive, Follows simple commands, Responds to: Verbal    stimuli, Oriented (to): x2-3, Movement: strength 5/5 upper and lower    ext bilaterally, Tone: Normal    Labs / Radiology'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >> 4.0    117         [image002.jpg]    Other labs: Ca++:8.5, Mg++:2.0, PO4:1.5'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.5103103630798288
# ----- Data i -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Fatigue', 'Nose', 'Pharyngeal structure'}
# >>    Constitutional: Fatigue    Ear, Nose, Throat: Dry mouth'
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'acute stress', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Well nourished, No acute distress    Eyes / Conjunctiva: PERRL, EOMI no nystagmus    Head, Ears, Nose, Throat: Normocephalic, dry MM'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.8059925931113612
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: prescription
# >> Concepts: {'Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection', 'Potassium Chloride 2 MEQ/ML'}
# >> Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 40 mEq
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution', 'Fertilization in Vitro'}
# >> He received IVF, 60    mEq of KCL, and was free water restricted.'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 0.5078333750770082
# ----- Data i -----
# >> Time: 2196-10-14 00:00:00
# >> Type: prescription
# >> Concepts: {'sodium chloride 3%'}
# >> Patient was prescribed Sodium Chloride 3% (Hypertonic) 500 mL Bag IV of total 500 mL
# ----- Data j -----
# >> Time: 2196-10-14 22:36:00
# >> Type: sentence
# >> Concepts: {'potassium chloride', 'Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution', 'Fertilization in Vitro'}
# >> He received IVF, 60    mEq of KCL, and was free water restricted.'
# **********************************
# ********** Processing data for 2196-10-15 **********
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.5303300858899106
# ----- Data i -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Infantile Neuroaxonal Dystrophy'}
# >> Given that, renal was consulted with plan for hypertonic    saline.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Fluid restriction', 'Infantile Neuroaxonal Dystrophy', 'Prothrombin time assay'}
# >> Pt was admitted to medical    floor and plan for fluid restriction.'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.6123724356957946
# ----- Data i -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Infantile Neuroaxonal Dystrophy'}
# >> Given that, renal was consulted with plan for hypertonic    saline.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Imaging Techniques', 'Lung', 'Infantile Neuroaxonal Dystrophy'}
# >>    Imaging: CXR:  clear lungs    Assessment and Plan    89 y.o.'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> # Hyponatremia: No clear baseline.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> Hyponatremia    HPI:    89M p/w yesterday with confusion, Na=113.'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.5303300858899106
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hematuria', 'Prothrombin time assay'}
# >> # Hematuria: Pt was pulling on his foley catheter earlier.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Fluid restriction', 'Infantile Neuroaxonal Dystrophy', 'Prothrombin time assay'}
# >> Pt was admitted to medical    floor and plan for fluid restriction.'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> Given hyponatremia, this is concerning for    new mental status changes, however, attention intact.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> Hyponatremia    HPI:    89M p/w yesterday with confusion, Na=113.'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> Given hyponatremia, this is concerning for    new mental status changes, however, attention intact.'
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> # Hyponatremia: No clear baseline.'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.5000000000000001
# ----- Data i -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic'}
# >> --Continue to hold hypertonic saline.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Hydrochlorothiazide 50 MG Oral Tablet', 'hydrochlorothiazide', 'Hyponatremia'}
# >> 1) Hyponatremia:    --Improving with cessation of HCTZ and 2 hours of hypertonic saline.'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 0.9271050693011064
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 27 (17 - 28) insp/min    SpO2: 99%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 73 kg (admission): 73 kg              Total In:                                                                     103 mL                                                                      53 mL    PO:                                                                      80 mL              TF:    IVF:                                                                      23 mL                                                                      53 mL    Blood products:    Total out:                                                                   1,320 mL                                                                   1,480 mL    Urine:                                                                     320 mL                                                                   1,480 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,217 mL                                                                  -1,427 mL    Respiratory support    O2 Delivery Device: None    SpO2: 99%'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Sinus Tachycardia', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 17 (17 - 28) insp/min    SpO2: 99%    Heart rhythm: ST (Sinus Tachycardia)    Wgt (current): 73 kg (admission): 73 kg              Total In:                                                                     103 mL                                                                     103 mL    PO:                                                                      80 mL                                                                      50 mL    TF:    IVF:                                                                      23 mL                                                                      53 mL    Blood products:    Total out:                                                                   1,320 mL                                                                   1,760 mL    Urine:                                                                     320 mL                                                                   1,760 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,217 mL                                                                  -1,657 mL    Respiratory support    O2 Delivery Device: None    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.5000000000000001
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Saline Solution, Hypertonic', 'Americium', 'Restriction of oral free water', 'Happy Cappy'}
# >> - Free water restriction to 1L  per day    - infuse 3% NS at 20cc/hr via PICC, with goal of increasing  [**1-13**]     mEq/hour or <12 mEq/24 hrs (Renal will be happy with Na 123-125)    - Check Na q 2-3h    - Na reached 121 so 3% stopped  subsequent Na 127 this AM    - Hold on any further hypertonic saline    .', "# Mental status change: Unclear what patient's baseline is."
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic'}
# >> --Continue to hold hypertonic saline.'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 0.6546536707079772
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Line of Therapy', 'Kidney'}
# >> Discussed with Renal again as Na 119 prior to starting tx with    3% saline and concern for indication for hypertonic saline; given pt    ongoing confusion Renal attending recommends initiating hypertonic    saline therapy at this time.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic'}
# >> --Continue to hold hypertonic saline.'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 0.545544725589981
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Line of Therapy', 'Kidney'}
# >> Discussed with Renal again as Na 119 prior to starting tx with    3% saline and concern for indication for hypertonic saline; given pt    ongoing confusion Renal attending recommends initiating hypertonic    saline therapy at this time.'
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Saline Solution, Hypertonic', 'Americium', 'Restriction of oral free water', 'Happy Cappy'}
# >> - Free water restriction to 1L  per day    - infuse 3% NS at 20cc/hr via PICC, with goal of increasing  [**1-13**]     mEq/hour or <12 mEq/24 hrs (Renal will be happy with Na 123-125)    - Check Na q 2-3h    - Na reached 121 so 3% stopped  subsequent Na 127 this AM    - Hold on any further hypertonic saline    .', "# Mental status change: Unclear what patient's baseline is."
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2196-10-15 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'subcutaneous heparin'}
# >> # Prophylaxis: Subcutaneous heparin    .'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2196-10-15 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.33 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 27 (17 - 28) insp/min    SpO2: 99%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 73 kg (admission): 73 kg              Total In:                                                                     103 mL                                                                      53 mL    PO:                                                                      80 mL              TF:    IVF:                                                                      23 mL                                                                      53 mL    Blood products:    Total out:                                                                   1,320 mL                                                                   1,480 mL    Urine:                                                                     320 mL                                                                   1,480 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,217 mL                                                                  -1,427 mL    Respiratory support    O2 Delivery Device: None    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2196-10-15 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.33 m/uL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Blood Stop'}
# >> Denies any blood    in his stool.'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-15 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 3.3 mEq/L.
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> TTKG -    (39 x 234) / (2.9 x 346) is 9 - suggesting significant renal loss of    potassium.'
# **********************************
# ***** PAIR INDEX 45 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2196-10-15 00:00:00
# >> Type: lab
# >> Concepts: {'kalium'}
# >> Patient's Potassium lab came back 3.6 mEq/L.
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'kalium'}
# >> TTKG -    (39 x 234) / (2.9 x 346) is 9 - suggesting significant renal loss of    potassium.'
# **********************************
# ***** PAIR INDEX 46 *****
# Cosine similarity: 0.6123724356957946
# ----- Data i -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Infantile Neuroaxonal Dystrophy'}
# >> Given that, renal was consulted with plan for hypertonic    saline.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Imaging Techniques', 'Lung', 'Infantile Neuroaxonal Dystrophy'}
# >>    Imaging: CXR:  clear lungs    Assessment and Plan    89 y.o.'
# **********************************
# ***** PAIR INDEX 47 *****
# Cosine similarity: 0.545544725589981
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Line of Therapy', 'Kidney'}
# >> Discussed with Renal again as Na 119 prior to starting tx with    3% saline and concern for indication for hypertonic saline; given pt    ongoing confusion Renal attending recommends initiating hypertonic    saline therapy at this time.'
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Saline Solution, Hypertonic', 'Americium', 'Restriction of oral free water', 'Happy Cappy'}
# >> - Free water restriction to 1L  per day    - infuse 3% NS at 20cc/hr via PICC, with goal of increasing  [**1-13**]     mEq/hour or <12 mEq/24 hrs (Renal will be happy with Na 123-125)    - Check Na q 2-3h    - Na reached 121 so 3% stopped  subsequent Na 127 this AM    - Hold on any further hypertonic saline    .', "# Mental status change: Unclear what patient's baseline is."
# **********************************
# ***** PAIR INDEX 48 *****
# Cosine similarity: 0.9271050693011064
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 27 (17 - 28) insp/min    SpO2: 99%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 73 kg (admission): 73 kg              Total In:                                                                     103 mL                                                                      53 mL    PO:                                                                      80 mL              TF:    IVF:                                                                      23 mL                                                                      53 mL    Blood products:    Total out:                                                                   1,320 mL                                                                   1,480 mL    Urine:                                                                     320 mL                                                                   1,480 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,217 mL                                                                  -1,427 mL    Respiratory support    O2 Delivery Device: None    SpO2: 99%'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Sinus Tachycardia', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 17 (17 - 28) insp/min    SpO2: 99%    Heart rhythm: ST (Sinus Tachycardia)    Wgt (current): 73 kg (admission): 73 kg              Total In:                                                                     103 mL                                                                     103 mL    PO:                                                                      80 mL                                                                      50 mL    TF:    IVF:                                                                      23 mL                                                                      53 mL    Blood products:    Total out:                                                                   1,320 mL                                                                   1,760 mL    Urine:                                                                     320 mL                                                                   1,760 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,217 mL                                                                  -1,657 mL    Respiratory support    O2 Delivery Device: None    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 49 *****
# Cosine similarity: 0.545544725589981
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Saline Solution, Hypertonic', 'Line of Therapy', 'Kidney'}
# >> Discussed with Renal again as Na 119 prior to starting tx with    3% saline and concern for indication for hypertonic saline; given pt    ongoing confusion Renal attending recommends initiating hypertonic    saline therapy at this time.'
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Saline Solution, Hypertonic', 'Americium', 'Restriction of oral free water', 'Happy Cappy'}
# >> - Free water restriction to 1L  per day    - infuse 3% NS at 20cc/hr via PICC, with goal of increasing  [**1-13**]     mEq/hour or <12 mEq/24 hrs (Renal will be happy with Na 123-125)    - Check Na q 2-3h    - Na reached 121 so 3% stopped  subsequent Na 127 this AM    - Hold on any further hypertonic saline    .', "# Mental status change: Unclear what patient's baseline is."
# **********************************
# ***** PAIR INDEX 50 *****
# Cosine similarity: 0.6123724356957946
# ----- Data i -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay'}
# >> Pt was transferred to MICU for this.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Fluid restriction', 'Infantile Neuroaxonal Dystrophy', 'Prothrombin time assay'}
# >> Pt was admitted to medical    floor and plan for fluid restriction.'
# **********************************
# ***** PAIR INDEX 51 *****
# Cosine similarity: 0.5303300858899106
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hematuria', 'Prothrombin time assay'}
# >> # Hematuria: Pt was pulling on his foley catheter earlier.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Fluid restriction', 'Infantile Neuroaxonal Dystrophy', 'Prothrombin time assay'}
# >> Pt was admitted to medical    floor and plan for fluid restriction.'
# **********************************
# ***** PAIR INDEX 52 *****
# Cosine similarity: 0.8660254037844388
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hematuria', 'Prothrombin time assay'}
# >> # Hematuria: Pt was pulling on his foley catheter earlier.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay'}
# >> Pt was transferred to MICU for this.'
# **********************************
# ***** PAIR INDEX 53 *****
# Cosine similarity: 0.5303300858899106
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Prothrombin time assay'}
# >> Pt evaluated by Renal, recs for 3%    saline.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Fluid restriction', 'Infantile Neuroaxonal Dystrophy', 'Prothrombin time assay'}
# >> Pt was admitted to medical    floor and plan for fluid restriction.'
# **********************************
# ***** PAIR INDEX 54 *****
# Cosine similarity: 0.8660254037844388
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Prothrombin time assay'}
# >> Pt evaluated by Renal, recs for 3%    saline.'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Prothrombin time assay'}
# >> Pt was transferred to MICU for this.'
# **********************************
# ***** PAIR INDEX 55 *****
# Cosine similarity: 0.75
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Prothrombin time assay'}
# >> Pt evaluated by Renal, recs for 3%    saline.'
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Hematuria', 'Prothrombin time assay'}
# >> # Hematuria: Pt was pulling on his foley catheter earlier.'
# **********************************
# ***** PAIR INDEX 56 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2196-10-15 00:00:00
# >> Type: lab
# >> Concepts: {'Phosphate measurement'}
# >> Patient's Phosphate lab came back 2.0 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Phosphate measurement'}
# >> - Replete prn to K of 4, Mag of 2    - Replete phos    .'
# **********************************
# ***** PAIR INDEX 57 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Extx: wd/wp, no edema    Labs / Radiology    277 K/uL'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: Responds to: Not assessed, Movement: Not assessed, Tone:    Not assessed    Labs / Radiology'
# **********************************
# ***** PAIR INDEX 58 *****
# Cosine similarity: 0.9271050693011064
# ----- Data i -----
# >> Time: 2196-10-15 06:46:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'strontium', 'Uridine', 'Blood product'}
# >>    RR: 27 (17 - 28) insp/min    SpO2: 99%    Heart rhythm: SR (Sinus Rhythm)    Wgt (current): 73 kg (admission): 73 kg              Total In:                                                                     103 mL                                                                      53 mL    PO:                                                                      80 mL              TF:    IVF:                                                                      23 mL                                                                      53 mL    Blood products:    Total out:                                                                   1,320 mL                                                                   1,480 mL    Urine:                                                                     320 mL                                                                   1,480 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,217 mL                                                                  -1,427 mL    Respiratory support    O2 Delivery Device: None    SpO2: 99%'
# ----- Data j -----
# >> Time: 2196-10-15 09:05:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Sinus Tachycardia', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    RR: 17 (17 - 28) insp/min    SpO2: 99%    Heart rhythm: ST (Sinus Tachycardia)    Wgt (current): 73 kg (admission): 73 kg              Total In:                                                                     103 mL                                                                     103 mL    PO:                                                                      80 mL                                                                      50 mL    TF:    IVF:                                                                      23 mL                                                                      53 mL    Blood products:    Total out:                                                                   1,320 mL                                                                   1,760 mL    Urine:                                                                     320 mL                                                                   1,760 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,217 mL                                                                  -1,657 mL    Respiratory support    O2 Delivery Device: None    SpO2: 99%'
# **********************************
# ********** Processing data for 2196-10-16 **********
# ********** Processing data for 2196-10-17 **********
# ********** Processing data for 2196-10-18 **********
# ********** Processing data for 2196-10-19 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
#                                                                                        sentence 1  \
# 7  Patient was prescribed Heparin Flush (10 units/ml) 10 Units/mL - 5 mL Syringe IV of total 2 mL
# 8  Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
#
#                                  sentence 2     time 1              time 2  \
# 7  # Prophylaxis: Subutaneous heparin    .' 2196-10-14 2196-10-14 22:36:00
# 8  # Prophylaxis: Subutaneous heparin    .' 2196-10-14 2196-10-14 22:36:00
#
#          type 1    type 2 concepts 1              concepts 2  \
# 7  prescription  sentence  {heparin}  {subcutaneous heparin}
# 8  prescription  sentence  {heparin}  {subcutaneous heparin}
#
#   cosine similarity            semantic type
# 7  0.707107          Pharmacologic Substance
# 8  0.707107          Pharmacologic Substance

# %%
prescription_pairs_df
# Out:
#                                                                                         sentence 1  \
# 7   Patient was prescribed Heparin Flush (10 units/ml) 10 Units/mL - 5 mL Syringe IV of total 2 mL
# 8   Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# 9   Patient was prescribed Potassium Chloride 20mEq Packet PO of total 60 mEq
# 10  Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# 28  Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 40 mEq
# 29  Patient was prescribed Sodium Chloride 3% (Hypertonic) 500 mL Bag IV of total 500 mL
# 41  Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
#
#                                                             sentence 2  \
# 7   # Prophylaxis: Subutaneous heparin    .'
# 8   # Prophylaxis: Subutaneous heparin    .'
# 9   He received IVF, 60    mEq of KCL, and was free water restricted.'
# 10  # Prophylaxis: Subutaneous heparin    .'
# 28  He received IVF, 60    mEq of KCL, and was free water restricted.'
# 29  He received IVF, 60    mEq of KCL, and was free water restricted.'
# 41  # Prophylaxis: Subcutaneous heparin    .'
#
#        time 1              time 2        type 1    type 2  \
# 7  2196-10-14 2196-10-14 22:36:00  prescription  sentence
# 8  2196-10-14 2196-10-14 22:36:00  prescription  sentence
# 9  2196-10-14 2196-10-14 22:36:00  prescription  sentence
# 10 2196-10-14 2196-10-14 22:36:00  prescription  sentence
# 28 2196-10-14 2196-10-14 22:36:00  prescription  sentence
# 29 2196-10-14 2196-10-14 22:36:00  prescription  sentence
# 41 2196-10-15 2196-10-15 06:46:00  prescription  sentence
#
#                                                                                                concepts 1  \
# 7   {heparin}
# 8   {heparin}
# 9   {potassium chloride, Potassium Chloride}
# 10  {heparin}
# 28  {Potassium Chloride 2 MEQ/ML includes Injectable Solution and Injection, Potassium Chloride 2 MEQ/ML}
# 29  {sodium chloride 3%}
# 41  {heparin}
#
#                                                                                                                                                                                                                     concepts 2  \
# 7   {subcutaneous heparin}
# 8   {subcutaneous heparin}
# 9   {potassium chloride, Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution, Fertilization in Vitro}
# 10  {subcutaneous heparin}
# 28  {potassium chloride, Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution, Fertilization in Vitro}
# 29  {potassium chloride, Calcium Chloride 0.23 MEQ/ML / Magnesium Chloride 0.53 MEQ/ML / Potassium Chloride 0.1 MEQ/ML / Sodium Acetate 1.48 MEQ/ML / Sodium Chloride 0.27 MEQ/ML Injectable Solution, Fertilization in Vitro}
# 41  {subcutaneous heparin}
#
#    cosine similarity            semantic type
# 7   0.707107          Pharmacologic Substance
# 8   0.707107          Pharmacologic Substance
# 9   0.507833          Pharmacologic Substance
# 10  0.707107          Pharmacologic Substance
# 28  0.805993          Clinical Drug
# 29  0.507833          Clinical Drug
# 41  0.707107          Pharmacologic Substance

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 28
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "He received IVFand was free water restricted, KCL stopped."
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# prescription 1:	Patient was prescribed Potassium Chloride 2mEq/mL-20mL IV of total 40 mEq
# sentence 2:	He received IVF, 60    mEq of KCL, and was free water restricted.'
#
# New contradicting sentence: He received IVFand was free water restricted, KCL stopped.

# %%
no_contradiction_pair_idx = [41]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# prescription 1:	Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# sentence 2:	# Prophylaxis: Subcutaneous heparin    .'
# *****************************

# %% [markdown]
# ## Patient 10

# %%
#### Process patient data and iterate over pairs of Data instances to get pairs
# Step 1: Select a patient -- processes all the data
hadm_id = hadm_ids[9] # Note: `hadm_ids` is a list of all HADM id's with consecutive physician notes

# for storing data
generated_data_dict[int(hadm_id)] = {"contradiction": {}, "none": []}

print(f"Patient {int(hadm_id)}")

pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
              med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
              physician_only=True)

# Making data directory
processed_dir = 'processed'
os.makedirs(processed_dir, exist_ok=True)

pt_csv = os.path.join(processed_dir, f"{int(hadm_id)}.csv")

# Step 2: Generate pairs for this patient
df, data_inst_pairs = generate_data_pairs(pat)

# df.to_csv(pt_csv)
# print("Data has been saved!")
# Out:
# Patient 196357
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2143-04-20 **********
# ********** Processing data for 2143-04-21 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.5714285714285713
# ----- Data i -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Kidney Failure, Acute'}
# >>    Acute Renal Failure:   [**Month (only) 60**]  be due to decompensated heart failure.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Kidney', 'Tomorrow', 'Chronic diastolic heart failure', 'Ultrasonography'}
# >> Renal US to r/o obstruction    Acute on chronic diastolic heart failure:  Check echo tomorrow.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 0.6546536707079772
# ----- Data i -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Hyponatremia'}
# >>    Hyponatremia:  Likely due to heart failure.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Kidney Failure, Acute'}
# >>    Acute Renal Failure:   [**Month (only) 60**]  be due to decompensated heart failure.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Hyponatremia'}
# >> Concern that    confusion was due symptomatic hyponatremia.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Hyponatremia'}
# >>    Hyponatremia:  Likely due to heart failure.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Refractory anemias'}
# >>    ED Course Notables: brought in by family after being found confused.', "She appeared grossly overloaded on exam, 88% RA, improved to mid-90's    on 2L NC."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Refractory anemias'}
# >> In ED sat 88%    on RA, felt to be fluid overloaded.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.5222329678670936
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Dyspnea on exertion', 'Hyponatremia', 'Infantile Neuroaxonal Dystrophy', 'Lethargy', 'Take Action', 'Pancreatin'}
# >> Assessment and Plan    72F with metastatic ovarian and pancreatic cancer with lung involvement    with recent admission for CAP, who is brought in by family for concerns    of confusion, lethargy, DOE, poor PO intake and found to have    hyponatremia.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his /    her note above, including assessment and plan.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.8728715609439696
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Kidney Failure, Acute'}
# >>    ARF: Picture consistent with pre-renal picture.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Kidney Failure, Acute'}
# >>    Acute Renal Failure:   [**Month (only) 60**]  be due to decompensated heart failure.'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP>5000, Cr 1.6 (baseline 1.0).'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Given LE edema, crackles    on exam, and high BNP.'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Arthralgia'}
# >>    Musculoskeletal: No(t) Joint pain    Integumentary (skin): No(t) Rash'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Not assessed'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.7106690545187014
# ----- Data i -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: No(t) Dry mouth'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 0.974679434480896
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Americium', 'Fertilization in Vitro', 'Blood Stop Topical Product', 'Uridine', 'Blood product'}
# >>    Neurologic: No(t) Seizure    Flowsheet Data as of  [**2143-4-21**]  01:04 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since 12 AM                   Total In:                   PO:                   TF:    IVF:    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                       0 mL    Respiratory    O2 Delivery Device: Nasal cannula    Physical Examination'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,467 mL    PO:              TF:    IVF:    1,467 mL    Blood products:    Total out:                                                                   1,200 mL                                                                     200 mL    Urine:    200 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,200 mL                                                                   1,267 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 0.801783725737273
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Liver', 'Liver Extract', 'Lung', 'Pancreatin'}
# >>    Oncology: Hx of metastatic ovarian and pancreatic cancer metastatic to    liver and lung.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Liver', 'Liver Extract', 'Lung', 'Chest CT'}
# >> - one year later found to have metastatic disease to liver    ( [**10/2142**] )    Admitted  [**3-26**]  with CAP, Chest CT with metastatic disease to lungs.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'S-1 Antimetabolite agent'}
# >>    Cardiovascular: (PMI Normal), (S1: Normal), (S2: Normal), (Murmur:  [**1-23**]     soft Systolic Ejection Murmur)'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'S-1 Antimetabolite agent'}
# >>    Cardiovascular: (S1: Normal), (S2: Normal)'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Warm'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Not assessed'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.8944271909999159
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract'}
# >>    Skin:  Warm'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Felis catus skin extract', 'Arthralgia'}
# >>    Musculoskeletal: No(t) Joint pain    Integumentary (skin): No(t) Rash'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol', 'nesiritide'}
# >> BNP    > 5000, EF 75% on recent ECHO.', "Perhaps there are new wall motion    abnormalities that aren't allowing optimal cardiac output, thus causing    a pre-renal picture."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Given LE edema, crackles    on exam, and high BNP.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol', 'nesiritide'}
# >> BNP    > 5000, EF 75% on recent ECHO.', "Perhaps there are new wall motion    abnormalities that aren't allowing optimal cardiac output, thus causing    a pre-renal picture."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP>5000, Cr 1.6 (baseline 1.0).'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 0.6324555320336758
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Uridine', 'Hypovolemic', 'Take Action', 'Hyponatremia'}
# >>    Hyponatremia: Patient with Sodium of 118 with confusion.', "Absence of    JVD,  Urine lytes and poor PO intake would suggest that she's got    hypovolemic hyponatremia."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Take Action'}
# >> Poor PO intake.'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Intestines', 'Sea Soft'}
# >>    Abdominal: Soft, Non-tender, No bowel sounds present, nontender    palpaple mass in epigastrium'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Sea Soft'}
# >>    Abdominal: Soft, Non-tender, Mass in RUQ'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >>    Drugs: None'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Pharmaceutical Preparations'}
# >>    Drugs: none'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP > 5000.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Given LE edema, crackles    on exam, and high BNP.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP > 5000.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP>5000, Cr 1.6 (baseline 1.0).'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP > 5000.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol', 'nesiritide'}
# >> BNP    > 5000, EF 75% on recent ECHO.', "Perhaps there are new wall motion    abnormalities that aren't allowing optimal cardiac output, thus causing    a pre-renal picture."
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL, Conjunctiva pale    Head, Ears, Nose, Throat: Normocephalic, dry MM'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 0.7106690545187014
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL, Conjunctiva pale    Head, Ears, Nose, Throat: Normocephalic, dry MM'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: No(t) Dry mouth'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Lasix'}
# >> If patient does require    lasix, she may benefit from a lasix gtt.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Lasix'}
# >> Patient may have    new diastolic dysfunction requiring lasix.'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Electrolytes', 'Uridine'}
# >> Will give patient 1L NS and recheck her electrolytes given that she    likely pre-renal    Will follow urine lytes.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Uridine'}
# >> Will follow urine lytes    3.'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Gross lower extremity edema, CXR findings,    and BNP would suggest that she has hypervolemic hypernatremia, although    this may be due to underlying malignancy.', "Sodium correction rate    ideally 0.5 meq/L/hour given that she's generally asymptomatic."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Given LE edema, crackles    on exam, and high BNP.'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Gross lower extremity edema, CXR findings,    and BNP would suggest that she has hypervolemic hypernatremia, although    this may be due to underlying malignancy.', "Sodium correction rate    ideally 0.5 meq/L/hour given that she's generally asymptomatic."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP>5000, Cr 1.6 (baseline 1.0).'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Gross lower extremity edema, CXR findings,    and BNP would suggest that she has hypervolemic hypernatremia, although    this may be due to underlying malignancy.', "Sodium correction rate    ideally 0.5 meq/L/hour given that she's generally asymptomatic."
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol', 'nesiritide'}
# >> BNP    > 5000, EF 75% on recent ECHO.', "Perhaps there are new wall motion    abnormalities that aren't allowing optimal cardiac output, thus causing    a pre-renal picture."
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> Gross lower extremity edema, CXR findings,    and BNP would suggest that she has hypervolemic hypernatremia, although    this may be due to underlying malignancy.', "Sodium correction rate    ideally 0.5 meq/L/hour given that she's generally asymptomatic."
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'nesiritide'}
# >> BNP > 5000.'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 0.5202659817144719
# ----- Data i -----
# >> Time: 2143-04-21 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.34 m/uL.
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,467 mL    PO:              TF:    IVF:    1,467 mL    Blood products:    Total out:                                                                   1,200 mL                                                                     200 mL    Urine:    200 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,200 mL                                                                   1,267 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.5070925528371099
# ----- Data i -----
# >> Time: 2143-04-21 00:00:00
# >> Type: lab
# >> Concepts: {'Red blood cells, blood product'}
# >> Patient's Red Blood Cells lab came back 4.34 m/uL.
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Americium', 'Fertilization in Vitro', 'Blood Stop Topical Product', 'Uridine', 'Blood product'}
# >>    Neurologic: No(t) Seizure    Flowsheet Data as of  [**2143-4-21**]  01:04 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since 12 AM                   Total In:                   PO:                   TF:    IVF:    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                       0 mL    Respiratory    O2 Delivery Device: Nasal cannula    Physical Examination'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 0.7106690545187014
# ----- Data i -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: No(t) Dry mouth'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.801783725737273
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Liver', 'Liver Extract', 'Lung', 'Pancreatin'}
# >>    Oncology: Hx of metastatic ovarian and pancreatic cancer metastatic to    liver and lung.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Liver', 'Liver Extract', 'Lung', 'Chest CT'}
# >> - one year later found to have metastatic disease to liver    ( [**10/2142**] )    Admitted  [**3-26**]  with CAP, Chest CT with metastatic disease to lungs.'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.6784005252999681
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Fatigue', 'Nose', 'Pharyngeal structure', 'Ear structure'}
# >>    Constitutional: Fatigue, No Fever, Weight loss ~6 lbs in 3 weeks    Ear, Nose, Throat: Dry mouth'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 0.8249579113843053
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Fatigue', 'Nose', 'Pharyngeal structure', 'Ear structure'}
# >>    Constitutional: Fatigue, No Fever, Weight loss ~6 lbs in 3 weeks    Ear, Nose, Throat: Dry mouth'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: No(t) Dry mouth'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL, Conjunctiva pale    Head, Ears, Nose, Throat: Normocephalic, dry MM'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 0.7106690545187014
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL, Conjunctiva pale    Head, Ears, Nose, Throat: Normocephalic, dry MM'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Visine', 'Eye', 'Ear structure'}
# >>    Eyes: No(t)  Blurry vision    Ear, Nose, Throat: No(t) Dry mouth'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 0.6784005252999681
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Nose', 'Pharyngeal structure', 'Eye', 'Structure of palpebral conjunctiva', 'Sus scrofa conjunctiva preparation', 'Ear structure'}
# >>    General Appearance: Thin    Eyes / Conjunctiva: PERRL, Conjunctiva pale    Head, Ears, Nose, Throat: Normocephalic, dry MM'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Fatigue', 'Nose', 'Pharyngeal structure', 'Ear structure'}
# >>    Constitutional: Fatigue, No Fever, Weight loss ~6 lbs in 3 weeks    Ear, Nose, Throat: Dry mouth'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Limb structure'}
# >>    Extremities: Right: 2+, Left: 2+ DP pulses'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Limb structure'}
# >>    Extremities: Right: 3+, Left: 3+'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will repeat ECHO.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Echo  [**3-26**]  with EF of 75% and ?'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Pred Mild', 'Lasix', 'ECHO protocol'}
# >> She has never been on Lasix.', "She's never had a dx of heart failure and    most recent ECHO from  [**2143-4-9**]  revealed EF75%, mild AR, trivial MR,    impaired relaxation."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Echo  [**3-26**]  with EF of 75% and ?'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Pred Mild', 'Lasix', 'ECHO protocol'}
# >> She has never been on Lasix.', "She's never had a dx of heart failure and    most recent ECHO from  [**2143-4-9**]  revealed EF75%, mild AR, trivial MR,    impaired relaxation."
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will repeat ECHO.'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 0.974679434480896
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Americium', 'Fertilization in Vitro', 'Blood Stop Topical Product', 'Uridine', 'Blood product'}
# >>    Neurologic: No(t) Seizure    Flowsheet Data as of  [**2143-4-21**]  01:04 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since 12 AM                   Total In:                   PO:                   TF:    IVF:    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                       0 mL    Respiratory    O2 Delivery Device: Nasal cannula    Physical Examination'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,467 mL    PO:              TF:    IVF:    1,467 mL    Blood products:    Total out:                                                                   1,200 mL                                                                     200 mL    Urine:    200 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,200 mL                                                                   1,267 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol', 'nesiritide'}
# >> BNP    > 5000, EF 75% on recent ECHO.', "Perhaps there are new wall motion    abnormalities that aren't allowing optimal cardiac output, thus causing    a pre-renal picture."
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Echo  [**3-26**]  with EF of 75% and ?'
# **********************************
# ***** PAIR INDEX 45 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol', 'nesiritide'}
# >> BNP    > 5000, EF 75% on recent ECHO.', "Perhaps there are new wall motion    abnormalities that aren't allowing optimal cardiac output, thus causing    a pre-renal picture."
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will repeat ECHO.'
# **********************************
# ***** PAIR INDEX 46 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Palliative Care'}
# >> Pallative care consult regarding Hospice options    Leuckocytosis/CXR infiltrate: Unclear etiology at this time.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Palliative Care'}
# >> Will get palliative care consult.'
# **********************************
# ***** PAIR INDEX 47 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will continue to cycle enzymes and obtain    another ECHO in the am.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Echo  [**3-26**]  with EF of 75% and ?'
# **********************************
# ***** PAIR INDEX 48 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will continue to cycle enzymes and obtain    another ECHO in the am.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will repeat ECHO.'
# **********************************
# ***** PAIR INDEX 49 *****
# Cosine similarity: 0.5345224838248487
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will continue to cycle enzymes and obtain    another ECHO in the am.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Heart failure', 'Pred Mild', 'Lasix', 'ECHO protocol'}
# >> She has never been on Lasix.', "She's never had a dx of heart failure and    most recent ECHO from  [**2143-4-9**]  revealed EF75%, mild AR, trivial MR,    impaired relaxation."
# **********************************
# ***** PAIR INDEX 50 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol'}
# >> Will continue to cycle enzymes and obtain    another ECHO in the am.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'ECHO protocol', 'nesiritide'}
# >> BNP    > 5000, EF 75% on recent ECHO.', "Perhaps there are new wall motion    abnormalities that aren't allowing optimal cardiac output, thus causing    a pre-renal picture."
# **********************************
# ***** PAIR INDEX 51 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Pain control'}
# >> Pain control as needed    3.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Pain control', 'Constipation', 'Narcotics'}
# >>    Constipation:  [**Month (only) 60**]  be due to narcotics that the patinet is taking for    pain control.'
# **********************************
# ***** PAIR INDEX 52 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography'}
# >>    EKG: nsr, rate 65, new q waves in V1-V3, TWI in V1-V3    CXR  [**2143-4-20**]     1.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography'}
# >>    ECG: poor R wave progression.'
# **********************************
# ***** PAIR INDEX 53 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Diagnosis'}
# >> She has had LE edema in    the past and was recently diagnosed with lymphangitis carcinomatosis.'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Nausea', 'Diagnosis', 'Vomiting'}
# >> Patient without nausea or vomiting, but if this ensues,    would quickly entertain diagnosis of obstruction due to underlying    disease.'
# **********************************
# ***** PAIR INDEX 54 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Ultrasonography'}
# >>    Occupation: former storekeeper in  [**First Name8 (NamePattern2) 2520**]   [**Country 944**] , moved to US in 200    after husband disappeared during their pilgrimage to  [**Location (un) 2522**]  in  [**2133**]'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Ultrasonography'}
# >> Will obtain renal US in am.'
# **********************************
# ***** PAIR INDEX 55 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography'}
# >> EKG with ?'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography'}
# >>    ECG: poor R wave progression.'
# **********************************
# ***** PAIR INDEX 56 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography'}
# >> EKG with ?'
# ----- Data j -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Electrocardiography'}
# >>    EKG: nsr, rate 65, new q waves in V1-V3, TWI in V1-V3    CXR  [**2143-4-20**]     1.'
# **********************************
# ***** PAIR INDEX 57 *****
# Cosine similarity: 0.5262348115842176
# ----- Data i -----
# >> Time: 2143-04-21 00:00:00
# >> Type: lab
# >> Concepts: {'Activated Partial Thromboplastin Time measurement'}
# >> Patient's PTT lab came back 29.5 sec.
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lipase', 'Amylases', 'Laboratory test finding', 'Prothrombin time assay', 'Mandibular right second primary molar', 'amylase'}
# >> 36.5 %    12.2 g/dL    122 mg/dL    1.5 mg/dL    44 mg/dL    29 mEq/L    84 mEq/L    4.3 mEq/L    120 mEq/L    12.5 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM    WBC                                     12.5    Hct                                     36.5    Plt                                      163    Cr                                      1.5                                      1.5    TropT                                     0.03    Glucose                                      130                                      122    Other labs: PT / PTT / INR:14.7/29.5/1.3, CK / CKMB /    Troponin-T:30/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:3.1 mg/dL, PO4:5.1 mg/dL'
# **********************************
# ***** PAIR INDEX 58 *****
# Cosine similarity: 0.8660254037844388
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: Attentive, Responds to: Verbal stimuli, Oriented (to):    person and place, Movement: Not assessed, Tone: Not assessed    Labs / Radiology    155    141'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding', 'Lethargy'}
# >>    Neurologic: Responds to: Not assessed, Movement: Not assessed, Tone:    Not assessed, Lethargic    Labs / Radiology    163 K/uL'
# **********************************
# ***** PAIR INDEX 59 *****
# Cosine similarity: 0.6666666666666669
# ----- Data i -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Pleurisy', 'Chest Pain'}
# >>    Cardiovascular: Chest pain, pleuritic CP'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Chest Pain', 'Lethargy'}
# >> confusion, lethargy, chest pain    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# **********************************
# ***** PAIR INDEX 60 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Dyspnea'}
# >> This may be contributing to dyspnea.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Dyspnea', 'Dry cough'}
# >> HPI:    72 yo women presents with progressive SOB, LE edema (stable), right    sided pleurtic CP with some dry cough.'
# **********************************
# ***** PAIR INDEX 61 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Coughing', 'Dyspnea', 'Zicam Cough'}
# >>    Respiratory: Cough, Dyspnea'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Dyspnea', 'Dry cough'}
# >> HPI:    72 yo women presents with progressive SOB, LE edema (stable), right    sided pleurtic CP with some dry cough.'
# **********************************
# ***** PAIR INDEX 62 *****
# Cosine similarity: 0.5163977794943223
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Chest Pain', 'Dyspnea on exertion'}
# >> She denies any other chest pain but does endorse    DOE, and orthopnea.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Chest Pain', 'Lethargy'}
# >> confusion, lethargy, chest pain    I saw and examined the patient, and was physically present with the ICU    Resident for key portions of the services provided.'
# **********************************
# ***** PAIR INDEX 63 *****
# Cosine similarity: 0.5163977794943223
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Chest Pain', 'Dyspnea on exertion'}
# >> She denies any other chest pain but does endorse    DOE, and orthopnea.'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Pleurisy', 'Chest Pain'}
# >>    Cardiovascular: Chest pain, pleuritic CP'
# **********************************
# ***** PAIR INDEX 64 *****
# Cosine similarity: 0.974679434480896
# ----- Data i -----
# >> Time: 2143-04-21 01:24:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Americium', 'Fertilization in Vitro', 'Blood Stop Topical Product', 'Uridine', 'Blood product'}
# >>    Neurologic: No(t) Seizure    Flowsheet Data as of  [**2143-4-21**]  01:04 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since 12 AM                   Total In:                   PO:                   TF:    IVF:    Blood products:    Total out:                                                                       0 mL                                                                       0 mL    Urine:    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                       0 mL    Respiratory    O2 Delivery Device: Nasal cannula    Physical Examination'
# ----- Data j -----
# >> Time: 2143-04-21 09:19:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:              1,467 mL    PO:              TF:    IVF:    1,467 mL    Blood products:    Total out:                                                                   1,200 mL                                                                     200 mL    Urine:    200 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,200 mL                                                                   1,267 mL    Respiratory    O2 Delivery Device: Nasal cannula    SpO2: 99%'
# **********************************
# ********** Processing data for 2143-04-22 **********
# ***** PAIR INDEX 65 *****
# Cosine similarity: 0.6030226891555273
# ----- Data i -----
# ...
# Cosine similarity: 0.5262348115842176
# ----- Data i -----
# >> Time: 2143-04-22 00:00:00
# >> Type: lab
# >> Concepts: {'Activated Partial Thromboplastin Time measurement'}
# >> Patient's PTT lab came back 29.6 sec.
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lipase', 'Amylases', 'Laboratory test finding', 'Prothrombin time assay', 'Mandibular right second primary molar', 'amylase'}
# >> 33.7 %    13.6 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM                               [**2143-4-21**]   04:25 PM                               [**2143-4-21**]   09:47 PM                               [**2143-4-22**]   04:36 AM                               [**2143-4-22**]   04:52 AM    WBC    12.5    13.6    Hct    36.5    33.7    Plt    163    144    Cr    1.5    1.5    1.3    1.3    1.2    TropT    0.03    0.03    TCO2    26    Glucose    130    122    105    120    118    Other labs: PT / PTT / INR:14.4/29.6/1.3, CK / CKMB /    Troponin-T:27/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:2.8 mg/dL, PO4:4.5 mg/dL'
# **********************************
# ***** PAIR INDEX 107 *****
# Cosine similarity: 0.5262348115842176
# ----- Data i -----
# >> Time: 2143-04-22 00:00:00
# >> Type: lab
# >> Concepts: {'Activated Partial Thromboplastin Time measurement'}
# >> Patient's PTT lab came back 33.0 sec.
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lipase', 'Amylases', 'Laboratory test finding', 'Prothrombin time assay', 'Mandibular right second primary molar', 'amylase'}
# >> 33.7 %    13.6 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM                               [**2143-4-21**]   04:25 PM                               [**2143-4-21**]   09:47 PM                               [**2143-4-22**]   04:36 AM                               [**2143-4-22**]   04:52 AM    WBC    12.5    13.6    Hct    36.5    33.7    Plt    163    144    Cr    1.5    1.5    1.3    1.3    1.2    TropT    0.03    0.03    TCO2    26    Glucose    130    122    105    120    118    Other labs: PT / PTT / INR:14.4/29.6/1.3, CK / CKMB /    Troponin-T:27/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:2.8 mg/dL, PO4:4.5 mg/dL'
# **********************************
# ***** PAIR INDEX 108 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Access: PIVx1, art sticks for labs, would consider A-line.'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: No(t) Attentive, No(t) Follows simple commands, Responds    to: Not assessed, Movement: Not assessed, Tone: Not assessed    Labs / Radiology    144 K/uL'
# **********************************
# ***** PAIR INDEX 109 *****
# Cosine similarity: 0.8075006161486821
# ----- Data i -----
# >> Time: 2143-04-22 09:04:00
# >> Type: sentence
# >> Concepts: {'Measurement of fractional excretion of sodium', 'Body fluid analysis', 'Laboratory test finding', 'Prothrombin time assay', 'Amylases', 'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lipase', 'Uridine', 'Infantile Neuroaxonal Dystrophy', 'Mandibular right second primary molar', 'amylase'}
# >> 33.7 %    13.6 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM                               [**2143-4-21**]   04:25 PM                               [**2143-4-21**]   09:47 PM                               [**2143-4-22**]   04:36 AM                               [**2143-4-22**]   04:52 AM    WBC    12.5    13.6    Hct    36.5    33.7    Plt    163    144    Cr    1.5    1.5    1.3    1.3    1.2    TropT    0.03    0.03    TCO2    26    Glucose    130    122    105    120    118    Other labs: PT / PTT / INR:14.4/29.6/1.3, CK / CKMB /    Troponin-T:27/2/0.03, ALT / AST:45/102, Alk Phos / T Bili:242/0.5,    Amylase / Lipase:27/13, Albumin:2.8 g/dL, LDH:400 IU/L, Ca++:8.2 mg/dL,    Mg++:2.8 mg/dL, PO4:4.5 mg/dL    Fluid analysis / Other labs: urine lytes    urea 284, fena 15%    uosm 287    AB6 7.54/29/69    Assessment and Plan    1.'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Primed lymphocyte test', 'Activated Partial Thromboplastin Time measurement', 'Lipase', 'Amylases', 'Laboratory test finding', 'Prothrombin time assay', 'Mandibular right second primary molar', 'amylase'}
# >> 33.7 %    13.6 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM                               [**2143-4-21**]   04:25 PM                               [**2143-4-21**]   09:47 PM                               [**2143-4-22**]   04:36 AM                               [**2143-4-22**]   04:52 AM    WBC    12.5    13.6    Hct    36.5    33.7    Plt    163    144    Cr    1.5    1.5    1.3    1.3    1.2    TropT    0.03    0.03    TCO2    26    Glucose    130    122    105    120    118    Other labs: PT / PTT / INR:14.4/29.6/1.3, CK / CKMB /    Troponin-T:27/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:2.8 mg/dL, PO4:4.5 mg/dL'
# **********************************
# ***** PAIR INDEX 110 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2143-04-22 09:04:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Chest: bibasilar rales, no wheezes    Labs / Radiology'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neurologic: No(t) Attentive, No(t) Follows simple commands, Responds    to: Not assessed, Movement: Not assessed, Tone: Not assessed    Labs / Radiology    144 K/uL'
# **********************************
# ***** PAIR INDEX 111 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2143-04-22 09:04:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Chest: bibasilar rales, no wheezes    Labs / Radiology'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Access: PIVx1, art sticks for labs, would consider A-line.'
# **********************************
# ***** PAIR INDEX 112 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Dyspnea'}
# >> This may be contributing to dyspnea.'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Dyspnea', 'nesiritide'}
# >> Difficult to assess volume status in this patient, but patient with CXR    c/w edema, elevated BNP, b/l LE Edema and difficulty lying flat due to    SOB suggesting hypervolemic state and warrants diuresis.'
# **********************************
# ***** PAIR INDEX 113 *****
# Cosine similarity: 0.7276068751089989
# ----- Data i -----
# >> Time: 2143-04-22 09:04:00
# >> Type: sentence
# >> Concepts: {'Radiography of kidney-ureter-bladder', 'Pepcid', 'Pharmaceutical Preparations', 'Lasix', 'Electrocardiography', 'Ultrasonography', 'Infusion procedures', 'famotidine', 'Americium', 'Nausea and vomiting', 'Zoloft', 'Famotidine', 'heparin sodium', 'Nausea', 'Sertraline 50 MG Oral Tablet'}
# >> HPI:    24 Hour Events:  EKG - At  [**2143-4-21**]  08:42 AM  ULTRASOUND - At  [**2143-4-21**]  02:00 PM:    no DVT    Nausea KUB - no bowel dilation    Started on Lasix drip    Allergies:    Hydrochlorothiazide    hyponatremia/na    Zoloft (Oral) (Sertraline Hcl)    Nausea/Vomiting    Last dose of Antibiotics:    Infusions:    Furosemide (Lasix) - 4 mg/hour    Other ICU medications:    Furosemide (Lasix) -  [**2143-4-21**]  06:25 PM    Famotidine (Pepcid) -  [**2143-4-22**]  08:07 AM    Heparin Sodium (Prophylaxis) -  [**2143-4-22**]  08:07 AM    Other medications:    Changes to medical and family history:    PMH, SH, FH and ROS are unchanged from Admission except where noted    above and below    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2143-4-22**]  09:04 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Facial Paresis', 'Americium', 'Radiography of kidney-ureter-bladder', 'Zoloft', 'Nausea and vomiting', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Tylenol', 'Pharmaceutical Preparations', 'Lasix', 'Nausea', 'Sertraline 50 MG Oral Tablet', 'Constipation', 'Infusion procedures'}
# >> - CT Head for new facial droop not noted previously by family    - KUB for nausea and constipation, no bowel dilation (supine film only    but no clear air fluid levels)    - Changed pain meds to vicodin with 2g tylenol per day restriction    Allergies:    Hydrochlorothiazide    hyponatremia/na    Zoloft (Oral) (Sertraline Hcl)    Nausea/Vomiting    Last dose of Antibiotics:    Infusions:    Furosemide (Lasix) - 4 mg/hour    Other ICU medications:    Furosemide (Lasix) -  [**2143-4-21**]  06:25 PM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2143-4-22**]  06:59 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# **********************************
# ***** PAIR INDEX 114 *****
# Cosine similarity: 0.9999999999999996
# ----- Data i -----
# >> Time: 2143-04-22 09:04:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                   2,313 mL                                                                     617 mL    PO:                                                                      60 mL                                                                      60 mL    TF:    IVF:                                                                   2,013 mL                                                                     557 mL    Blood products:    Total out:                                                                   1,180 mL                                                                   1,115 mL    Urine:                                                                   1,180 mL                                                                   1,115 mL    NG:    Stool:    Drains:    Balance:                                                                   1,133 mL                                                                    -498 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 98%'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Drainage procedure', 'Systane Balance', 'nitroglycerin', 'Blood Stop Topical Product', 'Fertilization in Vitro', 'Uridine', 'Blood product'}
# >>    Height: 65 Inch              Total In:                                                                   2,313 mL                                                                     589 mL    PO:                                                                      60 mL                                                                      60 mL    TF:    IVF:                                                                   2,013 mL                                                                     529 mL    Blood products:    Total out:                                                                   1,180 mL                                                                     940 mL    Urine:                                                                   1,180 mL                                                                     940 mL    NG:    Stool:    Drains:    Balance:                                                                   1,133 mL                                                                    -351 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 99%'
# **********************************
# ***** PAIR INDEX 115 *****
# Cosine similarity: 0.7276068751089989
# ----- Data i -----
# >> Time: 2143-04-22 09:04:00
# >> Type: sentence
# >> Concepts: {'Radiography of kidney-ureter-bladder', 'Pepcid', 'Pharmaceutical Preparations', 'Lasix', 'Electrocardiography', 'Ultrasonography', 'Infusion procedures', 'famotidine', 'Americium', 'Nausea and vomiting', 'Zoloft', 'Famotidine', 'heparin sodium', 'Nausea', 'Sertraline 50 MG Oral Tablet'}
# >> HPI:    24 Hour Events:  EKG - At  [**2143-4-21**]  08:42 AM  ULTRASOUND - At  [**2143-4-21**]  02:00 PM:    no DVT    Nausea KUB - no bowel dilation    Started on Lasix drip    Allergies:    Hydrochlorothiazide    hyponatremia/na    Zoloft (Oral) (Sertraline Hcl)    Nausea/Vomiting    Last dose of Antibiotics:    Infusions:    Furosemide (Lasix) - 4 mg/hour    Other ICU medications:    Furosemide (Lasix) -  [**2143-4-21**]  06:25 PM    Famotidine (Pepcid) -  [**2143-4-22**]  08:07 AM    Heparin Sodium (Prophylaxis) -  [**2143-4-22**]  08:07 AM    Other medications:    Changes to medical and family history:    PMH, SH, FH and ROS are unchanged from Admission except where noted    above and below    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2143-4-22**]  09:04 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# ----- Data j -----
# >> Time: 2143-04-22 06:59:00
# >> Type: sentence
# >> Concepts: {'Facial Paresis', 'Americium', 'Radiography of kidney-ureter-bladder', 'Zoloft', 'Nausea and vomiting', 'MICROCEPHALY, EPILEPSY, AND DIABETES SYNDROME', 'Tylenol', 'Pharmaceutical Preparations', 'Lasix', 'Nausea', 'Sertraline 50 MG Oral Tablet', 'Constipation', 'Infusion procedures'}
# >> - CT Head for new facial droop not noted previously by family    - KUB for nausea and constipation, no bowel dilation (supine film only    but no clear air fluid levels)    - Changed pain meds to vicodin with 2g tylenol per day restriction    Allergies:    Hydrochlorothiazide    hyponatremia/na    Zoloft (Oral) (Sertraline Hcl)    Nausea/Vomiting    Last dose of Antibiotics:    Infusions:    Furosemide (Lasix) - 4 mg/hour    Other ICU medications:    Furosemide (Lasix) -  [**2143-4-21**]  06:25 PM    Other medications:    Changes to medical and family history:    Review of systems is unchanged from admission except as noted below    Review of systems:    Flowsheet Data as of   [**2143-4-22**]  06:59 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# **********************************
# ********** Processing data for 2143-04-23 **********
# ********** Processing data for 2143-04-24 **********
# ********** Processing data for 2143-04-25 **********
# ********** Processing data for 2143-04-26 **********

# %%
#### Inserting contradictions to Sentence instances
# IMPORTANT: We should only insert contradictions if it is a sentence from a note ("type" should be sentence, not lab or prescription)! 

# Step 3: Get all the pairs about prescriptions values
prescription_pairs_df = df.loc[(df['type 1'] == "prescription") | (df['type 2'] == "prescription")]

prescription_pairs_df.head(2)
# Out:
# Empty DataFrame
# Columns: [sentence 1, sentence 2, time 1, time 2, type 1, type 2, concepts 1, concepts 2, cosine similarity, semantic type]
# Index: []

# %%
prescription_pairs_df
# Out:
# Empty DataFrame
# Columns: [sentence 1, sentence 2, time 1, time 2, type 1, type 2, concepts 1, concepts 2, cosine similarity, semantic type]
# Index: []

# %%
# Step 4: Insert contradictions

# We should probably aim for 1-2 contradictions per patient. 
# So basically, copy/paste code for Steps 1-4 for each patient, and push to Github.
# Small heads up -- for a given patient, try not to insert contradictions 
# into two sentences that look really really similar. 
# There's a chance this might refer to the same underlying Sentence instance, 
# which could overwrite a contradiction you previously inserted. 

# Look through the sentence pairs by going through `prescription_pairs_df`.
# If you find a good one you want to insert a contradiction for, 
# make note of the row index (i.e. the number at the left), 
# and set this to `pair_idx` below. 
# Also make note of which sentence (i.e. sentence 1 or sentence 2)
# you want to modify, and set the `is_sentence2` flag appropriately.

# %%
pair_idx = 48
is_sentence2 = True

data_1 = data_inst_pairs[pair_idx][0][0]
data_2 = data_inst_pairs[pair_idx][0][1]

print(f"{data_1.type} 1:\t{data_1.txt}")
print(f"{data_2.type} 2:\t{data_2.txt}")

sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

# Set `contradicting_txt` to the new contradicting sentence.
# This will just update the text for now.

contradicting_txt = "36.5 %    12.2 g/dL    122 mg/dL    1.5 mg/dL    44 mg/dL    29 mEq/L    " +\
                    "84 mEq/L    4.3 mEq/L    120 mEq/L    12.5 K/uL         [image002.jpg]                               " +\
                    "[**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM    " +\
                    "WBC                                     12.5    Hct                                     36.5    " +\
                    "Plt                                      163    Cr                                      " +\
                    "1.5                                      1.5    TropT                                     0.03    " +\
                    "Glucose                                      130                                      122    " +\
                    "Other labs: PT / PTT / INR:14.7/290.0/1.3, CK / CKMB /    Troponin-T:30/2/0.03, ALT / AST:28/55, Alk Phos " +\
                    "/ T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    " +\
                    "Mg++:3.1 mg/dL, PO4:5.1 mg/dL'"
sentence_to_modify.update_text(contradicting_txt)

print(f"\nNew contradicting sentence: {contradicting_txt}")

# Store conflict
generated_data_dict[int(hadm_id)]['contradiction'][pair_idx] = (is_sentence2, contradicting_txt)
# Out:
# lab 1:	Patient's PTT lab came back 29.5 sec.
# sentence 2:	36.5 %    12.2 g/dL    122 mg/dL    1.5 mg/dL    44 mg/dL    29 mEq/L    84 mEq/L    4.3 mEq/L    120 mEq/L    12.5 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM    WBC                                     12.5    Hct                                     36.5    Plt                                      163    Cr                                      1.5                                      1.5    TropT                                     0.03    Glucose                                      130                                      122    Other labs: PT / PTT / INR:14.7/29.5/1.3, CK / CKMB /    Troponin-T:30/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:3.1 mg/dL, PO4:5.1 mg/dL'
#
# New contradicting sentence: 36.5 %    12.2 g/dL    122 mg/dL    1.5 mg/dL    44 mg/dL    29 mEq/L    84 mEq/L    4.3 mEq/L    120 mEq/L    12.5 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM    WBC                                     12.5    Hct                                     36.5    Plt                                      163    Cr                                      1.5                                      1.5    TropT                                     0.03    Glucose                                      130                                      122    Other labs: PT / PTT / INR:14.7/290.0/1.3, CK / CKMB /    Troponin-T:30/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:3.1 mg/dL, PO4:5.1 mg/dL'

# %%
no_contradiction_pair_idx = [48, 49, 104]

print("Examples of non-contradictions")
print("*****************************")
for pair_idx in no_contradiction_pair_idx:
    data_1 = data_inst_pairs[pair_idx][0][0]
    data_2 = data_inst_pairs[pair_idx][0][1]
    
    print(f"{data_1.type} 1:\t{data_1.txt}")
    print(f"{data_2.type} 2:\t{data_2.txt}")
    print("*****************************")
    
# Store negative examples
generated_data_dict[int(hadm_id)]['none'] = no_contradiction_pair_idx
# Out:
# Examples of non-contradictions
# *****************************
# lab 1:	Patient's PTT lab came back 29.5 sec.
# sentence 2:	36.5 %    12.2 g/dL    122 mg/dL    1.5 mg/dL    44 mg/dL    29 mEq/L    84 mEq/L    4.3 mEq/L    120 mEq/L    12.5 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM    WBC                                     12.5    Hct                                     36.5    Plt                                      163    Cr                                      1.5                                      1.5    TropT                                     0.03    Glucose                                      130                                      122    Other labs: PT / PTT / INR:14.7/29.5/1.3, CK / CKMB /    Troponin-T:30/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:3.1 mg/dL, PO4:5.1 mg/dL'
# *****************************
# lab 1:	Patient's White Blood Cells lab came back 12.5 K/uL , which is abnormal.
# sentence 2:	WBC 13, Cr 1.6 (baseline 1.0).'
# *****************************
# lab 1:	Patient's PTT lab came back 33.0 sec.
# sentence 2:	33.7 %    13.6 K/uL         [image002.jpg]                               [**2143-4-21**]   12:58 AM                               [**2143-4-21**]   04:50 AM                               [**2143-4-21**]   04:25 PM                               [**2143-4-21**]   09:47 PM                               [**2143-4-22**]   04:36 AM                               [**2143-4-22**]   04:52 AM    WBC    12.5    13.6    Hct    36.5    33.7    Plt    163    144    Cr    1.5    1.5    1.3    1.3    1.2    TropT    0.03    0.03    TCO2    26    Glucose    130    122    105    120    118    Other labs: PT / PTT / INR:14.4/29.6/1.3, CK / CKMB /    Troponin-T:27/2/0.03, ALT / AST:28/55, Alk Phos / T Bili:161/0.4,    Amylase / Lipase:27/13, Albumin:2.9 g/dL, LDH:347 IU/L, Ca++:8.2 mg/dL,    Mg++:2.8 mg/dL, PO4:4.5 mg/dL'
# *****************************

# %%
generated_data_dict
# Out:
# {155131: {'contradiction': {140: (True, 'DC heparin stopped.')},
#   'none': [32, 33]},
#  129414: {'contradiction': {10: (True,
#     'He stopped his albuterol use but this did not help so he came to the emergency room.')},
#   'none': [25, 26]},
#  133623: {'contradiction': {37: (True, 'Metoprolol not recommended.')},
#   'none': []},
#  197325: {'contradiction': {49: (True, 'Acetaminophen not given.')},
#   'none': [76]},
#  186291: {'contradiction': {101: (True,
#     '- stop doxazosin - hydralazine as needed for diastolic >100 - continue to monitor # HIV: last CD4 307, VL 187; per ID fellow overnight recommendations, continue pt on abacavir/lamivudine/atazanavir.')},
#   'none': [102, 103]},
#  180836: {'contradiction': {72: (True,
#     'Initially patient appeared in stress but later was doing well and did not require Morphine.')},
#   'none': [31, 88]},
#  154802: {'contradiction': {10: (True, 'Metoclopramide held.')},
#   'none': [13, 14, 39, 44]},
#  133857: {'contradiction': {10: (True, 'Phenytoin not given.')},
#   'none': [1, 309]},
#  166389: {'contradiction': {28: (True,
#     'He received IVFand was free water restricted, KCL stopped.')},
#   'none': [41]},
#  196357: {'contradiction': {}, 'none': []}}

# %%
import pickle
data_dict_file = "generated_data_dict_prescription.pkl"
with open(data_dict_file, "wb") as f:
    pickle.dump(generated_data_dict, f)

# %% [markdown]
# # 5. Loading contradictions data for pipeline [skip 4 if pickle file already created]
#
# If `generated_data_dict_lab.pkl` has already been created, skip part 4. You should still run the inital cells, above "README" in that section though.
#
# About 2 min per HADM_ID, 20 min total

# %%
# 9 - positive examples
# 16 - negative examples

# %%
import pickle
data_dict_file = "generated_data_dict_lab.pkl"
with open(data_dict_file, "rb") as f:
    generated_data_dict = pickle.load(f)

# %%
generated_dataset = [] # list of tuples, ((data 1, data 2), label)

for hadm_id in hadm_ids[:10]:
    print("***********************************")
    print(f"Patient {int(hadm_id)}")
    try:
        hadm_generated_dict = generated_data_dict[int(hadm_id)]
    except KeyError:
        print("This patient does not exist in contradiction set.")
        continue
        
    # Step 1: Select a patient -- process all data
    pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
                  med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
                  physician_only=True)

    # Step 2: Generate pairs for this patient
    df, data_inst_pairs = generate_data_pairs(pat)

    # Step 3A: Insert contradictions 
    print("+++++ Inserting contradictions +++++")
    for pair_idx, (is_sentence2, contradicting_txt) in hadm_generated_dict['contradiction'].items():
        data_1 = data_inst_pairs[pair_idx][0][0]
        data_2 = data_inst_pairs[pair_idx][0][1]

        print(f"{data_1.type} 1:\t{data_1.txt}")
        print(f"{data_2.type} 2:\t{data_2.txt}")

        sentence_to_modify = data_inst_pairs[pair_idx][0][is_sentence2]

        # Set `contradicting_txt` to the new contradicting sentence.
        # Update text and reprocess features.
        sentence_to_modify.update_text(contradicting_txt, True)

        print(f"\nNew contradicting sentence: {contradicting_txt}")
        print("+++++++++++++++++++++++++++++++++++")
        
        # Add example to dataset
        if is_sentence2:
            sentences = (data_1, sentence_to_modify)
        else:
            sentences = (sentence_to_modify, data_2)
        generated_dataset.append((sentences, 1)) # these are all contradictions
    
    # Step 3B: Insert negative examples (not contradictions)
    print("+++++ Inserting negative examples +++++")
    for pair_idx in hadm_generated_dict['none']:
        data_1 = data_inst_pairs[pair_idx][0][0]
        data_2 = data_inst_pairs[pair_idx][0][1]

        print(f"{data_1.type} 1:\t{data_1.txt}")
        print(f"{data_2.type} 2:\t{data_2.txt}")
        
        generated_dataset.append(((data_1, data_2), 0))
        print("+++++++++++++++++++++++++++++++++++")
# Out:
# ***********************************
# Patient 155131
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/dianaflores71798/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents

# %%
n = len(generated_dataset)
n_negatives = len(list(filter(lambda x: x[1]==0, generated_dataset)))
n_positives = len(list(filter(lambda x: x[1]==1, generated_dataset)))

print(f"We have {n} total examples\n\t- {n_negatives} negative examples\n\t- {n_positives} positive examples")

# %% [markdown]
# # 6. Generating evaluation data (unlabeled) from MIMIC
#
# We'll avoid the first 10 patients since they were used for generated contradictions

# %%
processed_dir = "processed"
os.makedirs(processed_dir, exist_ok=True)

# %%
per_pat_dataset_dict = {} # maps HADMID to patient's dataset in the form [((data 1, data 2), label), ...]
df_list = []
for hadm_id in hadm_ids[10:20]:
    print("***********************************")
    print(f"Patient {int(hadm_id)}")
        
    # Step 1: Select a patient -- process all data
    pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
                  med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
                  physician_only=True)

    # Step 2: Generate pairs for this patient
    df, data_inst_pairs = generate_data_pairs(pat)
    df['HADM_ID'] = hadm_id
    per_pat_dataset_dict[hadm_id] = data_inst_pairs
    df_list.append(df)
    
    df.to_csv(f"{processed_dir}/{int(hadm_id)}.csv")
# Out:
# ***********************************
# Patient 162197
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /home/yutsumi/opennotes-error-detection/data_structures.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['START_DT']] = start_dt
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /home/yutsumi/opennotes-error-detection/data_structures.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['END_DT']]   = end_dt
# /home/yutsumi/opennotes-error-detection/data_structures.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.prescription_df[['Sentence']] = prescription_sents
# /home/yutsumi/opennotes-error-detection/data_structures.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['DT']] = time_dt
# /home/yutsumi/opennotes-error-detection/data_structures.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['NULL_FLAG']] = self.lab_df.FLAG.isnull() # True if null, False otherwise
# /home/yutsumi/opennotes-error-detection/data_structures.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lab_df[['Sentence']] = lab_sents
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ********** Processing data for 2189-09-07 **********
# ********** Processing data for 2189-09-08 **********
# ***** PAIR INDEX 0 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Communicable Diseases'}
# >> Most likely with ascending GU infection.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Communicable Diseases'}
# >> Also sepsis criteria given identification of GU infection.'
# **********************************
# ***** PAIR INDEX 1 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis'}
# >> Findings c/w pyelonephritis with    ureteritis bilaterally.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis'}
# >> She had a grossly positive U/A, and CT Abd/Pelvis    showed evidence of bilateral pyelonephritis.'
# **********************************
# ***** PAIR INDEX 2 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> She denies ever having a urinary tract    infection.'
# **********************************
# ***** PAIR INDEX 3 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> She denies ever having a urinary tract    infection.'
# **********************************
# ***** PAIR INDEX 4 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# **********************************
# ***** PAIR INDEX 5 *****
# Cosine similarity: 0.5477225575051662
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Nausea', 'Hepatitis C, Chronic', 'Pyelonephritis', 'Chills', 'Dysuria'}
# >> Hypotension, pyelonephritis    HPI:    Ms.  [**Known lastname 385**]  is a 60 yo F with hx of chronic hepatitis C who presents    to the ED with dysuria x 4 days, chills, nausea and vomiting.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Dysuria', 'Hepatitis C', 'Liver Cirrhosis'}
# >>    Assessment: 60 yo female with hx of chronic hepatitis C infection    (without cirrhosis) presenting to the ED with 4 day hx of dysuria,    chills and found to have a grossly positive U/A with evidence of    bilateral pyelonephritis on CT Abd/pelvis who became hypotensive to    80/30.'
# **********************************
# ***** PAIR INDEX 6 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Incontinence', 'Dysuria'}
# >>    Genitourinary: Dysuria, hematuria, frequency, urgency, incontinence'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Incontinence', 'Dysuria'}
# >> She first    noted hematuria on Saturday, then developed dysuria, urinary frequency,    urgency and incontinence.'
# **********************************
# ***** PAIR INDEX 7 *****
# Cosine similarity: 0.6324555320336758
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Liver Cirrhosis', 'Pyelonephritis', 'Chills', 'Chronic infectious disease', 'Dysuria'}
# >> This is a 60 yo female hx of chronic hep C    infection (without cirrhosis), recent Bell s Palsy in  [**7-/2189**]  treated    with prednisone 20 mg x 10 days,  presenting to the ED with 4 day hx of    hematuria, dysuria, chills and found to have a grossly positive U/A    with evidence of bilateral pyelonephritis on CT Abd/pelvis who became    hypotensive to 80/30.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Dysuria', 'Hepatitis C', 'Liver Cirrhosis'}
# >>    Assessment: 60 yo female with hx of chronic hepatitis C infection    (without cirrhosis) presenting to the ED with 4 day hx of dysuria,    chills and found to have a grossly positive U/A with evidence of    bilateral pyelonephritis on CT Abd/pelvis who became hypotensive to    80/30.'
# **********************************
# ***** PAIR INDEX 8 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Liver Cirrhosis', 'Pyelonephritis', 'Chills', 'Chronic infectious disease', 'Dysuria'}
# >> This is a 60 yo female hx of chronic hep C    infection (without cirrhosis), recent Bell s Palsy in  [**7-/2189**]  treated    with prednisone 20 mg x 10 days,  presenting to the ED with 4 day hx of    hematuria, dysuria, chills and found to have a grossly positive U/A    with evidence of bilateral pyelonephritis on CT Abd/pelvis who became    hypotensive to 80/30.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Nausea', 'Hepatitis C, Chronic', 'Pyelonephritis', 'Chills', 'Dysuria'}
# >> Hypotension, pyelonephritis    HPI:    Ms.  [**Known lastname 385**]  is a 60 yo F with hx of chronic hepatitis C who presents    to the ED with dysuria x 4 days, chills, nausea and vomiting.'
# **********************************
# ***** PAIR INDEX 9 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis'}
# >> ['Chief Complaint:', "Pyelonephritis    24 Hour Events:    - pt received 5L in ED and additional 2L in the ICU    - pt pressures cont to run SBP 80-90's, but mentating well and good UOP"
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis'}
# >> She had a grossly positive U/A, and CT Abd/Pelvis    showed evidence of bilateral pyelonephritis.'
# **********************************
# ***** PAIR INDEX 10 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis'}
# >> ['Chief Complaint:', "Pyelonephritis    24 Hour Events:    - pt received 5L in ED and additional 2L in the ICU    - pt pressures cont to run SBP 80-90's, but mentating well and good UOP"
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis'}
# >> Findings c/w pyelonephritis with    ureteritis bilaterally.'
# **********************************
# ***** PAIR INDEX 11 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pressors', 'Pyelonephritis', 'Urinary tract infection', 'Septicemia'}
# >> UTI, pyelonephritis with sepsis, hypotensive, slowly improving BP, not    on pressors.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> She denies ever having a urinary tract    infection.'
# **********************************
# ***** PAIR INDEX 12 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pressors', 'Pyelonephritis', 'Urinary tract infection', 'Septicemia'}
# >> UTI, pyelonephritis with sepsis, hypotensive, slowly improving BP, not    on pressors.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# **********************************
# ***** PAIR INDEX 13 *****
# Cosine similarity: 0.6666666666666669
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pressors', 'Pyelonephritis', 'Urinary tract infection', 'Septicemia'}
# >> UTI, pyelonephritis with sepsis, hypotensive, slowly improving BP, not    on pressors.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# **********************************
# ***** PAIR INDEX 14 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Communicable Diseases'}
# >> Most likely with ascending GU infection.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Communicable Diseases'}
# >> Also sepsis criteria given identification of GU infection.'
# **********************************
# ***** PAIR INDEX 15 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Communicable Diseases'}
# >> Most likely with ascending GU infection.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Communicable Diseases'}
# >> Most likely with ascending GU infection.'
# **********************************
# ***** PAIR INDEX 16 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'nitroglycerin', 'Systane Balance', 'Blood Stop Topical Product', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Uridine'}
# >>    Height: 66 Inch              Total In:              7,667 mL    PO:              240 mL    TF:    IVF:    2,427 mL    Blood products:    Total out:                                                                       0 mL                                                                   1,880 mL    Urine:    1,480 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   5,787 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 92%'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'nitroglycerin', 'Systane Balance', 'Blood Stop Topical Product', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Uridine'}
# >>    Height: 66 Inch              Total In:              5,500 mL    PO:              TF:    IVF:    500 mL    Blood products:    Total out:                                                                       0 mL                                                                     790 mL    Urine:    390 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   4,710 mL    Respiratory    SpO2: 95%    Physical Examination'
# **********************************
# ***** PAIR INDEX 17 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Bacteremia'}
# >> Also possible spread from bacteremia, though no    reason to suspect this.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Bacteremia'}
# >> Also possible spread from bacteremia, though no    reason to suspect this.'
# **********************************
# ***** PAIR INDEX 18 *****
# Cosine similarity: 0.6546536707079772
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Adrenal gland hypofunction', 'hydrocortisone', 'Hydrocortisone'}
# >> Started on hydrocortisone for possible adrenal    insufficiency.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Adrenal gland hypofunction'}
# >> Consider relative    adrenal insufficiency (hx of pred x 10 d last month).'
# **********************************
# ***** PAIR INDEX 19 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> She denies ever having a urinary tract    infection.'
# **********************************
# ***** PAIR INDEX 20 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# **********************************
# ***** PAIR INDEX 21 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# **********************************
# ***** PAIR INDEX 22 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pressors', 'Pyelonephritis', 'Urinary tract infection', 'Septicemia'}
# >> UTI, pyelonephritis with sepsis, hypotensive, slowly improving BP, not    on pressors.'
# **********************************
# ***** PAIR INDEX 23 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with his /    her note above, including assessment and plan.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Infantile Neuroaxonal Dystrophy'}
# >> I agree with the above    findings and plan of care.'
# **********************************
# ***** PAIR INDEX 24 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> She denies ever having a urinary tract    infection.'
# **********************************
# ***** PAIR INDEX 25 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# **********************************
# ***** PAIR INDEX 26 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# **********************************
# ***** PAIR INDEX 27 *****
# Cosine similarity: 0.6666666666666669
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pressors', 'Pyelonephritis', 'Urinary tract infection', 'Septicemia'}
# >> UTI, pyelonephritis with sepsis, hypotensive, slowly improving BP, not    on pressors.'
# **********************************
# ***** PAIR INDEX 28 *****
# Cosine similarity: 0.7071067811865477
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Urinary tract infection'}
# >> No recent UTIs or hx of    resistent organisms.'
# **********************************
# ***** PAIR INDEX 29 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Hepatitis C', 'Therapeutic procedure'}
# >> # Chronic hepatitis C infection: Stable, has not required treatment.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Hepatitis C', 'Therapeutic procedure'}
# >> # Chronic hepatitis C infection: Stable, has not required treatment.'
# **********************************
# ***** PAIR INDEX 30 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Kidney Failure, Acute'}
# >> # Acute renal failure: Creatinine 1.0 today and treding down.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Kidney Failure, Acute'}
# >> # Acute renal failure: Creatinine 1.1 up from baseline 0.7.'
# **********************************
# ***** PAIR INDEX 31 *****
# Cosine similarity: 0.9128709291752769
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Sore to touch', 'Cerebrovascular accident'}
# >>    Musculoskeletal: CVA tenderness R>L'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Sore to touch', 'Cerebrovascular accident', 'Lung'}
# >> Lungs CTA, S1S2 normal, no murmurs, significant CVA tenderness, no LE    edema.'
# **********************************
# ***** PAIR INDEX 32 *****
# Cosine similarity: 0.6201736729460423
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Glucose', 'Pyelonephritis', 'Liver Cirrhosis', 'Infantile Neuroaxonal Dystrophy', 'glucose', 'Chills', 'Hepatitis C', 'Dysuria'}
# >> 1.0 mg/dL    21 mEq/L    3.2 mEq/L    13 mg/dL    109 mEq/L    137 mEq/L    28.3 %    6.9 K/uL         [image002.jpg]                              [**2189-9-8**]   04:59 AM    WBC    6.9    Hct    28.3    Plt    122    Cr    1.0    Glucose    120    Assessment and Plan    60 yo female with hx of chronic hepatitis C infection (without    cirrhosis) presenting to the ED with 4 day hx of dysuria, chills and    found to have a grossly positive U/A with evidence of bilateral    pyelonephritis on CT Abd/pelvis who became hypotensive to 80/30.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Dysuria', 'Hepatitis C', 'Liver Cirrhosis'}
# >>    Assessment: 60 yo female with hx of chronic hepatitis C infection    (without cirrhosis) presenting to the ED with 4 day hx of dysuria,    chills and found to have a grossly positive U/A with evidence of    bilateral pyelonephritis on CT Abd/pelvis who became hypotensive to    80/30.'
# **********************************
# ***** PAIR INDEX 33 *****
# Cosine similarity: 0.5892556509887895
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Pred Mild', 'Papain', 'Headache', 'BC Headache'}
# >>    Pain:  [**1-20**]  Mild    Pain location: headache    Flowsheet Data as of  [**2189-9-8**]  12:48 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since 12 AM'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'BC Headache', 'Dyspnea', 'Deglutition Disorders', 'Headache'}
# >>    ROS: +headache, no CP, SOB or dysphagia.'
# **********************************
# ***** PAIR INDEX 34 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Feverall', 'Physical therapy'}
# >> Pt    remains hypotensive even after receiving 5L of IVFs, but likely was    dehydrated prior to presentation and has high insensible losses due to    fever.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Feverall'}
# >> Likely    prerenal w/ combination of poor po intake, vomiting, fever.'
# **********************************
# ***** PAIR INDEX 35 *****
# Cosine similarity: 0.7905694150420948
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'BC Headache', 'Headache'}
# >>    Neurologic: Headache'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'BC Headache', 'Dyspnea', 'Deglutition Disorders', 'Headache'}
# >>    ROS: +headache, no CP, SOB or dysphagia.'
# **********************************
# ***** PAIR INDEX 36 *****
# Cosine similarity: 0.7453559924999298
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'BC Headache', 'Headache'}
# >>    Neurologic: Headache'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Americium', 'Pred Mild', 'Papain', 'Headache', 'BC Headache'}
# >>    Pain:  [**1-20**]  Mild    Pain location: headache    Flowsheet Data as of  [**2189-9-8**]  12:48 AM    Vital Signs    Hemodynamic monitoring    Fluid Balance                                                                   24 hours                                                                Since 12 AM'
# **********************************
# ***** PAIR INDEX 37 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'acute stress', 'Structure of palpebral conjunctiva', 'Nose', 'Ear structure', 'Sus scrofa conjunctiva preparation', 'Pharyngeal structure', 'Eye'}
# >>    General Appearance: No acute distress, Diaphoretic    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'acute stress', 'Structure of palpebral conjunctiva', 'Nose', 'Ear structure', 'Sus scrofa conjunctiva preparation', 'Pharyngeal structure', 'Eye'}
# >>    General Appearance: Well nourished, No acute distress    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 38 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'strontium'}
# >>    RR: 21 (18 - 26) insp/min    SpO2: 92%    Heart rhythm: SR (Sinus Rhythm)'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'strontium'}
# >>    RR: 19 (19 - 23) insp/min    SpO2: 95%    Heart rhythm: SR (Sinus Rhythm)'
# **********************************
# ***** PAIR INDEX 39 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >>    Genitourinary: Foley    Flowsheet Data as of   [**2189-9-8**]  06:58 AM    Vital signs    Hemodynamic monitoring    Fluid balance                                                                   24 hours                                                                Since 12 AM'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Americium'}
# >> will check random cortisol and start HC 25mg IV q6h to reassessed in    AM.'
# **********************************
# ***** PAIR INDEX 40 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'nitroglycerin', 'Systane Balance', 'Blood Stop Topical Product', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Uridine'}
# >>    Height: 66 Inch              Total In:              7,667 mL    PO:              240 mL    TF:    IVF:    2,427 mL    Blood products:    Total out:                                                                       0 mL                                                                   1,880 mL    Urine:    1,480 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   5,787 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 92%'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'nitroglycerin', 'Systane Balance', 'Blood Stop Topical Product', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Uridine'}
# >>    Height: 66 Inch              Total In:              5,500 mL    PO:              TF:    IVF:    500 mL    Blood products:    Total out:                                                                       0 mL                                                                     790 mL    Urine:    390 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   4,710 mL    Respiratory    SpO2: 95%    Physical Examination'
# **********************************
# ***** PAIR INDEX 41 *****
# Cosine similarity: 0.7071067811865475
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Sea Soft'}
# >>    Abdominal: Soft, Non-tender, Bowel sounds present'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Sea Soft', 'Cerebrovascular accident'}
# >>    Abdominal: Soft, Non-tender, Bowel sounds present, No(t) Tender: , CVA    tenderness R > L'
# **********************************
# ***** PAIR INDEX 42 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Feverall', 'Physical therapy'}
# >> Pt    remains hypotensive (SBP 80-90) even after receiving 7L of IVFs, but    likely was dehydrated prior to presentation and has high insensible    losses due to fever.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Feverall'}
# >> Likely    prerenal w/ combination of poor po intake, vomiting, fever.'
# **********************************
# ***** PAIR INDEX 43 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Feverall', 'Physical therapy'}
# >> Pt    remains hypotensive (SBP 80-90) even after receiving 7L of IVFs, but    likely was dehydrated prior to presentation and has high insensible    losses due to fever.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Feverall', 'Physical therapy'}
# >> Pt    remains hypotensive even after receiving 5L of IVFs, but likely was    dehydrated prior to presentation and has high insensible losses due to    fever.'
# **********************************
# ***** PAIR INDEX 44 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> ciprofloxacin, pt improving and no need to broaden.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> ciprofloxacin, may broaded to include vancomycin /    enterococcus coverage    - Monitor uop    .'
# **********************************
# ***** PAIR INDEX 45 *****
# Cosine similarity: 0.9999999999999999
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'heparin, porcine', 'heparin'}
# >> # PPx: heparin sc, bowel regimen    .'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'heparin, porcine', 'heparin'}
# >> # PPx: heparin sc, bowel regimen    .'
# **********************************
# ***** PAIR INDEX 46 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 00:00:00
# >> Type: prescription
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> Patient was prescribed Ciprofloxacin IV 400mg Premix Bag IV of total 400 mg
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> ciprofloxacin, may broaded to include vancomycin /    enterococcus coverage    - Monitor uop    .'
# **********************************
# ***** PAIR INDEX 47 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 00:00:00
# >> Type: prescription
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> Patient was prescribed Ciprofloxacin IV 400mg Premix Bag IV of total 400 mg
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> ciprofloxacin, pt improving and no need to broaden.'
# **********************************
# ***** PAIR INDEX 48 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 00:00:00
# >> Type: prescription
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> Patient was prescribed Ciprofloxacin IV 400mg Premix Bag IV of total 400 mg
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> ciprofloxacin, may broaded to include vancomycin /    enterococcus coverage    - Monitor uop    .'
# **********************************
# ***** PAIR INDEX 49 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 00:00:00
# >> Type: prescription
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> Patient was prescribed Ciprofloxacin IV 400mg Premix Bag IV of total 400 mg
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'ciprofloxacin', 'Ciprofloxacin'}
# >> ciprofloxacin, pt improving and no need to broaden.'
# **********************************
# ***** PAIR INDEX 50 *****
# Cosine similarity: 0.9999999999999999
# ----- Data i -----
# >> Time: 2189-09-08 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin, porcine', 'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'heparin, porcine', 'heparin'}
# >> # PPx: heparin sc, bowel regimen    .'
# **********************************
# ***** PAIR INDEX 51 *****
# Cosine similarity: 0.9999999999999999
# ----- Data i -----
# >> Time: 2189-09-08 00:00:00
# >> Type: prescription
# >> Concepts: {'heparin, porcine', 'heparin'}
# >> Patient was prescribed Heparin 5000 Units / mL- 1mL Vial SC of total 5000 UNIT
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'heparin, porcine', 'heparin'}
# >> # PPx: heparin sc, bowel regimen    .'
# **********************************
# ***** PAIR INDEX 52 *****
# Cosine similarity: 0.5547001962252291
# ----- Data i -----
# >> Time: 2189-09-08 00:00:00
# >> Type: lab
# >> Concepts: {'glucose', 'Glucose'}
# >> Patient's Glucose lab came back 120 mg/dL , which is abnormal.
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Glucose', 'Pyelonephritis', 'Liver Cirrhosis', 'Infantile Neuroaxonal Dystrophy', 'glucose', 'Chills', 'Hepatitis C', 'Dysuria'}
# >> 1.0 mg/dL    21 mEq/L    3.2 mEq/L    13 mg/dL    109 mEq/L    137 mEq/L    28.3 %    6.9 K/uL         [image002.jpg]                              [**2189-9-8**]   04:59 AM    WBC    6.9    Hct    28.3    Plt    122    Cr    1.0    Glucose    120    Assessment and Plan    60 yo female with hx of chronic hepatitis C infection (without    cirrhosis) presenting to the ED with 4 day hx of dysuria, chills and    found to have a grossly positive U/A with evidence of bilateral    pyelonephritis on CT Abd/pelvis who became hypotensive to 80/30.'
# **********************************
# ***** PAIR INDEX 53 *****
# Cosine similarity: 0.5892556509887897
# ----- Data i -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'acute stress', 'Structure of palpebral conjunctiva', 'Nose', 'Ear structure', 'Sus scrofa conjunctiva preparation', 'Pharyngeal structure', 'Eye'}
# >>    General Appearance: Well nourished, No acute distress    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pharyngeal structure', 'Nose'}
# >>    Constitutional: Fever    Ear, Nose, Throat: Dry mouth'
# **********************************
# ***** PAIR INDEX 54 *****
# Cosine similarity: 0.5892556509887897
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'acute stress', 'Structure of palpebral conjunctiva', 'Nose', 'Ear structure', 'Sus scrofa conjunctiva preparation', 'Pharyngeal structure', 'Eye'}
# >>    General Appearance: No acute distress, Diaphoretic    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pharyngeal structure', 'Nose'}
# >>    Constitutional: Fever    Ear, Nose, Throat: Dry mouth'
# **********************************
# ***** PAIR INDEX 55 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'acute stress', 'Structure of palpebral conjunctiva', 'Nose', 'Ear structure', 'Sus scrofa conjunctiva preparation', 'Pharyngeal structure', 'Eye'}
# >>    General Appearance: No acute distress, Diaphoretic    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'acute stress', 'Structure of palpebral conjunctiva', 'Nose', 'Ear structure', 'Sus scrofa conjunctiva preparation', 'Pharyngeal structure', 'Eye'}
# >>    General Appearance: Well nourished, No acute distress    Eyes / Conjunctiva: PERRL    Head, Ears, Nose, Throat: Normocephalic'
# **********************************
# ***** PAIR INDEX 56 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'All extremities'}
# >>    Extremities: Right: Trace, Left: Trace'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'All extremities'}
# >>    Extremities: Right: Absent, Left: Absent'
# **********************************
# ***** PAIR INDEX 57 *****
# Cosine similarity: 1.0
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'nitroglycerin', 'Systane Balance', 'Blood Stop Topical Product', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Uridine'}
# >>    Height: 66 Inch              Total In:              7,667 mL    PO:              240 mL    TF:    IVF:    2,427 mL    Blood products:    Total out:                                                                       0 mL                                                                   1,880 mL    Urine:    1,480 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   5,787 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 92%'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'nitroglycerin', 'Systane Balance', 'Blood Stop Topical Product', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Uridine'}
# >>    Height: 66 Inch              Total In:              5,500 mL    PO:              TF:    IVF:    500 mL    Blood products:    Total out:                                                                       0 mL                                                                     790 mL    Urine:    390 mL    NG:    Stool:    Drains:    Balance:                                                                       0 mL                                                                   4,710 mL    Respiratory    SpO2: 95%    Physical Examination'
# **********************************
# ***** PAIR INDEX 58 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt is afebrile and no longer tachy.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# **********************************
# ***** PAIR INDEX 59 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt is afebrile and no longer tachy.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Feverall', 'Physical therapy'}
# >> Pt    remains hypotensive even after receiving 5L of IVFs, but likely was    dehydrated prior to presentation and has high insensible losses due to    fever.'
# **********************************
# ***** PAIR INDEX 60 *****
# Cosine similarity: 0.6123724356957945
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Stress Dose Steroid Therapy', 'Physical therapy'}
# >> Pt also started on stress dose steriods.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Feverall', 'Physical therapy'}
# >> Pt    remains hypotensive even after receiving 5L of IVFs, but likely was    dehydrated prior to presentation and has high insensible losses due to    fever.'
# **********************************
# ***** PAIR INDEX 61 *****
# Cosine similarity: 0.7499999999999998
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Stress Dose Steroid Therapy', 'Physical therapy'}
# >> Pt also started on stress dose steriods.'
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt is afebrile and no longer tachy.'
# **********************************
# ***** PAIR INDEX 62 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# **********************************
# ***** PAIR INDEX 63 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt is afebrile and no longer tachy.'
# **********************************
# ***** PAIR INDEX 64 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Hepatitis C', 'Therapeutic procedure'}
# >> # Chronic hepatitis C infection: Stable, has not required treatment.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Hepatitis C', 'Therapeutic procedure'}
# >> # Chronic hepatitis C infection: Stable, has not required treatment.'
# **********************************
# ***** PAIR INDEX 65 *****
# Cosine similarity: 0.5773502691896258
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt    WBC count today down to 6.9.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Pyelonephritis', 'Urinary tract infection', 'Physical therapy'}
# >> # Pyelonephritis/Sepsis: Pt w/ signs and sx of UTI for several days.'
# **********************************
# ***** PAIR INDEX 66 *****
# Cosine similarity: 0.816496580927726
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt    WBC count today down to 6.9.'
# ----- Data j -----
# >> Time: 2189-09-08 00:49:00
# >> Type: sentence
# >> Concepts: {'Feverall', 'Physical therapy'}
# >> Pt    remains hypotensive even after receiving 5L of IVFs, but likely was    dehydrated prior to presentation and has high insensible losses due to    fever.'
# **********************************
# ***** PAIR INDEX 67 *****
# Cosine similarity: 0.9999999999999998
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt    WBC count today down to 6.9.'
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt is afebrile and no longer tachy.'
# **********************************
# ***** PAIR INDEX 68 *****
# Cosine similarity: 0.7499999999999998
# ----- Data i -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Physical therapy'}
# >> Pt    WBC count today down to 6.9.'
# ----- Data j -----
# >> Time: 2189-09-08 06:58:00
# >> Type: sentence
# >> Concepts: {'Stress Dose Steroid Therapy', 'Physical therapy'}
# >> Pt also started on stress dose steriods.'
# ...
# Cosine similarity: 0.6123724356957945
# ----- Data i -----
# >> Time: 2195-11-25 07:13:00
# >> Type: sentence
# >> Concepts: {'Hematocrit procedure', 'Chronic disease', 'Laboratory test finding', 'Anemia'}
# >> -- Guaiac negative    -- labs c/w anemia of chronic disease    -- trend HCT daily    .'
# ----- Data j -----
# >> Time: 2195-11-25 07:13:00
# >> Type: sentence
# >> Concepts: {'Laboratory test finding'}
# >>    Neuro: Alert and oriented x 3    Labs / Radiology    484 K/uL'
# **********************************
# ***** PAIR INDEX 136 *****
# Cosine similarity: 0.685506162763685
# ----- Data i -----
# >> Time: 2195-11-25 10:57:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]'}
# >> ATRIAL FIBRILLATION (AFIB):  Rate controlled.'
# ----- Data j -----
# >> Time: 2195-11-25 10:57:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'nitroglycerin', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Ting AF', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Systane Balance', 'Blood Stop Topical Product', 'Uridine'}
# >>    RR: 25 (19 - 28) insp/min    SpO2: 96%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 146.8 kg (admission): 146.8 kg              Total In:                                                                   3,927 mL                                                                     660 mL    PO:                                                                   1,640 mL                                                                     360 mL    TF:    IVF:                                                                   1,992 mL                                                                     300 mL    Blood products:    Total out:                                                                   5,895 mL                                                                   3,325 mL    Urine:                                                                   5,895 mL                                                                   3,325 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,968 mL                                                                  -2,665 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 96%'
# **********************************
# ***** PAIR INDEX 137 *****
# Cosine similarity: 1.0000000000000002
# ----- Data i -----
# >> Time: 2195-11-25 07:13:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'nitroglycerin', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Ting AF', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Systane Balance', 'Blood Stop Topical Product', 'Uridine'}
# >>    RR: 23 (16 - 28) insp/min    SpO2: 97%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 146.8 kg (admission): 146.8 kg                   Total In:                                                                   3,927 mL                                                                     240 mL    PO:                                                                   1,640 mL                                                                     240 mL    TF:    IVF:                                                                   1,992 mL    Blood products:    Total out:                                                                   5,895 mL                                                                   2,400 mL    Urine:                                                                   5,895 mL                                                                   2,400 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,968 mL                                                                  -2,160 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 97%'
# ----- Data j -----
# >> Time: 2195-11-25 10:57:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'nitroglycerin', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Ting AF', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Systane Balance', 'Blood Stop Topical Product', 'Uridine'}
# >>    RR: 25 (19 - 28) insp/min    SpO2: 96%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 146.8 kg (admission): 146.8 kg              Total In:                                                                   3,927 mL                                                                     660 mL    PO:                                                                   1,640 mL                                                                     360 mL    TF:    IVF:                                                                   1,992 mL                                                                     300 mL    Blood products:    Total out:                                                                   5,895 mL                                                                   3,325 mL    Urine:                                                                   5,895 mL                                                                   3,325 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,968 mL                                                                  -2,665 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 96%'
# **********************************
# ***** PAIR INDEX 138 *****
# Cosine similarity: 0.685506162763685
# ----- Data i -----
# >> Time: 2195-11-25 07:13:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'nitroglycerin', 'Blood product', 'Ventricular Fibrillation, Paroxysmal Familial, 1', 'Drainage procedure', 'Ting AF', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]', 'Systane Balance', 'Blood Stop Topical Product', 'Uridine'}
# >>    RR: 23 (16 - 28) insp/min    SpO2: 97%    Heart rhythm: AF (Atrial Fibrillation)    Wgt (current): 146.8 kg (admission): 146.8 kg                   Total In:                                                                   3,927 mL                                                                     240 mL    PO:                                                                   1,640 mL                                                                     240 mL    TF:    IVF:                                                                   1,992 mL    Blood products:    Total out:                                                                   5,895 mL                                                                   2,400 mL    Urine:                                                                   5,895 mL                                                                   2,400 mL    NG:    Stool:    Drains:    Balance:                                                                  -1,968 mL                                                                  -2,160 mL    Respiratory support    O2 Delivery Device: Nasal cannula    SpO2: 97%'
# ----- Data j -----
# >> Time: 2195-11-25 10:57:00
# >> Type: sentence
# >> Concepts: {'Atrial Fibrillation', 'Atrial Fibrillation Sotalol Hydrochloride 80 MG Oral Tablet [Betapace]'}
# >> ATRIAL FIBRILLATION (AFIB):  Rate controlled.'
# **********************************
# ********** Processing data for 2195-11-26 **********
# ********** Processing data for 2195-11-27 **********
# ********** Processing data for 2195-11-28 **********
# ********** Processing data for 2195-11-29 **********
# ********** Processing data for 2195-11-30 **********
# ********** Processing data for 2195-12-01 **********
# ********** Processing data for 2195-12-02 **********
# ***********************************
# Patient 160489
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/scispacy/candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-c25f15272c3d> in <module>
#       8     pat = Patient(hadm_id, notes_df, drug_df, lab_df, d_lab_df, \
#       9                   med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, \
# ---> 10                   physician_only=True)
#      11
#      12     # Step 2: Generate pairs for this patient
#
# ~/opennotes-error-detection/data_structures.py in __init__(self, hadm_id, notes_df, prescription_df, lab_df, d_lab_df, med7_nlp, umls_nlp, rxnorm_nlp, umls_linker, rxnorm_linker, physician_only)
#      64
#      65         # Process notes, prescriptions, and labs
# ---> 66         self.process_notes()
#      67         self.process_prescriptions()
#      68         self.process_labs()                # note: comment out if removing labs
#
# ~/opennotes-error-detection/data_structures.py in process_notes(self)
#      93         notes = []
#      94         for row_id in self.notes_df.ROW_ID:
# ---> 95             note = Note(self, row_id)
#      96             notes.append(note)
#      97         self.notes = notes
#
# ~/opennotes-error-detection/data_structures.py in __init__(self, patient, row_id)
#     320
#     321         # Process each sentence
# --> 322         self.process_sentences(sentences)
#     323
#     324     def process_sentences(self, sentences):
#
# ~/opennotes-error-detection/data_structures.py in process_sentences(self, sentences)
#     332             sent_rep = Sentence(self, idx,
#     333                                 filter_map=SEMANTIC_TYPE_TO_NAME,
# --> 334                                 conflict_map=CONFLICT_TO_SEMANTIC_TYPE)
#     335             sentence_reps.append(sent_rep)
#     336
#
# ~/opennotes-error-detection/data_structures.py in __init__(self, note, sentence_idx, filter_map, conflict_map, sentence)
#     511         self.type         = "sentence"
#     512
# --> 513         super(Sentence, self).__init__(note, txt, filter_map, conflict_map)
#     514
#     515     def update_text(self, new_text, run_reprocessing=False):
#
# ~/opennotes-error-detection/data_structures.py in __init__(self, dailydata, txt, filter_map, conflict_map)
#     420         self.umls_doc    = dailydata.umls(self.txt)
#     421         self.rxnorm_doc  = dailydata.rxnorm(self.txt)
# --> 422         self.med7_doc    = dailydata.med7(self.txt)
#     423
#     424         self.semantic_types = []
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     443             if not hasattr(proc, "__call__"):
#     444                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 445             doc = proc(doc, **component_cfg.get(name, {}))
#     446             if doc is None:
#     447                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     293     def begin_update(seqs_in, drop=0.0):
#     294         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 295         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     296         if bp_layer is None:
#     297             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      27
#      28     def begin_update(self, X, drop=0.0):
# ---> 29         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      30         if isinstance(X, list):
#      31             output = [X[i] + y[i] for i in range(len(X))]
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      60     def begin_update(self, X, drop=0.0):
#      61         if self.child is not None:
# ---> 62             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      63         else:
#      64             backprop_child = None
#
# /opt/conda/envs/opennotes/lib/python3.7/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      74         if drop is not None:
#      75             drop *= self.drop_factor
# ---> 76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %% [markdown]
# ### Getting History + Allergy Information - @Sharon, you can ignore everytihng below

# %%
# todo: 
# - DONE function to re-process all data from Patient instance -- pat.process_notes(); pat.process_by_date()
# - function to update Note -- should update dataframe of patient directly
#   - can go back to dataframe, but can't map tokenized sentence to original note in df -- todo
#   - function to update tokenized sentence
# - later: function to update original dataframe from patient dataframe

import re

def get_section(regex_dict, txt):
    """ Given a dictionary of start and end regex's for a
        particular section, gets the start and endpoint of 
        section in the text and returns indices. 
        Returns None if section does not exist.
    """
    try:
        start    = re.search(regex_dict["start"], txt).start()
        end      = re.search(regex_dict["end"],   txt).start()
    except AttributeError:
        start, end = None, None
    
    return start, end

note = pat.notes[4]

# Sections to store 
# note: most of these sections have already been removed,
#       but if they haven't might have to remove then 
#       reprocess everything
allergy_regex = {"start": "Allergies:",
                 "end":   "Last dose of Antibiotics:"}
history_regex = {"start": "Past medical history:",
                 "end":   "Other:"}

allergy_start, allergy_end = get_section(allergy_regex, note.txt)
history_start, history_end = get_section(history_regex, note.txt)

pt_allergies = "" if allergy_start is None else note.txt[allergy_start:allergy_end]
pt_histories = "" if history_start is None else note.txt[history_start:history_end]

print("******** Allergies ********")
print(pt_allergies[:100])
print("******** Histories ********")
print(pt_histories[:100])
# Out:
# ******** Allergies ********
# Allergies:
#    Bactrim (Oral) (Sulfamethoxazole/Trimethoprim)
#    Nausea/Vomiting
#    Amiodarone
#    Ras
# ******** Histories ********
